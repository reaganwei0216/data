# %%
# from bs4 import BeautifulSoup, SoupStrainer
# import requests
# import pandas as pd
# url='http://data.judicial.gov.tw/'
# table = pd.read_html(url)[1]
# print(table.shape)
# table = table.drop(table.columns[0:2],axis=0)  #delete rows
# table = table.drop(table.columns[2:table.shape[1]],axis=1)    #delete columns
# table
# Out:
#                              檔案名稱         大小
# 0                      199601.rar    2673029
# 1                      199602.rar    1973538
# 2                      199603.rar    2396411
# 3                      199604.rar    2497431
# 4                      199605.rar    2908691
# 5                      199606.rar    2456341
# 6                      199607.rar    2310602
# 7                      199608.rar    2750300
# 8                      199609.rar    2625571
# 9                      199610.rar    2689673
# 10                     199611.rar    2576306
# 11                     199612.rar    3258976
# 12                     199701.rar    3398733
# 13                     199702.rar    2099142
# 14                     199703.rar    3690761
# 15                     199704.rar    3699459
# 16                     199705.rar    3680557
# 17                     199706.rar    3370214
# 18                     199707.rar    3332080
# 19                     199708.rar    2832390
# ...

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
url='http://data.judicial.gov.tw/'
df=pd.read_html(url)[1]
df
# Out:
#                              檔案名稱         大小
# 0                      199601.rar    2673029
# 1                      199602.rar    1973538
# 2                      199603.rar    2396411
# 3                      199604.rar    2497431
# 4                      199605.rar    2908691
# 5                      199606.rar    2456341
# 6                      199607.rar    2310602
# 7                      199608.rar    2750300
# 8                      199609.rar    2625571
# 9                      199610.rar    2689673
# 10                     199611.rar    2576306
# 11                     199612.rar    3258976
# 12                     199701.rar    3398733
# 13                     199702.rar    2099142
# 14                     199703.rar    3690761
# 15                     199704.rar    3699459
# 16                     199705.rar    3680557
# 17                     199706.rar    3370214
# 18                     199707.rar    3332080
# 19                     199708.rar    2832390
# ...

# %%
df.shape[0]
df.shape
# Out:
# (283, 3)

# %%
# df=df.iloc[3:df.shape[0],0:2]

# %%
df.columns=["filename","size","url"]

# %%
df["url"]="http://data.judicial.gov.tw/rar/"+df["filename"]

# %%
df.head()
# Out:
#      filename     size                                         url
# 0  199601.rar  2673029  http://data.judicial.gov.tw/rar/199601.rar
# 1  199602.rar  1973538  http://data.judicial.gov.tw/rar/199602.rar
# 2  199603.rar  2396411  http://data.judicial.gov.tw/rar/199603.rar
# 3  199604.rar  2497431  http://data.judicial.gov.tw/rar/199604.rar
# 4  199605.rar  2908691  http://data.judicial.gov.tw/rar/199605.rar

# %%
df.tail()
# Out:
#                          filename       size  \
# 278  201903--(20190818Update).rar  211179952
# 279  201904--(20190818Update).rar  212161094
# 280  201905--(20190818Update).rar  238995910
# 281  201906--(20190818Update).rar  210589516
# 282              Delete-Infor.csv       1102
#
#                                                    url
# 278  http://data.judicial.gov.tw/rar/201903--(20190...
# 279  http://data.judicial.gov.tw/rar/201904--(20190...
# 280  http://data.judicial.gov.tw/rar/201905--(20190...
# 281  http://data.judicial.gov.tw/rar/201906--(20190...
# 282   http://data.judicial.gov.tw/rar/Delete-Infor.csv

# %%
df.loc[282,"url"]
# Out:
# 'http://data.judicial.gov.tw/rar/Delete-Infor.csv'

# %%
df.loc[282,"filename"]
type(df.loc[282,'filename'])
# Out:
# str

# %%
# C:\Users\bigdata
filename='D:\\\Scripts\\\R\\\judge\\\\' + df.iloc[282,0]
filename
# Out:
# 'D:\\\\Scripts\\\\R\\\\judge\\\\Delete-Infor.csv'

# %%
import requests
print('Beginning file download with requests')
url = df.loc[285,"url"]
r = requests.get(url)
filename='D:\\Scripts\\R\\judge\\' + df.iloc[282,0]

with open(local, 'wb') as f:
    f.write(r.content)

# Retrieve HTTP meta-data
print(r.status_code)
print(r.headers['content-type'])
print(r.encoding)
# Out:
# Beginning file download with requests
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 285
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-adc84f608cf8> in <module>
# ...

# %%
% dir
# Out:
# UsageError: Line magic function `%` not found.
