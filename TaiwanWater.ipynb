# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://www.water.gov.tw/member_mobilesearch_act.aspx'

# %%
payload = {"waternumber1":"C1","waternumber2": "23332005","waternumber3":"0"}

# %%
res = requests.post(url , data = payload)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n\r\n<html>\r\n    \r\n<head>\r\n<meta charset="UTF-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n<title>台灣自來水公司</title>\r\n<link rel="stylesheet" href="styles/layout_main_Mobile/css/jquery.mobile.structure-1.3.2.css">\r\n<!--<link rel="stylesheet" href="css/csu.css"> -->\r\n<link rel="stylesheet" href="styles/layout_main_Mobile/css/mobile.css">\r\n<script type="text/javascript" src="js/counter_e.js"></script>\r\n<script type="text/javascript" src="js/checkwaterno.js"></script>\r\n<script type="text/javascript" src="js/jquery.js"></script>\r\n<script type="text/javascript" src="js/jquery.mobile-1.3.2.min.js"></script>\r\n <META   HTTP-EQUIV="Pragma"   CONTENT="no-cache">  \r\n  <META   HTTP-EQUIV="Cache-Control"   CONTENT="no-cache">  \r\n  <META   HTTP-EQUIV="Expires"   CONTENT="0">  \r\n\r\n<script>\r\n\r\n    function changeactionfun() {\r\n        var form1 = document.getElementById(\'creditcard_form\');\r\n        for
# ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    台灣自來水公司
#   </title>
#   <link href="styles/layout_main_Mobile/css/jquery.mobile.structure-1.3.2.css" rel="stylesheet"/>
#   <!--<link rel="stylesheet" href="css/csu.css"> -->
#   <link href="styles/layout_main_Mobile/css/mobile.css" rel="stylesheet"/>
#   <script src="js/counter_e.js" type="text/javascript">
#   </script>
#   <script src="js/checkwaterno.js" type="text/javascript">
#   </script>
#   <script src="js/jquery.js" type="text/javascript">
#   </script>
#   <script src="js/jquery.mobile-1.3.2.min.js" type="text/javascript">
#   </script>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="no-cache" http-equiv="Cache-Control"/>
#   <meta content="0" http-equiv="Expires"/>
#   <script>
#    function changeactionfun() {
#         var form1 = document.getElementById('creditcard_form');
# ...

# %%
# a = soup.select('table')[0]

# %%
# type(a)
# Out:
# bs4.element.Tag

# %%
# b=str(a)

# %%
# type(b)
# Out:
# str

# %%
# b

# %%
str(soup.select('table')[1])
# Out:
# '<table>\n<h3>帳單資料 第2筆</h3>\n<!--<a href="https://www.water.gov.tw/ct.aspx?xItem=55802&CtNode=760&mp=1" style="color:red;" target="_blank">前往繳費方式簡介</a> -->\n<tr>\n<th scope="row">水號：</th>\n<td>C1233320050</td>\n</tr>\n<tr>\n<th scope="row">水號地址：</th>\n<td>＊＊＊２弄１４－３號</td>\n</tr>\n<tr>\n<th scope="row">繳費年月: </th>\n<td>10804</td>\n</tr>\n<tr>\n<th scope="row">帳單到期日:</th>\n<td>108/04/21</td>\n</tr>\n<tr>\n<th scope="row">用水度數(不含分攤度數):</th>\n<td>31度</td>\n</tr>\n<tr>\n<th scope="row">合計度數(含分攤度數):</th>\n<td>31度</td>\n</tr>\n<tr>\n<th scope="row">應繳金額:</th>\n<td>334元</td>\n</tr>\n<tr>\n<th scope="row">實繳金額:</th>\n<td>334元</td>\n</tr>\n<tr>\n<th scope="row">銷帳日期:</th>\n<td>108/ 4/ 9</td>\n</tr>\n<tr>\n<th scope="row">繳費狀況:</th>\n<td>已繳費\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t</td>\n</tr>\n<tr>\n<th scope="row">與去年比較增減度數:</th>\n<td>N/A</td>\n</tr>\n<tr>\n<th scope="row">省水比例(含分攤度數):</th>\n<td>N/A</td>\n</tr>\n<tr>\n<th scope="row">省水比例(不含分攤度數):</th>\n<td>N/A</td>\n</tr>\n<tr>\n<th scope="row"></th>\
# ...

# %%
pd.read_html(str(soup.select('table')[0]))[0]
# Out:
#                 0            1
# 0             水號：  C1233320050
# 1           水號地址：   ＊＊＊２弄１４－３號
# 2           繳費年月:        10806
# 3          帳單到期日:    108/06/21
# 4   用水度數(不含分攤度數):          33度
# 5    合計度數(含分攤度數):          33度
# 6           應繳金額:         354元
# 7           實繳金額:         354元
# 8           銷帳日期:    108/ 6/ 6
# 9           繳費狀況:          已繳費
# 10     與去年比較增減度數:          NaN
# 11   省水比例(含分攤度數):          NaN
# 12  省水比例(不含分攤度數):          NaN
# 13            NaN          NaN

# %%
pd.read_html(str(soup.select('table')[1]))[0]
# Out:
#                 0            1
# 0             水號：  C1233320050
# 1           水號地址：   ＊＊＊２弄１４－３號
# 2           繳費年月:        10804
# 3          帳單到期日:    108/04/21
# 4   用水度數(不含分攤度數):          31度
# 5    合計度數(含分攤度數):          31度
# 6           應繳金額:         334元
# 7           實繳金額:         334元
# 8           銷帳日期:    108/ 4/ 9
# 9           繳費狀況:          已繳費
# 10     與去年比較增減度數:          NaN
# 11   省水比例(含分攤度數):          NaN
# 12  省水比例(不含分攤度數):          NaN
# 13            NaN          NaN

# %%
type(pd.read_html(str(soup.select('table')[1]))[0])
# Out:
# pandas.core.frame.DataFrame

# %%
DfWater=pd.DataFrame()

# %%
for i in range(0,11):
    print(i)
    df=pd.read_html(str(soup.select('table')[i]))[0]
    print("---")
    print(df)
# Out:
# 0
# ---
#                 0            1
# 0             水號：  C1233320050
# 1           水號地址：   ＊＊＊２弄１４－３號
# 2           繳費年月:        10806
# 3          帳單到期日:    108/06/21
# 4   用水度數(不含分攤度數):          33度
# 5    合計度數(含分攤度數):          33度
# 6           應繳金額:         354元
# 7           實繳金額:         354元
# 8           銷帳日期:    108/ 6/ 6
# 9           繳費狀況:          已繳費
# 10     與去年比較增減度數:          NaN
# 11   省水比例(含分攤度數):          NaN
# 12  省水比例(不含分攤度數):          NaN
# 13            NaN          NaN
# 1
# ---
#                 0            1
# 0             水號：  C1233320050
# 1           水號地址：   ＊＊＊２弄１４－３號
# 2           繳費年月:        10804
# 3          帳單到期日:    108/04/21
# 4   用水度數(不含分攤度數):          31度
# 5    合計度數(含分攤度數):          31度
# 6           應繳金額:         334元
# 7           實繳金額:         334元
# 8           銷帳日期:    108/ 4/ 9
# 9           繳費狀況:          已繳費
# 10     與去年比較增減度數:          NaN
# 11   省水比例(含分攤度數):          NaN
# 12  省水比例(不含分攤度數):          NaN
# ...
