# %% [markdown]
# ## 資料庫操作

# %%
import sqlite3 as lite
con = lite.connect('test.sqlite')
cur = con.cursor()
cur.execute('SELECT SQLITE_VERSION();')
data = cur.fetchone()
print(data)
con.close()
# Out:
# ('3.14.2',)

# %%
with lite.connect('test.sqlite') as con:
    cur = con.cursor()
    cur.execute('SELECT SQLITE_VERSION();')
    data = cur.fetchone()
    print(data)
# Out:
# ('3.14.2',)

# %%
with lite.connect("test.sqlite") as con: 
    cur = con.cursor() 
    # 如果表格存在，捨棄表格
    cur.execute("DROP TABLE IF EXISTS PhoneAddress")
    # 建立PhoneAddress 表格
    cur.execute("CREATE TABLE PhoneAddress(\
                      phone   CHAR(10) PRIMARY KEY, \
                      address TEXT                , \
                      name    TEXT unique         , \
                      age     INT NOT NULL)") 
    # 新增資料
    cur.execute("INSERT INTO PhoneAddress VALUES(\
                  '0912173381','United State','Jhon Doe',53)") 
    cur.execute("INSERT INTO PhoneAddress VALUES(\
                  '0928375018','Tokyo Japan','MuMu Cat',6)") 
    cur.execute("INSERT INTO PhoneAddress VALUES(\
                  '0957209108','Taipei','Richard',29)")
    #查詢資料
    cur.execute("SELECT phone,address FROM PhoneAddress") 
    data = cur.fetchall() 
    for rec in data: 
        print(rec)
        #print(rec[0], rec[1])
# Out:
# ('0912173381', 'United State')
# ('0928375018', 'Tokyo Japan')
# ('0957209108', 'Taipei')

# %%
with lite.connect("test.sqlite") as con: 
    cur = con.cursor() 
    #查詢資料
    cur.execute("SELECT phone,address FROM PhoneAddress") 
    data = cur.fetchone()
    print(data)
    #data = cur.fetchall()
    #print(data)
    #for rec in data: 
    #    print(rec)
        #print(rec[0], rec[1])
# Out:
# ('0912173381', 'United State')

# %%
with lite.connect("test.sqlite") as con: 
    cur = con.cursor() 
    #查詢資料
    cur.execute("SELECT phone,address FROM PhoneAddress") 
    data = cur.fetchone()
    print(data)
    data = cur.fetchall()
    print(data)
    #for rec in data: 
    #    print(rec)
        #print(rec[0], rec[1])
# Out:
# ('0912173381', 'United State')
# [('0928375018', 'Tokyo Japan'), ('0957209108', 'Taipei')]

# %% [markdown]
# ## 使用Pandas 操作SQLite

# %%
import pandas
employee = [{'name':'Mary', 'age':23 , 'gender': 'F'},\
            {'name':'John', 'age':33 , 'gender': 'M'}]

df = pandas.DataFrame(employee)
df
# Out:
#    age gender  name
# 0   23      F  Mary
# 1   33      M  John

# %%
import sqlite3 as lite
with lite.connect('test.sqlite') as db:
    df.to_sql(name='employee', index=False, con=db, if_exists='replace')

# %% [markdown]
# ## 台銀匯率查詢存入資料庫

# %%
import pandas
dfs = pandas.read_html('http://rate.bot.com.tw/xrt/quote/l6m/USD')
df = dfs[0]
df.info
df.columns = ['掛牌日期', '幣別', '現金匯率-買入','現金匯率-賣出', '即期匯率-買入', '即期匯率-賣出','多的']
df[['掛牌日期', '幣別', '現金匯率-買入','現金匯率-賣出', '即期匯率-買入', '即期匯率-賣出']]
# Out:
#            掛牌日期        幣別  現金匯率-買入  現金匯率-賣出  即期匯率-買入  即期匯率-賣出
# 0    2018/01/26  美金 (USD)   28.735   29.277   29.035   29.135
# 1    2018/01/25  美金 (USD)   28.695   29.237   28.995   29.095
# 2    2018/01/24  美金 (USD)   28.860   29.402   29.160   29.260
# 3    2018/01/23  美金 (USD)   28.910   29.452   29.210   29.310
# 4    2018/01/22  美金 (USD)   28.990   29.532   29.290   29.390
# 5    2018/01/19  美金 (USD)   29.060   29.602   29.360   29.460
# 6    2018/01/18  美金 (USD)   29.200   29.742   29.500   29.600
# 7    2018/01/17  美金 (USD)   29.200   29.742   29.500   29.600
# 8    2018/01/16  美金 (USD)   29.195   29.737   29.495   29.595
# 9    2018/01/15  美金 (USD)   29.185   29.727   29.485   29.585
# 10   2018/01/12  美金 (USD)   29.245   29.787   29.545   29.645
# 11   2018/01/11  美金 (USD)   29.250   29.792   29.550   29.650
# 12   2018/01/10  美金 (USD)   29.245   29.787   29.545   29.645
# 13   2018/01/09  美金 (USD)   29.185   29.727   29.485   29.585
# 14   2018/01/08  美金 (USD)   29.150   29.692   29.450   29.550
# 15   2018/01/05  美金 (USD)   29.150   29.692   29.450   29.550
# 16   2018/01/04  美金 (USD)   29.230   29.772   29.530   29.630
# 17   2018/01/03  美金 (USD)   29.225   29.767   29.525   29.625
# 18   2018/01/02  美金 (USD)   29.265   29.807   29.565   29.665
# 19   2017/12/29  美金 (USD)   29.410   29.952   29.710   29.810
# 20   2017/12/28  美金 (USD)   29.420   29.962   29.720   29.820
# 21   2017/12/27  美金 (USD)   29.580   30.122   29.880   29.980
# 22   2017/12/26  美金 (USD)   29.595   30.137   29.895   29.995
# 23   2017/12/25  美金 (USD)   29.610   30.152   29.910   30.010
# 24   2017/12/22  美金 (USD)   29.610   30.152   29.910   30.010
# 25   2017/12/21  美金 (USD)   29.630   30.172   29.930   30.030
# 26   2017/12/20  美金 (USD)   29.645   30.187   29.945   30.045
# 27   2017/12/19  美金 (USD)   29.635   30.177   29.935   30.035
# 28   2017/12/18  美金 (USD)   29.655   30.197   29.955   30.055
# 29   2017/12/15  美金 (USD)   29.630   30.172   29.930   30.030
# ..          ...       ...      ...      ...      ...      ...
# 97   2017/09/08  美金 (USD)   29.640   30.182   29.940   30.040
# 98   2017/09/07  美金 (USD)   29.690   30.232   29.990   30.090
# 99   2017/09/06  美金 (USD)   29.745   30.287   30.045   30.145
# 100  2017/09/05  美金 (USD)   29.710   30.252   30.010   30.110
# 101  2017/09/04  美金 (USD)   29.740   30.282   30.040   30.140
# 102  2017/09/01  美金 (USD)   29.765   30.307   30.065   30.165
# 103  2017/08/31  美金 (USD)   29.830   30.372   30.130   30.230
# 104  2017/08/30  美金 (USD)   29.800   30.342   30.100   30.200
# 105  2017/08/29  美金 (USD)   29.845   30.387   30.145   30.245
# 106  2017/08/28  美金 (USD)   29.810   30.352   30.110   30.210
# 107  2017/08/25  美金 (USD)   29.880   30.422   30.180   30.280
# 108  2017/08/24  美金 (USD)   29.910   30.452   30.210   30.310
# 109  2017/08/23  美金 (USD)   29.935   30.477   30.235   30.335
# 110  2017/08/22  美金 (USD)   29.940   30.482   30.240   30.340
# 111  2017/08/21  美金 (USD)   29.970   30.512   30.270   30.370
# 112  2017/08/18  美金 (USD)   29.970   30.512   30.270   30.370
# 113  2017/08/17  美金 (USD)   29.955   30.497   30.255   30.355
# 114  2017/08/16  美金 (USD)   30.000   30.542   30.300   30.400
# 115  2017/08/15  美金 (USD)   29.935   30.477   30.235   30.335
# 116  2017/08/14  美金 (USD)   29.950   30.492   30.250   30.350
# 117  2017/08/11  美金 (USD)   29.985   30.527   30.285   30.385
# 118  2017/08/10  美金 (USD)   29.950   30.492   30.250   30.350
# 119  2017/08/09  美金 (USD)   29.865   30.407   30.165   30.265
# 120  2017/08/08  美金 (USD)   29.840   30.382   30.140   30.240
# 121  2017/08/07  美金 (USD)   29.875   30.417   30.175   30.275
# 122  2017/08/04  美金 (USD)   29.835   30.377   30.135   30.235
# 123  2017/08/03  美金 (USD)   29.850   30.392   30.150   30.250
# 124  2017/08/02  美金 (USD)   29.870   30.412   30.170   30.270
# 125  2017/08/01  美金 (USD)   29.880   30.422   30.180   30.280
# 126  2017/07/31  美金 (USD)   29.845   30.387   30.145   30.245
#
# [127 rows x 6 columns]

# %%
import pandas
dfs = pandas.read_html('http://rate.bot.com.tw/xrt/quote/l6m/USD')
df = dfs[0]
#df = df[[0,1,2,3,4,5]]
df.columns = ['掛牌日期', '幣別', '現金匯率-買入','現金匯率-賣出', '即期匯率-買入', '即期匯率-賣出','多的']
df=df[['掛牌日期', '幣別', '現金匯率-買入','現金匯率-賣出', '即期匯率-買入', '即期匯率-賣出']]

with lite.connect('test.sqlite') as db:
    df.to_sql(name='USD', index=False, con=db, if_exists='replace')

# %% [markdown]
# ## 安裝 MySQLdb
# - pip install PyMySQL
# - https://github.com/ywchiu/pyfintech2/blob/master/20160924Demo.ipynb  連結資料庫

# %%
! pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-0.7.11-py2.py3-none-any.whl (78kB)
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-0.7.11

# %%
import pymysql

from sqlalchemy import create_engine
#engine = create_engine("mysql+pymysql://USER:"+'PASSWORD'+"@localhost/DATABASE?charset=utf8", encoding = 'UTF-8')
engine = create_engine("mysql+pymysql://root:"+'test'+"@localhost/appledaily?charset=utf8", encoding = 'UTF-8')
df.to_sql(name='currency2', con=engine, if_exists='replace')
db.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xA5x\\xA5_\\xBC\\xD0...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)

# %% [markdown]
# ## 華納威秀訂票爬蟲

# %%
import requests
headers = {
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
'Cookie':'ASP.NET_SessionId=3bnpc5ejpkoq4sdysww5jfgl; _ga=GA1.3.366970417.1502011895; _gid=GA1.3.338287781.1503197651'
}
res = requests.post('https://sales.vscinemas.com.tw/VieShowTicket/Home/SelectSeats', data = {}, headers = headers)
#dfs = pandas.read_html(res.text)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')
seat_ary = []
for seat in soup.select('td[data-type="Empty"]'):
    #print(seat['data-col'],seat['data-name'])
    seat_ary.append({'座位號':seat['data-col'], '排號':seat['data-name']})
df = pandas.DataFrame(seat_ary)
df
# Out:
#     座位號 排號
# 0     1  B
# 1     2  B
# 2     3  B
# 3     4  B
# 4     5  B
# 5     6  B
# 6     7  B
# 7     8  B
# 8     9  B
# 9    10  B
# 10   11  B
# 11   12  B
# 12    1  C
# 13    2  C
# 14    3  C
# 15    4  C
# 16    5  C
# 17    6  C
# 18    7  C
# 19    8  C
# 20    9  C
# 21   10  C
# 22   11  C
# 23   12  C
# 24    1  D
# 25    2  D
# 26    3  D
# 27    4  D
# 28    5  D
# 29    6  D
# ..   .. ..
# 100  11  J
# 101  12  J
# 102   3  K
# 103   4  K
# 104   5  K
# 105   6  K
# 106   7  K
# 107   8  K
# 108   9  K
# 109  10  K
# 110  11  K
# 111  12  K
# 112   1  L
# 113   2  L
# 114   3  L
# 115   4  L
# 116   5  L
# 117   6  L
# 118   7  L
# 119   8  L
# 120   9  L
# 121  10  L
# 122  11  L
# 123  12  L
# 124   1  M
# 125   6  M
# 126   7  M
# 127   8  M
# 128   9  M
# 129  12  M
#
# [130 rows x 2 columns]

# %% [markdown]
# ## Selenium
# - https://addons.mozilla.org/en-US/firefox/addon/selenium-ide/
# - https://sites.google.com/a/chromium.org/chromedriver/downloads
# - https://chromedriver.storage.googleapis.com/2.31/chromedriver_win32.zip

# %% [markdown]
# ## 華納威秀查電影片

# %%
# -*- coding: utf-8 -*-
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re


driver = webdriver.Chrome('chromedriver.exe')
driver.implicitly_wait(30)    

driver.get('http://web.vscinemas.com.tw')
Select(driver.find_element_by_name("cinema")).select_by_visible_text(u"台北信義威秀影城")
Select(driver.find_element_by_name("movie")).select_by_visible_text(u"(數位)模犯生")
Select(driver.find_element_by_name("date")).select_by_visible_text(u"今天")
driver.find_element_by_css_selector("option[value=\"2017/08/20\"]").click()
time.sleep(3)
Select(driver.find_element_by_name("session")).select_by_visible_text("19:30")
driver.find_element_by_css_selector("input[type=\"button\"]").click()
time.sleep(3)
driver.find_element_by_css_selector("a.icon-vsgeneral > h2").click()
time.sleep(3)
driver.find_element_by_name("agree").click()
time.sleep(3)
driver.find_element_by_css_selector("input[type=\"submit\"]").click()
time.sleep(3)
driver.find_element_by_link_text(u"一般票種").click()
time.sleep(3)
Select(driver.find_element_by_id("HO000000010001")).select_by_visible_text("2")
driver.find_element_by_css_selector("#HO000000010001 > option[value=\"2\"]").click()
time.sleep(3)
driver.find_element_by_id("btnDoNext").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-2-50b99a197973> in <module>()
#      14 driver.get('http://web.vscinemas.com.tw')
#      15 Select(driver.find_element_by_name("cinema")).select_by_visible_text(u"台北信義威秀影城")
# ---> 16 Select(driver.find_element_by_name("movie")).select_by_visible_text(u"(數位)模犯生")
#      17 Select(driver.find_element_by_name("date")).select_by_visible_text(u"今天")
#      18 driver.find_element_by_css_selector("option[value=\"2017/08/20\"]").click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\support\select.py in select_by_visible_text(self, text)
#     138
#     139         if not matched:
# --> 140             raise NoSuchElementException("Could not locate element with visible text: %s" % text)
#     141
#     142     def deselect_all(self):
#
# NoSuchElementException: Message: Could not locate element with visible text: (數位)模犯生

# %% [markdown]
# ## Facebook AutoLogin
# - https://buyaccs.com/
# - 無痕視窗

# %%
# -*- coding: utf-8 -*-
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re

driver = webdriver.Chrome()
driver.implicitly_wait(30)
base_url = "https://www.facebook.com/"


driver.get(base_url)
driver.find_element_by_id("email").clear()
driver.find_element_by_id("email").send_keys("KodratVorobev1989@mail.ru")
driver.find_element_by_id("pass").clear()
driver.find_element_by_id("pass").send_keys("l0axJAB")
driver.find_element_by_id("u_0_0").click()
driver.find_element_by_id("q").click()
time.sleep(3)

# %%
driver.get('https://www.facebook.com/mdc.cwb')

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.select('.fbTimelineTimePeriod .userContent')
# Out:
# [<div class="_5pbx userContent" data-ft='{"tn":"K"}' id="js_h"><p>寬廣的"火彩虹"</p><p> 這其實不是彩虹，是稱為"環地平弧"的日暈現象，紅色在上，藍紫色在下，通常只出現一小段，理論上有可能是最壯闊艷麗的日暈。<br/> 感謝胡家銓網友來自美國新墨西哥州的分享~</p></div>,
#  <div class="_5pbx userContent" data-ft='{"tn":"K"}' id="js_k"><p>Tyrone Lin 提供的"清晨殘月(潤6月29)"</p><p> 預告農曆七月的來臨~<br/> 大約我5歲時，曾經跌入退潮海邊的水道中，差點回不了家，從此對水存在深深的恐懼感。那一次，回到家時，媽媽和祖母正在拜拜，我問拜什麼，祖母回答：拜七娘媽。那就是民間七夕的拜拜，所以七夕對我來說也是個很特別的日子。我還記得，供桌上有兩大串龍眼，拜完後祖母給我一小串龍眼，那是最好吃的一串龍眼~</p></div>]

# %% [markdown]
# ## 儲存實例

# %%
import pandas
df = pandas.read_csv('rent_591_sample.csv', index_col=0)
df.head(1)
# Out:
#                                          detail_url search_date  \
# 0  https://rent.591.com.tw/rent-detail-1050934.html  2017-05-14
#
#                  title    address floor_info     price layout  building_area  \
# 0  套房出租-近東方學院(六~八月可入住)  高雄市湖內區民生街      3F/3F  4,500元/月    NaN            6.0
#
#   building_use   latitude  longitude
# 0     透天厝/獨立套房  22.878436  120.25081

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70315 entries, 0 to 70314
# Data columns (total 11 columns):
# detail_url       70315 non-null object
# search_date      70315 non-null object
# title            70315 non-null object
# address          70315 non-null object
# floor_info       69686 non-null object
# price            70315 non-null object
# layout           22630 non-null object
# building_area    70315 non-null float64
# building_use     65330 non-null object
# latitude         70315 non-null float64
# longitude        70315 non-null float64
# dtypes: float64(3), object(8)
# memory usage: 6.4+ MB

# %%
def normalizePrice(ele):
    res = int(ele.replace('元/月','').replace(',',''))
    return res

df['price'] = df['price'].map(normalizePrice)
df['price']
# Out:
# 0          4500
# 1          7500
# 2         11000
# 3          5000
# 4          5000
# 5         22000
# 6          6500
# 7          3000
# 8          6800
# 9         17000
# 10        10000
# 11        10000
# 12        16000
# 13         7500
# 14        11000
# 15        25000
# 16        15000
# 17        23000
# 18         3000
# 19         3900
# 20        70000
# 21         5000
# 22         7000
# 23         5500
# 24         6000
# 25         5400
# 26        50000
# 27         3200
# 28        39000
# 29         6500
#           ...
# 70285     12800
# 70286      9500
# 70287      5000
# 70288     14000
# 70289     14000
# 70290     16000
# 70291     24000
# 70292      7500
# 70293     20000
# 70294     15000
# 70295     12000
# 70296     25000
# 70297      9000
# 70298      4000
# 70299      7800
# 70300      5800
# 70301      5000
# 70302    170000
# 70303      4200
# 70304      8500
# 70305      5800
# 70306    135000
# 70307      6499
# 70308      8000
# 70309      6799
# 70310     13500
# 70311      8800
# 70312      5999
# 70313      3300
# 70314     17000
# Name: price, Length: 70315, dtype: int64

# %%
df = df[['detail_url', 'search_date', 'title', 'address', 'floor_info', 'price',
       'layout', 'building_area', 'building_use']]
df.head(5)
# Out:
#                                          detail_url search_date  \
# 0  https://rent.591.com.tw/rent-detail-1050934.html  2017-05-14
# 1  https://rent.591.com.tw/rent-detail-1008046.html  2017-05-14
# 2  https://rent.591.com.tw/rent-detail-1586266.html  2017-05-12
# 3  https://rent.591.com.tw/rent-detail-1699948.html  2017-05-13
# 4  https://rent.591.com.tw/rent-detail-1404725.html  2017-05-12
#
#                  title      address floor_info  price layout  building_area  \
# 0  套房出租-近東方學院(六~八月可入住)    高雄市湖內區民生街      3F/3F   4500    NaN            6.0
# 1      好房子【聰明的你、妳快來租吧】    新北市蘆洲區長安街      4F/5F   7500    NaN           10.0
# 2   陽台大套房(獨立洗衣機)近頂溪捷運站  新北市永和區中山路一段     8F/12F  11000    NaN            8.0
# 3          火車站附近~~優質套房    屏東縣潮州鎮六合路      3F/3F   5000    NaN            8.0
# 4          觀音四維路優質陽台套房    桃園市觀音區四維路      4F/5F   5000    NaN            7.0
#
#   building_use
# 0     透天厝/獨立套房
# 1     透天厝/獨立套房
# 2    電梯大樓/分租套房
# 3     透天厝/獨立套房
# 4     透天厝/分租套房

# %%
print(df['building_use'].dtypes)
print(df['price'].dtypes)
# Out:
# object
# int64

# %%
df['building_use'].head()
# Out:
# 0     透天厝/獨立套房
# 1     透天厝/獨立套房
# 2    電梯大樓/分租套房
# 3     透天厝/獨立套房
# 4     透天厝/分租套房
# Name: building_use, dtype: object

# %%
#df[df['building_use'].isnull()]
df[df['building_use'].isnull()]
# Out:
#                                              detail_url search_date  \
# 43     https://rent.591.com.tw/rent-detail-2392311.html  2017-05-11
# 121    https://rent.591.com.tw/rent-detail-2571360.html  2017-05-15
# 169    https://rent.591.com.tw/rent-detail-2678086.html  2017-05-12
# 270    https://rent.591.com.tw/rent-detail-2859612.html  2017-05-11
# 315    https://rent.591.com.tw/rent-detail-3454479.html  2017-05-13
# 349    https://rent.591.com.tw/rent-detail-3660959.html  2017-05-14
# 408    https://rent.591.com.tw/rent-detail-4175369.html  2017-05-14
# 498    https://rent.591.com.tw/rent-detail-3994919.html  2017-05-13
# 581    https://rent.591.com.tw/rent-detail-4060267.html  2017-05-10
# 588    https://rent.591.com.tw/rent-detail-4200093.html  2017-05-13
# 616    https://rent.591.com.tw/rent-detail-4470024.html  2017-05-14
# 618    https://rent.591.com.tw/rent-detail-4228802.html  2017-05-13
# 641    https://rent.591.com.tw/rent-detail-3983424.html  2017-05-12
# 682    https://rent.591.com.tw/rent-detail-4316369.html  2017-05-14
# 700    https://rent.591.com.tw/rent-detail-4336573.html  2017-05-11
# 743    https://rent.591.com.tw/rent-detail-4271556.html  2017-05-12
# 746    https://rent.591.com.tw/rent-detail-4371137.html  2017-05-14
# 751    https://rent.591.com.tw/rent-detail-4280139.html  2017-05-12
# 786    https://rent.591.com.tw/rent-detail-4389919.html  2017-05-13
# 852    https://rent.591.com.tw/rent-detail-4476269.html  2017-05-14
# 856    https://rent.591.com.tw/rent-detail-4663980.html  2017-05-14
# 873    https://rent.591.com.tw/rent-detail-4267873.html  2017-05-14
# 888    https://rent.591.com.tw/rent-detail-4673110.html  2017-05-13
# 921    https://rent.591.com.tw/rent-detail-4372976.html  2017-05-10
# 926    https://rent.591.com.tw/rent-detail-4374588.html  2017-05-14
# 928    https://rent.591.com.tw/rent-detail-4693689.html  2017-05-11
# 946    https://rent.591.com.tw/rent-detail-4556079.html  2017-05-15
# 947    https://rent.591.com.tw/rent-detail-4527969.html  2017-05-12
# 966    https://rent.591.com.tw/rent-detail-4400991.html  2017-05-08
# 970    https://rent.591.com.tw/rent-detail-4559922.html  2017-05-14
# ...                                                 ...         ...
# 69569  https://rent.591.com.tw/rent-detail-5192656.html  2017-05-12
# 69578  https://rent.591.com.tw/rent-detail-5190195.html  2017-05-13
# 69635  https://rent.591.com.tw/rent-detail-5192858.html  2017-05-12
# 69636  https://rent.591.com.tw/rent-detail-5192453.html  2017-05-12
# 69803  https://rent.591.com.tw/rent-detail-5193082.html  2017-05-12
# 69821  https://rent.591.com.tw/rent-detail-5193117.html  2017-05-12
# 69843  https://rent.591.com.tw/rent-detail-5192970.html  2017-05-12
# 69868  https://rent.591.com.tw/rent-detail-5191536.html  2017-05-13
# 69875  https://rent.591.com.tw/rent-detail-5193061.html  2017-05-13
# 69906  https://rent.591.com.tw/rent-detail-5191115.html  2017-05-13
# 69940  https://rent.591.com.tw/rent-detail-5191247.html  2017-05-12
# 69949  https://rent.591.com.tw/rent-detail-5191310.html  2017-05-13
# 69953  https://rent.591.com.tw/rent-detail-5191784.html  2017-05-13
# 69984  https://rent.591.com.tw/rent-detail-5191868.html  2017-05-13
# 69985  https://rent.591.com.tw/rent-detail-5191513.html  2017-05-13
# 70009  https://rent.591.com.tw/rent-detail-5191646.html  2017-05-13
# 70036  https://rent.591.com.tw/rent-detail-5191827.html  2017-05-13
# 70039  https://rent.591.com.tw/rent-detail-5191829.html  2017-05-13
# 70042  https://rent.591.com.tw/rent-detail-5191838.html  2017-05-12
# 70088  https://rent.591.com.tw/rent-detail-5192445.html  2017-05-13
# 70104  https://rent.591.com.tw/rent-detail-5192416.html  2017-05-12
# 70132  https://rent.591.com.tw/rent-detail-5192241.html  2017-05-12
# 70137  https://rent.591.com.tw/rent-detail-5192566.html  2017-05-13
# 70162  https://rent.591.com.tw/rent-detail-5192332.html  2017-05-12
# 70187  https://rent.591.com.tw/rent-detail-5192936.html  2017-05-12
# 70192  https://rent.591.com.tw/rent-detail-5192415.html  2017-05-12
# 70206  https://rent.591.com.tw/rent-detail-5192884.html  2017-05-12
# 70216  https://rent.591.com.tw/rent-detail-5192489.html  2017-05-13
# 70248  https://rent.591.com.tw/rent-detail-5193119.html  2017-05-12
# 70278   https://rent.591.com.tw/rent-detail-933207.html  2017-05-12
#
#                       title       address floor_info   price     layout  \
# 43     臨近新街廟,中正公園.宏其婦幼醫院後方.   桃園市中壢區延平路一段        NaN    2300        NaN
# 121       出租車位近市政府永春捷運站24小時  台北市信義區忠孝東路五段        NaN    4000        NaN
# 169    安和路2段室內平面大車位24小時警衛駐守   台北市大安區安和路二段        NaN    7500        NaN
# 270    倉儲室內車位，適中小型愛車，免受日曬雨淋   新北市板橋區長江路二段        NaN    3500        NaN
# 315                 機械式車位出租   台北市松山區八德路四段        NaN    3500        NaN
# 349    捷運中山國中10分鐘(房廳浴各1)附家具     台北市中山區龍江路      5F/5F   15000        NaN
# 408    南科善化賺錢店面中山路慶安宮附近,中華路     台南市善化區中華路      1F/4F   20000        NaN
# 498         竹南科學園區獨立陽台洗衣機套房    苗栗縣竹南鎮大埔五街      2F/5F    5000        NaN
# 581         全新豪宅24小時保全坡平面車位     台北市中山區朱崙街        NaN    6000        NaN
# 588                  員山路金店面     新北市中和區員山路      1F/5F   42000        NaN
# 616    苗栗交流道黃金店面出租/37坪/租金可議   苗栗縣公館鄉苗栗交流道      1F/1F   20000        NaN
# 618     正捷運G5站角間店面7米大面寬1+2樓   台中市北屯區文心路四段     1F/26F   60000        NaN
# 641        緊鄰學校住宅堤防公園黃金人潮區~     新北市蘆洲區永康街      1F/7F   35000        NaN
# 682       信義松德面寬深方正1樓店面商辦住辦     台北市信義區松德路     1F/14F   68000        NaN
# 700           縣道158大路邊~全新套房    雲林縣東勢鄉東勢東路      1F/1F    5000        NaN
# 743          【㊣信義路六段上】鄰松山家商   台北市信義區信義路六段      1F/4F   47000        NaN
# 746    租~~漢民商圈~大面寬~超大空間~大店面     高雄市小港區平治街      1F/1F   20000        NaN
# 751       7.5米大面寬獨立店面(1+夾層)     高雄市左營區文天路     1F/16F   45000        NaN
# 786    優質金店面,整棟1-2樓出租,近景碩公司     桃園市新屋區中華路      1F/2F   15000  4房2廳2衛1陽臺
# 852      金門街璞園機械式平面車庫車位含管理費     台北市中正區金門街        NaN    5000        NaN
# 856           中和精華地段雙捷運黃金商場   新北市中和區中山路二段     2F/19F  650000        NaN
# 873      [店面]天母新光三越正後方,方正格局    台北市士林區天母東路      1F/8F   35000        NaN
# 888      南勢角捷運美食街大坪數店面近興南夜市     新北市中和區仁愛街      1F/4F   98000        NaN
# 921                  1樓店面出租   新北市板橋區文化路一段      1F/5F   42000        NaN
# 926          三重五華街華泰銀行地下室車位     新北市三重區五華街        NaN    3000        NaN
# 928     竹科旺財適文武百市面寬1+2樓租金可談      新竹市東區埔頂路     1F/11F   51000        NaN
# 946       COSTCO空橋計畫1F+2F店辦      新竹市東區慈雲路     1F/28F   70000        NaN
# 947          *麗寶科技大樓*一樓黃金店面     台北市內湖區瑞光路      1F/7F  200000        NaN
# 966                  機械車位出租     高雄市三民區建昌路        NaN    2200        NaN
# 970                中國信託總部對面     台北市南港區園區街        NaN    3500        NaN
# ...                     ...           ...        ...     ...        ...
# 69569        文德捷運站旁一二樓大空間店面     台北市內湖區文德路     1F/10F  270000      開放式格局
# 69578    【住商新店北新加盟店】露天平面大車位     新北市新店區寶慶街        NaN    2500        NaN
# 69635       大林店面，鄰大林火車站大林國小     嘉義縣大林鎮中正路      1F/4F   12000        NaN
# 69636       (拒油煙)文華道低總價店面招租     台中市西屯區文華路      1F/4F   16000        NaN
# 69803    大墩商圈大新大業學區1+2樓店面住家   台中市南屯區東興路二段     1F/12F   29000  1房2廳1衛2陽臺
# 69821        市中心地下停車位月租便宜方便  台北市中正區重慶南路一段        NaN    2900        NaN
# 69843        店面分租~適合網拍、美甲美睫  台北市大安區羅斯福路二段      1F/5F   20000        NaN
# 69868          永安市場坡道機械車位出租     新北市永和區中和路        NaN    3500        NaN
# 69875    20坪特大套房附傢電1廚1房1廳1衛   台中市北屯區昌平路二段      2F/5F    8000        NaN
# 69906             公館大坪數餐飲金店  台北市中正區羅斯福路四段      1F/4F   85000        NaN
# 69940  正中華東路3段崇明路口黃金店面,地點超優   台南市東區中華東路三段      整棟/2F  120000        NaN
# 69949                黃金店面出租     新北市淡水區英專路      1F/5F  130000        NaN
# 69953             成功國小三角窗店面     台南市中西區成功路      1F/4F   98000        NaN
# 69984       10.5萬@安平街全棟租到賺到     台北市士林區安平街      整棟/4F  105000        NaN
# 69985          瑞隆東路大坪數辦公室出租    高雄市鳳山區瑞隆東路      2F/2F   60000        NaN
# 70009  【超級商城】室內挑高無柱設計*附有停車場    新竹市北區經國路三段      2F/2F  300000        NaN
# 70036      復興長安稀有獨棟透天人潮展示金店    台北市中山區復興北路      整棟/3F  300000        NaN
# 70039         市場旁$$賺錢$$店面$$     新北市新莊區裕民街      1F/5F   25000        NaN
# 70042  建國北路近行天宮捷運／一樓黃金店面適百業  台北市中山區建國北路二段     1F/14F  150000        NaN
# 70088         紀念館站出口一級三角窗店面    台北市大安區光復南路     1F/12F  380000        NaN
# 70104           成功路一樓約60坪出租     新竹縣湖口鄉成功路      1F/3F   50000        NaN
# 70132   植物園角間店面(臨30米路、惠宇建設)     台中市北區忠太東路     1F/14F   35000      開放式格局
# 70137  ★家美國際金融大樓電梯出入口B3大車位★  台北市信義區忠孝東路五段        NaN    8500        NaN
# 70162               黃金三角大店面   新北市八里區龍米路二段     1F/12F   50000        NaN
# 70187      連鎖最佳合適❤黃金大店面❤單元三   台中市南屯區益豐路四段      1F/2F  220000      開放式格局
# 70192      萬華極真大樓好停車位(光復橋旁)   台北市萬華區西園路二段        NaN    4000        NaN
# 70206            麗水青田稀有車位釋出     台北市大安區麗水街        NaN    4500        NaN
# 70216              五甲國小一樓店面    高雄市鳳山區南正二路      1F/4F   16000  1房0廳0衛0陽臺
# 70248  復興崗捷運站正對面室內停車位(含管理費)  台北市北投區中央北路三段        NaN    3000        NaN
# 70278  平面車位(月租$2500管理費$500)     桃園市桃園區信光路        NaN    3000        NaN
#
#        building_area building_use
# 43              6.00          NaN
# 121             3.00          NaN
# 169            10.00          NaN
# 270             3.00          NaN
# 315             5.00          NaN
# 349            12.00          NaN
# 408            30.00          NaN
# 498             7.00          NaN
# 581            10.00          NaN
# 588            22.46          NaN
# 616            37.00          NaN
# 618            63.00          NaN
# 641            36.00          NaN
# 682            60.00          NaN
# 700            15.00          NaN
# 743            25.00          NaN
# 746            79.86          NaN
# 751            40.00          NaN
# 786            45.00          NaN
# 852             1.00          NaN
# 856           396.50          NaN
# 873            20.00          NaN
# 888            70.00          NaN
# 921            18.00          NaN
# 926             3.00          NaN
# 928            60.00          NaN
# 946            88.00          NaN
# 947           138.00          NaN
# 966             5.00          NaN
# 970            10.00          NaN
# ...              ...          ...
# 69569         132.90          NaN
# 69578           3.00          NaN
# 69635          35.00          NaN
# 69636          12.00          NaN
# 69803          42.00          NaN
# 69821           5.00          NaN
# 69843           3.00          NaN
# 69868           5.00          NaN
# 69875          20.00          NaN
# 69906          50.00          NaN
# 69940         150.00          NaN
# 69949          24.00          NaN
# 69953          60.66          NaN
# 69984          60.00          NaN
# 69985         200.00          NaN
# 70009         200.00          NaN
# 70036         140.00          NaN
# 70039          18.00          NaN
# 70042          63.40          NaN
# 70088          47.00          NaN
# 70104          60.00          NaN
# 70132          63.30          NaN
# 70137          12.00          NaN
# 70162          43.00          NaN
# 70187         112.00          NaN
# 70192           5.00          NaN
# 70206           2.00          NaN
# 70216          18.57          NaN
# 70248           5.50          NaN
# 70278          12.00          NaN
#
# [4985 rows x 9 columns]

# %%
df['btype'] = df['building_use'].map(lambda e: str(e).split('/')[0])
df['btype'] .head()
# Out:
# 0     透天厝
# 1     透天厝
# 2    電梯大樓
# 3     透天厝
# 4     透天厝
# Name: btype, dtype: object

# %%
df['buse']  = df['building_use'].map(lambda e: str(e).split('/')[1] if '/' in str(e) else None)
df['buse'].head()
# Out:
# 0    獨立套房
# 1    獨立套房
# 2    分租套房
# 3    獨立套房
# 4    分租套房
# Name: buse, dtype: object

# %%
del df['building_use']

# %%
df[['city', 'area', 'road']] =  df['address'].str.extract('(.*?[市縣])(.*?[市區鄉鎮])(.*?[路街巷])')
df.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#                                          detail_url search_date  \
# 0  https://rent.591.com.tw/rent-detail-1050934.html  2017-05-14
# 1  https://rent.591.com.tw/rent-detail-1008046.html  2017-05-14
# 2  https://rent.591.com.tw/rent-detail-1586266.html  2017-05-12
# 3  https://rent.591.com.tw/rent-detail-1699948.html  2017-05-13
# 4  https://rent.591.com.tw/rent-detail-1404725.html  2017-05-12
#
#                  title      address floor_info  price layout  building_area  \
# 0  套房出租-近東方學院(六~八月可入住)    高雄市湖內區民生街      3F/3F   4500    NaN            6.0
# 1      好房子【聰明的你、妳快來租吧】    新北市蘆洲區長安街      4F/5F   7500    NaN           10.0
# 2   陽台大套房(獨立洗衣機)近頂溪捷運站  新北市永和區中山路一段     8F/12F  11000    NaN            8.0
# 3          火車站附近~~優質套房    屏東縣潮州鎮六合路      3F/3F   5000    NaN            8.0
# 4          觀音四維路優質陽台套房    桃園市觀音區四維路      4F/5F   5000    NaN            7.0
#
#   btype  buse city area road
# 0   透天厝  獨立套房  高雄市  湖內區  民生街
# 1   透天厝  獨立套房  新北市  蘆洲區  長安街
# 2  電梯大樓  分租套房  新北市  永和區  中山路
# 3   透天厝  獨立套房  屏東縣  潮州鎮  六合路
# 4   透天厝  分租套房  桃園市  觀音區  四維路

# %%
import sqlite3 as lite
with lite.connect('house.sqlite') as db:
    df.to_sql(name='rent_591', index=None, con=db, if_exists='replace')

# %%
import sqlite3 as lite
with lite.connect('house.sqlite') as db:
    df2=pandas.read_sql_query('select * from rent_591',con=db)
df2.head()

# %%
taipei = df[df['city'] == '台北市']
taipei.head()
# Out:
#                                           detail_url search_date  \
# 11  https://rent.591.com.tw/rent-detail-1944741.html  2017-05-14
# 15  https://rent.591.com.tw/rent-detail-2037235.html  2017-05-14
# 20  https://rent.591.com.tw/rent-detail-1954040.html  2017-05-13
# 39  https://rent.591.com.tw/rent-detail-2375928.html  2017-05-10
# 65  https://rent.591.com.tw/rent-detail-2061829.html  2017-05-08
#
#                    title      address floor_info  price     layout  \
# 11      政大靜巷優質(女)套房，可住雙人  台北市文山區指南路二段      5F/5F  10000        NaN
# 15   台北市北投新民路捷運溫泉78坪雙拼美廈    台北市北投區新民路      2F/9F  25000  4房3廳3衛3陽臺
# 20   小巨捷運敦化學區樓中樓可三代同堂兼辦公    台北市松山區北寧路      5F/7F  70000  7房2廳2衛1陽臺
# 39   環境單純，生活機能佳，近市中心交通便利    台北市松山區吉祥路      2F/4F   8000        NaN
# 65  房間分租/獨立衛浴/環境舒適~近天母三越   台北市士林區天母東路      3F/5F  14000        NaN
#
#     building_area btype  buse city area  road
# 11           6.00    公寓  獨立套房  台北市  文山區   指南路
# 15          78.00  電梯大樓  整層住家  台北市  北投區   新民路
# 20          66.35  電梯大樓  整層住家  台北市  松山區   北寧路
# 39           6.00   透天厝  分租套房  台北市  松山區   吉祥路
# 65          26.00    公寓    辦公  台北市  士林區  天母東路

# %% [markdown]
# ## pandas boxplot group by
# - https://stackoverflow.com/questions/18498690/boxplot-with-pandas-groupby

# %%
taipei['area'].head()
# Out:
# 11    文山區
# 15    北投區
# 20    松山區
# 39    松山區
# 65    士林區
# Name: area, dtype: object

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# ## 中文字變小框框
# - http://white5168.blogspot.tw/2017/12/jupyter-notebook-9-matplotlib.html#.Wnb12a6WbIU
# - plt.rcParams['font.sans-serif'] = 'simhei'
# - plt.rcParams['axes.unicode_minus'] = False

# %%
# %pylab inline
taipei.boxplot(column='price',by='area')
plt.rcParams['font.sans-serif'] = 'simhei'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\user\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
# %pylab inline
import numpy as np
taipei['logprice'] = np.log10(taipei['price']) 
taipei.boxplot(column='logprice',by='area')
plt.rcParams['font.sans-serif'] = 'simhei'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\user\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
# %pylab inline
import numpy as np
df['logprice'] = np.log10(df['price']) 
df.boxplot(column='logprice',by='city', figsize=[20,10], rot=30)
# rot=30 字轉30度
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\user\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
import sqlite3 as lite
with lite.connect('house.sqlite') as db:
    df.to_sql('rent_591', con = db , if_exists='replace', index=None)

# %%
import pandas
with lite.connect('house.sqlite') as db:
    #df2 = pandas.read_sql_query("select btype, buse, AVG(price) from rent_591 where btype = '電梯大樓' group by btype, buse having AVG(price) > 10000;", con = db)
    df2 = pandas.read_sql_query("select city, AVG(price) from rent_591 where btype = '電梯大樓' and buse = '獨立套房' group by city order by AVG(price) desc", con = db)

# %%
# %pylab inline
df2.plot(kind = 'bar', )
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 讀取股價資訊
# - pip install pandas_datareader

# %%
! pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.6.0-py2.py3-none-any.whl (103kB)
# Requirement already satisfied: requests>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader)
# Requirement already satisfied: requests-file in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader)
# Collecting requests-ftp (from pandas_datareader)
#   Downloading requests-ftp-0.3.1.tar.gz
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.3.0->pandas_datareader)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from requests-file->pandas_datareader)
# Requirement already satisfied: python-dateutil>=2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19.2->pandas_datareader)
# Requirement already satisfied: pytz>=2011k in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19.2->pandas_datareader)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19.2->pandas_datareader)
# Building wheels for collected packages: requests-ftp
#   Running setup.py bdist_wheel for requests-ftp: started
#   Running setup.py bdist_wheel for requests-ftp: finished with status 'done'
#   Stored in directory: C:\Users\user\AppData\Local\pip\Cache\wheels\76\fb\0d\1026eb562c34a4982dc9d39c9c582a734eefe7f0455f711deb
# Successfully built requests-ftp
# Installing collected packages: requests-ftp, pandas-datareader
# Successfully installed pandas-datareader-0.6.0 requests-ftp-0.3.1

# %%
import pandas_datareader
df = pandas_datareader.DataReader('MSFT', data_source = 'google', start = '2006-01-01')
df.tail()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-5128a44a0fd5> in <module>()
# ----> 1 import pandas_datareader
#       2 df = pandas_datareader.DataReader('MSFT', data_source = 'google', start = '2006-01-01')
#       3 df.tail()
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
# %pylab inline
df['Close'].plot(kind= 'line', figsize=[10, 5], legend=True, grid=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas_datareader
df = pandas_datareader.DataReader(['FB','AAPL', 'AMZN', 'MSFT', 'GOOG'], data_source = 'google', start = '2006-01-01')['Close']
df.tail()
# Out:
#               AAPL    AMZN      FB    GOOG   MSFT
# Date
# 2017-08-14  159.85  983.30  170.75  922.67  73.59
# 2017-08-15  161.60  982.74  171.00  922.22  73.22
# 2017-08-16  160.95  978.18  170.00  926.96  73.65
# 2017-08-17  157.86  960.57  166.91  910.98  72.40
# 2017-08-18  157.50  958.47  167.41  910.67  72.49

# %%
# %pylab inline
df.plot(kind= 'line', figsize=[10, 5], legend=True, grid=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 比特幣分析
# - https://www.coingecko.com/zh-tw/匯率圖/比特幣/usd

# %%
import requests
from bs4 import BeautifulSoup
#res = requests.get('https://www.coingecko.com/zh-tw/%E5%8C%AF%E7%8E%87%E8%B5%B0%E5%8B%A2%E5%9C%96/%E6%AF%94%E7%89%B9%E5%B9%A3/twd')
res=requests.get('https://www.coingecko.com/zh-tw/%E5%8C%AF%E7%8E%87%E5%9C%96/%E6%AF%94%E7%89%B9%E5%B9%A3/usd')
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"cd4a6493ab","applicationID":"83495717","transactionName":"dV5dRBNcDlkEEU5BEV9SVm8CWwNHFRBOQgtZRg==","queueTime":1,"applicationTime":122,"agent":""}</script>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ4EVVBUCBAIV1VbAgYGUQ=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var ...
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <title>比特幣/Bitcoin 匯率走勢 (BTC/USD) | CoinGecko(幣虎)</title>
# <meta content="比特幣 數字貨幣歷史 BTC/USD 匯率圖表" name="description">
# <meta content="比特幣/Bitcoin 匯率走勢 (BTC/USD) | CoinGecko(幣虎)" property="og:title"/>
# <meta content="website" property="og:type">
# <meta content="比特幣 數字貨幣歷史 BTC/USD 匯率圖表" property="og:description"/>
# <meta content="//assets.coingecko.com/coins/images/1/large/bitcoin.png?1510040391" property="og:image"/>
# <meta content="CoinGecko" property="og:site_name"/>
# <link href="https://www.coingecko.com/en/price_charts/bitcoin/usd" hreflang="en" rel="alternate">
# <link href="https://www.coingecko.com/zh/%E4%BB%B7%E6%A0%BC%E5%9B%BE/%E6%AF%94%E7%89%B9%E5%B8%81/usd" hreflang="zh" rel="alternate"/>
# <link href="https://www.coingecko.com/zh-tw/%E5%8C%AF%E7%8E%87%E5%9C%96/%E6%AF%94%E7%89%B9%E5%B9%A3/usd" hreflang="zh-tw" rel="alternate"/>
# <link href="https://www.coingecko.com/de/kurs_chart/bitcoin/usd" hreflang="de" rel="alternate"/>
# <link href="https://www.coingecko.com/fr/graphiques_cours/bitcoin/usd" hreflang="fr" rel="alternate"/>
# <link href="https://www.coingecko.com/es/tabla_de_precios/bitcoin/usd" hreflang="es" rel="alternate"/>
# <link href="https://www.coingecko.com/ja/%E7%9B%B8%E5%A0%B4%E3%83%81%E3%83%A3%E3%83%BC%E3%83%88/%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3/usd" hreflang="ja" rel="alternate"/>
# <link href="https://www.coingecko.com/id/grafik_harga/bitcoin/usd" hreflang="id" rel="alternate"/>
# <link href="https://www.coingecko.com/ru/%D0%B4%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0_%D1%86%D0%B5%D0%BD/%D0%B1%D0%B8%D1%82%D0%BA%D0%BE%D0%B8%D0%BD%D0%B0/usd" hreflang="ru" rel="alternate"/>
# <link href="https://www.coingecko.com/ko/%EC%8B%9C%EC%84%B8%EC%B0%A8%ED%8A%B8/%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8/usd" hreflang="ko" rel="alternate"/>
# <link href="https://www.coingecko.com/ar/%D9%85%D8%AE%D8%B7%D8%B7%D8%A7%D8%AA_%D8%A7%D9%84%D8%B3%D8%B9%D8%B1/%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86/usd" hreflang="ar" rel="alternate"/>
# <link href="https://www.coingecko.com/th/%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F_%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/%E0%B8%9A%E0%B8%B4%E0%B8%95%E0%B8%84%E0%B8%AD%E0%B8%A2%E0%B8%99%E0%B9%8C/usd" hreflang="th" rel="alternate"/>
# <link href="https://www.coingecko.com/vi/b%E1%BA%A3ng_gi%C3%A1/bitcoin/usd" hreflang="vi" rel="alternate"/>
# <link href="https://www.coingecko.com/it/grafici_del_prezzo/bitcoin/usd" hreflang="it" rel="alternate"/>
# <link href="https://www.coingecko.com/pt/gr%C3%A1ficos_de_pre%C3%A7os/bitcoin/usd" hreflang="pt" rel="alternate"/>
# <link href="https://www.coingecko.com/tr/fiyat_tablolar%C4%B1/bitcoin/usd" hreflang="tr" rel="alternate"/>
# <link href="https://www.coingecko.com/assets/application-3e22c1246116151f14b8ba02005abdada4d9d1cd862675df75e03c94fcfae8a2.css" media="all" rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/js-cookie/2.2.0/js.cookie.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/matchmedia-polyfill@0.3.0"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/accounting.js/0.4.1/accounting.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/blazy/1.8.2/blazy.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/numeral.js/2.0.6/numeral.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/money.js/0.2.0/money.min.js"></script>
# <script src="https://code.highcharts.com/stock/6.0.4/highstock.js"></script>
# <script src="https://code.highcharts.com/6.0.4/highcharts-more.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/modules/offline-exporting.js"></script>
# <script src="https://www.gstatic.com/firebasejs/4.8.2/firebase.js"></script>
# <script src="https://www.coingecko.com/assets/application-f95a7cd38265e419d530e2e695c6d94b74dd750e8c9b02f55d8e1d53c8850321.js"></script>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
# <meta content=" " name="application-name">
# <meta content="#FFFFFF" name="msapplication-TileColor">
# <meta content="mstile-144x144.png" name="msapplication-TileImage">
# <meta content="mstile-70x70.png" name="msapplication-square70x70logo">
# <meta content="mstile-150x150.png" name="msapplication-square150x150logo">
# <meta content="mstile-310x150.png" name="msapplication-wide310x150logo"/>
# <meta content="mstile-310x310.png" name="msapplication-square310x310logo"/>
# </meta></meta></meta></meta></meta></link></meta></meta></head>
# <body class="">
# <div id="render_async_60292ca3e51517720251">
# </div>
# <script>
# //<![CDATA[
#
#     if (window.jQuery) {
#       (function($){
#         $.ajax({ url: "/one_off_campaign?locale=zh-tw" }).always(function(response) {
#           $("#render_async_60292ca3e51517720251").replaceWith(response);
#
#         });
#       }(jQuery));
#     } else {
#       (function() {
#         var request = new XMLHttpRequest();
#         var asyncRequest = true;
#         var SUCCESS = 200;
#         var ERROR = 400;
#
#         request.open("GET", "/one_off_campaign?locale=zh-tw", asyncRequest);
#
#         request.onload = function() {
#           if (request.status >= SUCCESS && request.status < ERROR) {
#             var container = document.getElementById("render_async_60292ca3e51517720251");
#             container.outerHTML = request.response;
#
#           }
#         };
#
#         request.send();
#       })();
#     }
#
# //]]>
# </script>
# <div id="wrapper">
# <div class="header dashboard">
# <div class="logo container">
# <div class="row">
# <div class="col-md-4">
# <div class="main-logo">
# <a href="/zh-tw">
# <img alt="CoinGecko Logo" height="40px" src="https://www.coingecko.com/assets/coingecko-logo-920e592635f3fb66a1a30e6bc47e026c10d814ecab489ace1f950bc791ab84e9.png" width="145px"/>
# </a> </div>
# </div>
# <div class="col-md-8 right-panel desktop">
# <div class="top-header-right">
# <ul class="menu-top-header-menu">
# <span class="user-navigation"></span>
# <li class="divider"></li>
# <li class="language">
# <a data-toggle="dropdown" href="#">繁體中文 <span class="fa fa-caret-down"></span></a>
# <ul class="dropdown-menu ">
# <li><a class="" href="/en/price_charts/bitcoin/usd">English</a></li>
# <li><a class="" href="/es/tabla_de_precios/bitcoin/usd">Español</a></li>
# <li><a class="" href="/de/kurs_chart/bitcoin/usd">Deutsch</a></li>
# <li><a class="" href="/pt/gr%C3%A1ficos_de_pre%C3%A7os/bitcoin/usd">Português</a></li>
# <li><a class="" href="/fr/graphiques_cours/bitcoin/usd">Français</a></li>
# <li><a class="" href="/it/grafici_del_prezzo/bitcoin/usd">Italiano</a></li>
# <li><a class="" href="/id/grafik_harga/bitcoin/usd">Bahasa Indonesia</a></li>
# <li><a class="" href="/zh/%E4%BB%B7%E6%A0%BC%E5%9B%BE/%E6%AF%94%E7%89%B9%E5%B8%81/usd">简体中文</a></li>
# <li><a class="" href="/zh-tw/%E5%8C%AF%E7%8E%87%E5%9C%96/%E6%AF%94%E7%89%B9%E5%B9%A3/usd">繁體中文</a></li>
# <li><a class="" href="/ja/%E7%9B%B8%E5%A0%B4%E3%83%81%E3%83%A3%E3%83%BC%E3%83%88/%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3/usd">日本語</a></li>
# <li><a class="" href="/ko/%EC%8B%9C%EC%84%B8%EC%B0%A8%ED%8A%B8/%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8/usd">한국어</a></li>
# <li><a class="" href="/ru/%D0%B4%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0_%D1%86%D0%B5%D0%BD/%D0%B1%D0%B8%D1%82%D0%BA%D0%BE%D0%B8%D0%BD%D0%B0/usd">ру́сский</a></li>
# <li><a class="" href="/ar/%D9%85%D8%AE%D8%B7%D8%B7%D8%A7%D8%AA_%D8%A7%D9%84%D8%B3%D8%B9%D8%B1/%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86/usd">العربية</a></li>
# <li><a class="" href="/th/%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F_%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/%E0%B8%9A%E0%B8%B4%E0%B8%95%E0%B8%84%E0%B8%AD%E0%B8%A2%E0%B8%99%E0%B9%8C/usd">ภาษาไทย</a></li>
# <li><a class="" href="/vi/b%E1%BA%A3ng_gi%C3%A1/bitcoin/usd">Tiếng việt</a></li>
# <li><a class="" href="/tr/fiyat_tablolar%C4%B1/bitcoin/usd">Türkçe</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="language-mobile">
# <a data-target="#language-mobile" data-toggle="collapse" href="#"><i aria-hidden="true" class="fa fa-globe"></i></a>
# </div>
# <div class="main-menu mobile">
# <nav class="coingecko navbar navbar-light navbar-toggleable-md menu">
# <button aria-controls="containerNavbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler navbar-toggler-right" data-target="#containerNavbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse nav-menu" id="containerNavbar">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw">圖表</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/crypto_index/crix">
# CRIX
# </a> </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/ico">
# ICO <span class="label label-orange">Beta</span>
# </a> </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/%E5%95%86%E5%93%81">
# 商品
# </a> </li>
# <li class="nav-item">
# <a class="nav-link" href="/buzz?locale=zh-tw">
# Buzz
# </a> </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/%E9%97%9C%E6%96%BC">關於</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/%E5%B8%B8%E5%95%8F%E5%95%8F%E9%A1%8C">常問問題</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/zh-tw/%E6%96%B9%E6%B3%95">方法</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/coingecko-advertising.pdf">廣告宣傳</a>
# </li>
# <span class="user-navigation"></span>
# </ul>
# </div>
# </nav>
# </div>
# <div class="coingecko collapse navbar-collapse nav-menu" id="language-mobile">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item"><a class="nav-link" href="/en/price_charts/bitcoin/usd">English</a></li>
# <li class="nav-item"><a class="nav-link" href="/es/tabla_de_precios/bitcoin/usd">Español</a></li>
# <li class="nav-item"><a class="nav-link" href="/de/kurs_chart/bitcoin/usd">Deutsch</a></li>
# <li class="nav-item"><a class="nav-link" href="/pt/gr%C3%A1ficos_de_pre%C3%A7os/bitcoin/usd">Português</a></li>
# <li class="nav-item"><a class="nav-link" href="/fr/graphiques_cours/bitcoin/usd">Français</a></li>
# <li class="nav-item"><a class="nav-link" href="/it/grafici_del_prezzo/bitcoin/usd">Italiano</a></li>
# <li class="nav-item"><a class="nav-link" href="/id/grafik_harga/bitcoin/usd">Bahasa Indonesia</a></li>
# <li class="nav-item"><a class="nav-link" href="/zh/%E4%BB%B7%E6%A0%BC%E5%9B%BE/%E6%AF%94%E7%89%B9%E5%B8%81/usd">简体中文</a></li>
# <li class="nav-item"><a class="nav-link" href="/zh-tw/%E5%8C%AF%E7%8E%87%E5%9C%96/%E6%AF%94%E7%89%B9%E5%B9%A3/usd">繁體中文</a></li>
# <li class="nav-item"><a class="nav-link" href="/ja/%E7%9B%B8%E5%A0%B4%E3%83%81%E3%83%A3%E3%83%BC%E3%83%88/%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3/usd">日本語</a></li>
# <li class="nav-item"><a class="nav-link" href="/ko/%EC%8B%9C%EC%84%B8%EC%B0%A8%ED%8A%B8/%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8/usd">한국어</a></li>
# <li class="nav-item"><a class="nav-link" href="/ru/%D0%B4%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0_%D1%86%D0%B5%D0%BD/%D0%B1%D0%B8%D1%82%D0%BA%D0%BE%D0%B8%D0%BD%D0%B0/usd">ру́сский</a></li>
# <li class="nav-item"><a class="nav-link" href="/ar/%D9%85%D8%AE%D8%B7%D8%B7%D8%A7%D8%AA_%D8%A7%D9%84%D8%B3%D8%B9%D8%B1/%D8%A8%D9%8A%D8%AA%D9%83%D9%88%D9%8A%D9%86/usd">العربية</a></li>
# <li class="nav-item"><a class="nav-link" href="/th/%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F_%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/%E0%B8%9A%E0%B8%B4%E0%B8%95%E0%B8%84%E0%B8%AD%E0%B8%A2%E0%B8%99%E0%B9%8C/usd">ภาษาไทย</a></li>
# <li class="nav-item"><a class="nav-link" href="/vi/b%E1%BA%A3ng_gi%C3%A1/bitcoin/usd">Tiếng việt</a></li>
# <li class="nav-item"><a class="nav-link" href="/tr/fiyat_tablolar%C4%B1/bitcoin/usd">Türkçe</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div>
# <div class="" style="background: #4d4d4d; padding: 10px; color: white">
# <div class="container">
# <div class="row">
# <div class="col-md-4">
# </div>
# <div class="col-md-8" style="text-align: right;">
# <span class="badge badge-warning">New!</span>
# Learn about the current market dynamics.
# Download the exclusive <a data-target="#exampleModal" data-toggle="modal" href="#" style="font-weight: 500; color: #8cc53f" target="_blank">2017 Year-in-Review Cryptocurrency Report</a>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="exampleModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="exampleModalLabel">2017 Year-in-Review Cryptocurrency Report</h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <div class="text-center">
# <img alt="2017 ye report screenshot 1" src="https://www.coingecko.com/assets/2017-ye-report-screenshot-1-e0dd9e3a52e81a948d730afdae08e0d01289f9b2c3a25ecbab78550a8c2b95b8.png" style="width: 80%;"/>
# <form class="form-inline" id="lead-form">
# <div class="col-md-12 mt-2 mb-2">
# <label for="exampleInputEmail1">Enter your email address to view this for free</label>
# </div>
# <div class="col-md-12" style="display: flex">
# <input aria-describedby="emailHelp" class="form-control" id="lead-form-email" placeholder="Enter email" required="" style="flex: 3" type="email"/>
# <button class="btn btn-primary" style="flex: 1;" type="submit">Submit</button>
# </div>
# <div class="col-md-12">
# <small class="form-text text-muted" id="emailHelp">By providing your email address, you consent to receive information and updates on CoinGecko.</small>
# </div>
# </form>
# <div class="mt-2 mb-2" id="lead-download-link" style="display: none;">
# <a class="btn btn-primary btn-lg" href="http://bit.ly/2017-year-review-cryptocurrency-report-coingecko">Click here to view the report</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar mobile">
# <div class="container">
# <div class="row justify-content-center">
# <div class="col-md-12">
# <div class="input-group search">
# <select class="select2-search-coins" id="coins_to_search" name="coins_to_search" style="width:100%"><option value="">Search Coin</option><option value="863">0x (ZRX)</option>
# <option value="1045">10M Token (10MT)</option>
# <option value="686">1337 (1337)</option>
# <option value="667">2GIVE (2GIVE)</option>
# <option value="822">300 Token (300)</option>
# <option value="1385">808Coin (808)</option>
# <option value="2647">8Bit (8BIT)</option>
# <option value="2525">AICHAIN (AIT)</option>
# <option value="1003">ALIS (ALIS)</option>
# <option value="1206">ALQO (ALQO)</option>
# <option value="148">APEXcoin (APEX)</option>
# <option value="1239">APX (APX)</option>
# <option value="185">ARCHcoin (ARCH)</option>
# <option value="873">ATBCoin (ATB)</option>
# <option value="806">ATC Coin (ATCC)</option>
# <option value="1108">ATLANT (ATL)</option>
# <option value="1095">ATMChain (ATM)</option>
# <option value="936">ATMCoin (ATMC)</option>
# <option value="2542">ATN (ATN)</option>
# <option value="2558">AWARE (AWR)</option>
# <option value="1161">Abjcoin (ABJ)</option>
# <option value="1256">Accelerator Network (ACC)</option>
# <option value="1147">Achain (ACT)</option>
# <option value="172">Acoin (ACOIN)</option>
# <option value="2577">Acute Angle Cloud (AAC)</option>
# <option value="929">AdCoin (ACC)</option>
# <option value="847">AdEx (ADX)</option>
# <option value="868">AdShares (ADST)</option>
# <option value="1246">Adelphoi (ADL)</option>
# <option value="1337">Advanced Internet Block (AIB)</option>
# <option value="418">Adzcoin (ADZ)</option>
# <option value="321">Aeon (AEON)</option>
# <option value="1192">Aerium (AERM)</option>
# <option value="1124">Aeron (ARN)</option>
# <option value="1091">Aeternity (AE)</option>
# <option value="399">Agoras (AGRS)</option>
# <option value="900">Agrello (DLT)</option>
# <option value="192">AidBit (AID)</option>
# <option value="2144">AidCoin (AID)</option>
# <option value="74">Aiden (ADN)</option>
# <option value="1544">Aigang (AIX)</option>
# <option value="1023">Aion (AION)</option>
# <option value="1019">AirSwap (AST)</option>
# <option value="1000">AirToken (AIR)</option>
# <option value="1015">Akuya Coin (AKY)</option>
# <option value="1112">AltCommunity Coin (ALTCOM)</option>
# <option value="855">Altcoin (ALT)</option>
# <option value="1041">Amber (AMB)</option>
# <option value="315">AmberCoin (AMBER)</option>
# <option value="2651">Ammo Reloaded (AMMO)</option>
# <option value="319">AmsterdamCoin (AMS)</option>
# <option value="1311">Animecoin (ANI)</option>
# <option value="23">Anoncoin (ANC)</option>
# <option value="1876">AppCoins (APPC)</option>
# <option value="34">Applecoin (APC)</option>
# <option value="2657">AquariusCoin (ARCO)</option>
# <option value="681">Aragon (ANT)</option>
# <option value="519">Arcade Token (ARC)</option>
# <option value="633">ArcticCoin (ARC)</option>
# <option value="525">Ardor (ARDR)</option>
# <option value="433">Argentum (ARG)</option>
# <option value="740">Argus (ARGUS)</option>
# <option value="613">Ark (ARK)</option>
# <option value="141">ArtByte (ABY)</option>
# <option value="530">Artex Coin (ATX)</option>
# <option value="636">Asch (XAS)</option>
# <option value="72">Asiacoin (AC)</option>
# <option value="474">Asiadigicoin (ADCN)</option>
# <option value="1188">Astro (ASTRO)</option>
# <option value="1242">Atmos (ATMS)</option>
# <option value="628">AudioCoin (ADC)</option>
# <option value="309">Augur (REP)</option>
# <option value="2565">Aurora DAO (AURA)</option>
# <option value="3">Auroracoin (AUR)</option>
# <option value="2600">AurumCoin (AU)</option>
# <option value="1012">Authorship (ATS)</option>
# <option value="1122">Autonio (NIO)</option>
# <option value="901">Aventus (AVT)</option>
# <option value="696">Avoncoin (ACN)</option>
# <option value="1211">B2B (B2B)</option>
# <option value="1174">B3Coin (KB3)</option>
# <option value="2199">BANKEX (BKX)</option>
# <option value="678">BCAP (BCAP)</option>
# <option value="918">BITFID (FID)</option>
# <option value="1266">BLOCKv (VEE)</option>
# <option value="1056">BOScoin (BOS)</option>
# <option value="921">BROTHER (BRAT)</option>
# <option value="1081">BTCMoon (BTCM)</option>
# <option value="432">BTSR (BTSR)</option>
# <option value="736">Bancor Network Token (BNT)</option>
# <option value="626">Bankcoin (B@)</option>
# <option value="1949">Bankera (BNK)</option>
# <option value="677">Basic Attention Token (BAT)</option>
# <option value="1008">Bastonet (BSN)</option>
# <option value="271">Bata (BTA)</option>
# <option value="254">Bean Cash (BITB)</option>
# <option value="484">Beatcoin (XBTS)</option>
# <option value="580">Belacoin (BELA)</option>
# <option value="627">BenjiRolls (BENJI)</option>
# <option value="928">BiblePay (BBP)</option>
# <option value="1441">Bibox Token (BIX)</option>
# <option value="2222">BigONE Token (BIG)</option>
# <option value="2658">BigUp (BIGUP)</option>
# <option value="485">Bikercoin (BIC)</option>
# <option value="946">Billionaire Token (XBL)</option>
# <option value="825">Binance Coin (BNB)</option>
# <option value="574">BipCoin (BIP)</option>
# <option value="974">Bismuth (BIS)</option>
# <option value="793">Bit20 (BTWTY)</option>
# <option value="2489">BitAsean (BAS)</option>
# <option value="258">BitBay (BAY)</option>
# <option value="1194">BitBoost (BBT)</option>
# <option value="1585">BitClave (CAT)</option>
# <option value="842">BitCoal (COAL)</option>
# <option value="318">BitCrystals (BCY)</option>
# <option value="1653">BitDegree (BDG)</option>
# <option value="956">BitDice (CSNO)</option>
# <option value="612">BitSend (BSD)</option>
# <option value="1193">BitSerial (BTE)</option>
# <option value="95">BitShares (BTS)</option>
# <option value="1020">BitSoar (BSR)</option>
# <option value="231">BitStake (XBS)</option>
# <option value="250">BitSwift (SWIFT)</option>
# <option value="240">BitUSD (BITUSD)</option>
# <option value="283">BitZeny (ZNY)</option>
# <option value="1355">Bitair (BTCA)</option>
# <option value="97">Bitbar (BTB)</option>
# <option value="1101">Bitbase (BTBC)</option>
# <option value="476">Bitcedi (BXC)</option>
# <option value="1198">Bitcloud (BTDX)</option>
# <option value="1">Bitcoin (BTC)</option>
# <option value="2555">Bitcoin Atom [Futures] (BCA)</option>
# <option value="780">Bitcoin Cash (BCH)</option>
# <option value="1254">Bitcoin Diamond [Futures] (BCD)</option>
# <option value="1323">Bitcoin Fast (BCF)</option>
# <option value="1043">Bitcoin Gold (BTG)</option>
# <option value="469">Bitcoin Plus (XBC)</option>
# <option value="1054">Bitcoin Red (BTCRED)</option>
# <option value="296">Bitcoin Scrypt (BTCS)</option>
# <option value="1076">Bitcoin SegWit2X (BT2)</option>
# <option value="1063">Bitcoin Silver (BTCS)</option>
# <option value="2766">Bitcoin White (BTW)</option>
# <option value="1217">Bitcoin2x (BTC2X)</option>
# <option value="1033">BitcoinCashScrypt (BCCS)</option>
# <option value="118">BitcoinDark (BTCD)</option>
# <option value="360">BitcoinUltra (BTCU)</option>
# <option value="1351">BitcoinX [Futures] (BCX)</option>
# <option value="1004">BitcoinZ (BTCZ)</option>
# <option value="545">Bitconnect (BCC)</option>
# <option value="680">Bitcore (BTX)</option>
# <option value="1092">Bitdeal (BDL)</option>
# <option value="1075">Bitfinex Bitcoin Future (BT1)</option>
# <option value="368">Bitgem (BTG)</option>
# <option value="532">Bitland (CADASTRAL)</option>
# <option value="149">Bitleu (BTL)</option>
# <option value="125">Bitmark (BTM)</option>
# <option value="581">Bitparkcoin (BPC)</option>
# <option value="1156">Bitradio (BRO)</option>
# <option value="136">Bitstar (BITS)</option>
# <option value="249">Bitz (BITZ)</option>
# <option value="50">BlackCoin (BLK)</option>
# <option value="876">Blackmoon Crypto (BMC)</option>
# <option value="1392">BlakeStar (BLAS)</option>
# <option value="244">Blakecoin (BLC)</option>
# <option value="653">Blitzcash (BLITZ)</option>
# <option value="2645">Block Array (ARY)</option>
# <option value="1154">BlockCAT (CAT)</option>
# <option value="1301">BlockCDN (BCDN)</option>
# <option value="1022">BlockMason Credit Protocol (BCPT)</option>
# <option value="481">BlockPay (BLOCKPAY)</option>
# <option value="344">BlockShares (BKS)</option>
# <option value="908">Blockchain Index (BLX)</option>
# <option value="236">Blocknet (BLOCK)</option>
# <option value="1143">Blockpool (BPL)</option>
# <option value="2316">Blockport (BPT)</option>
# <option value="1233">Blocktix (TIX)</option>
# <option value="2662">Bloom (BLT)</option>
# <option value="1036">Blue (BLUE)</option>
# <option value="96">Bluecoin (BLU)</option>
# <option value="1218">Bodhi (BOT)</option>
# <option value="1325">Bolivarcoin (BOLI)</option>
# <option value="1314">Bonpay (BON)</option>
# <option value="122">Boolberry (BBR)</option>
# <option value="345">BoostCoin (BOST)</option>
# <option value="180">Bottlecaps (CAP)</option>
# <option value="2048">Bottos (BTO)</option>
# <option value="1444">Bounty0x (BNTY)</option>
# <option value="879">Bowhead Health (AHT)</option>
# <option value="1440">Bread (BRD)</option>
# <option value="624">Breakout (BRK)</option>
# <option value="625">Breakout Stake (BRX)</option>
# <option value="996">BridgeCoin (BCO)</option>
# <option value="651">Britcoin (BRIT)</option>
# <option value="1332">Bulwark (BWK)</option>
# <option value="202">Bunnycoin (BUN)</option>
# <option value="154">Burst (BURST)</option>
# <option value="884">BuzzCoin (BUZZ)</option>
# <option value="561">Byteball Bytes (GBYTE)</option>
# <option value="199">Bytecent (BYC)</option>
# <option value="92">Bytecoin (BCN)</option>
# <option value="1087">Bytom (BTM)</option>
# <option value="952">CHIPS (CHIPS)</option>
# <option value="2500">COMSA (CMS)</option>
# <option value="1011">CORION (COR)</option>
# <option value="955">COSS (COSS)</option>
# <option value="2097">CRYPTO20 (C20)</option>
# <option value="862">CVCoin (CVCOIN)</option>
# <option value="401">Cabbage Unit (CAB)</option>
# <option value="560">Cagecoin (CAGE)</option>
# <option value="526">Caliphcoin (CALC)</option>
# <option value="818">CampusCoin (CMPCO)</option>
# <option value="2027">CanYaCoin (CAN)</option>
# <option value="347">Canada eCoin (CDN)</option>
# <option value="538">Cannabis Industry Coin (XCI)</option>
# <option value="109">CannabisCoin (CANN)</option>
# <option value="155">Cannacoin (CCN)</option>
# <option value="1302">Cappasity (CAPP)</option>
# <option value="327">Capricoin (CPC)</option>
# <option value="1123">CarTaxi (CTX)</option>
# <option value="1291">Carboncoin (CARBON)</option>
# <option value="975">Cardano (ADA)</option>
# <option value="2580">CargoX (CXO)</option>
# <option value="1073">Cash Poker Pro (CASH)</option>
# <option value="2467">Cashcoin (CASH)</option>
# <option value="2491">Casino (CASINO)</option>
# <option value="64">Casinocoin (CSC)</option>
# <option value="844">Catcoin (CAT)</option>
# <option value="1287">Ccore (CCO)</option>
# <option value="941">Centra (CTR)</option>
# <option value="582">Centurion (CNT)</option>
# <option value="267">Cerium (XCE)</option>
# <option value="877">ChainLink (LINK)</option>
# <option value="672">Chaincoin (CHC)</option>
# <option value="1021">Change (CAG)</option>
# <option value="2568">ChatCoin (CHAT)</option>
# <option value="2653">ChessCoin (CHESS)</option>
# <option value="604">Chronobank (TIME)</option>
# <option value="951">Chronologic (DAY)</option>
# <option value="1006">Cindicator (CND)</option>
# <option value="70">Cinni (CINNI)</option>
# <option value="588">Circuits of Value (COVAL)</option>
# <option value="788">Civic (CVC)</option>
# <option value="230">Clams (CLAM)</option>
# <option value="1050">ClearPoll (POLL)</option>
# <option value="81">Cloakcoin (CLOAK)</option>
# <option value="2466">Cloud (CLD)</option>
# <option value="415">Clubcoin (CLUB)</option>
# <option value="789">CoEval (COE)</option>
# <option value="971">Cobinhood (COB)</option>
# <option value="762">Cofound.it (CFI)</option>
# <option value="827">Coimatic 2.0 (CTIC2)</option>
# <option value="639">Coin2.1 (C2)</option>
# <option value="1231">CoinDash (CDT)</option>
# <option value="278">Coinomat (CNMT)</option>
# <option value="966">ColossusCoinXT (COLX)</option>
# <option value="2630">Colossuscoin V2 (CV2)</option>
# <option value="470">Comet (CMT)</option>
# <option value="2545">Commodity Ad Network (CDX)</option>
# <option value="1157">Compcoin (CMP)</option>
# <option value="2661">Compucoin (CPN)</option>
# <option value="1204">Condensate (RAIN)</option>
# <option value="1126">Confido (CFD)</option>
# <option value="1213">Copico (XCPO)</option>
# <option value="1196">Corethum (CRTM)</option>
# <option value="9">Counterparty (XCP)</option>
# <option value="1950">Covesting (COV)</option>
# <option value="251">Crave (CRAVE)</option>
# <option value="1155">Cream (CRM)</option>
# <option value="682">CreativeCoin (CREA)</option>
# <option value="1121">Credence Coin (CRDNC)</option>
# <option value="378">Creditbit (CRB)</option>
# <option value="883">Credo (CREDO)</option>
# <option value="466">Crevacoin (CREVA)</option>
# <option value="1339">CrowdCoin (CRC)</option>
# <option value="328">Crown (CRW)</option>
# <option value="79">CryptCoin (CRYPT)</option>
# <option value="1901">Crypterium (CRPT)</option>
# <option value="273">Crypto (CTO)</option>
# <option value="133">Crypto Bullion (CBX)</option>
# <option value="660">CryptoCarbon (CCRB)</option>
# <option value="135">CryptoEscudo (CESC)</option>
# <option value="857">CryptoForecast (CFT)</option>
# <option value="953">CryptoInsight (TKR)</option>
# <option value="770">CryptoPing (PING)</option>
# <option value="472">Cryptojacks (CJ)</option>
# <option value="291">Cryptokenz (CYT)</option>
# <option value="1176">Cryptonex (CNX)</option>
# <option value="158">Cryptonite (XCN)</option>
# <option value="2216">Cryptopay (CPAY)</option>
# <option value="995">Crystal Clear (CCT)</option>
# <option value="2438">Cthulhu Offerings (OFF)</option>
# <option value="1368">Cubits (QBT)</option>
# <option value="76">Curecoin (CURE)</option>
# <option value="984">CybCSec (XCS)</option>
# <option value="1300">CyberMiles (CMT)</option>
# <option value="904">Cyder (CYDER)</option>
# <option value="867">Cypher (CYP)</option>
# <option value="1271">DAO.Casino (BET)</option>
# <option value="831">DAS (DAS)</option>
# <option value="2604">DATA (DTA)</option>
# <option value="1140">DCORP (DRP)</option>
# <option value="943">DFSCoin (DFS)</option>
# <option value="790">DHG (DHG)</option>
# <option value="1445">DIMCOIN (DIM)</option>
# <option value="87">DNotes (NOTE)</option>
# <option value="880">DROXNE (DRXNE)</option>
# <option value="1442">Dai (DAI)</option>
# <option value="932">Dalecoin (DALC)</option>
# <option value="591">Darcrus (DAR)</option>
# <option value="2435">DarkLisk (DISK)</option>
# <option value="2660">Darsek (KED)</option>
# <option value="19">Dash (DASH)</option>
# <option value="297">Dashcoin (DSH)</option>
# <option value="1353">Datum (DAT)</option>
# <option value="1363">DavorCoin (DAV)</option>
# <option value="803">Daxxcoin (DAXX)</option>
# <option value="275">DeBuNe (DEBUNE)</option>
# <option value="754">Decent (DCT)</option>
# <option value="1168">DecentBet (DBET)</option>
# <option value="878">Decentraland (MANA)</option>
# <option value="2606">Decentralized Universal Basic Income (DUBI)</option>
# <option value="1165">Decision Token (HST)</option>
# <option value="329">Decred (DCR)</option>
# <option value="2057">DeepBrain Chain (DBC)</option>
# <option value="1148">DeepOnion (ONION)</option>
# <option value="1133">Delphy (DPY)</option>
# <option value="760">Denarius (DNR)</option>
# <option value="1152">Dent (DENT)</option>
# <option value="850">Dentacoin (DCN)</option>
# <option value="1119">Desire (DSR)</option>
# <option value="272">Deutsche eMark (DEM)</option>
# <option value="22">Devcoin (DVC)</option>
# <option value="165">Diamond (DMD)</option>
# <option value="322">DigiCube (CUBE)</option>
# <option value="351">DigiEuro (DEUR)</option>
# <option value="1214">DigiPulse (DGPT)</option>
# <option value="63">Digibyte (DGB)</option>
# <option value="132">DigitalNote (XDN)</option>
# <option value="1138">DigitalPrice (DP)</option>
# <option value="33">Digitalcoin (DGC)</option>
# <option value="397">DigixDAO (DGD)</option>
# <option value="860">Dimecoin (DIME)</option>
# <option value="748">Dinastycoin (DCY)</option>
# <option value="153">Dirac (XDQ)</option>
# <option value="1273">Divi (DIVX)</option>
# <option value="2432">Dix Asset (DIX)</option>
# <option value="376">Dobbscoin (BOB)</option>
# <option value="5">Dogecoin (DOGE)</option>
# <option value="120">Dogeparty (XDP)</option>
# <option value="2649">Dollarcoin (DLC)</option>
# <option value="1030">DomRaider (DRT)</option>
# <option value="295">DopeCoin (DOPE)</option>
# <option value="669">Dotcoin (DOT)</option>
# <option value="1072">Dovu (DOVU)</option>
# <option value="1289">Dragonchain (DRGN)</option>
# <option value="629">DubaiCoin-DBIX (DBIX)</option>
# <option value="1028">Dutch Coin (DUTCH)</option>
# <option value="697">Dynamic (DYN)</option>
# <option value="1370">Dynamic Trading Rights (DTR)</option>
# <option value="524">E-Dinar Coin (EDR)</option>
# <option value="1180">E-coin (ECN)</option>
# <option value="1182">EA Coin (EAG)</option>
# <option value="744">ECC (ECC)</option>
# <option value="439">EDRCoin (EDRC)</option>
# <option value="2643">EDUCare (EKT)</option>
# <option value="2229">ENTCash (ENT)</option>
# <option value="738">EOS (EOS)</option>
# <option value="919">EOT Token (EOT)</option>
# <option value="1141">ERC20 (ERC20)</option>
# <option value="1099">ETHGAS (EGAS)</option>
# <option value="1365">ETHLend (LEND)</option>
# <option value="1049">EXRNchain (EXRN)</option>
# <option value="1181">EagleCoin (EAGLE)</option>
# <option value="111">Earthcoin (EAC)</option>
# <option value="2437">EchoLink (EKO)</option>
# <option value="737">Ecobit (ECOB)</option>
# <option value="635">Edgeless (EDG)</option>
# <option value="1018">Eidoo (EDO)</option>
# <option value="46">Einsteinium (EMC2)</option>
# <option value="811">Elastic (XEL)</option>
# <option value="447">Elcoin (EL)</option>
# <option value="688">Electra (ECA)</option>
# <option value="1109">Electroneum (ETN)</option>
# <option value="234">Electronic Gulden (EFL)</option>
# <option value="264">Elektron (EKN)</option>
# <option value="1278">Elementrem (ELE)</option>
# <option value="945">Elixir (ELIX)</option>
# <option value="1083">Ellaism (ELLA)</option>
# <option value="1118">Eltcoin (ELTCOIN)</option>
# <option value="817">EmberCoin (EMB)</option>
# <option value="781">Embers (MBRS)</option>
# <option value="259">EmerCoin (EMC)</option>
# <option value="2655">Emerald Crypto (EMD)</option>
# <option value="1162">Emphy (EPY)</option>
# <option value="1215">EncrypGen (DNA)</option>
# <option value="982">EncryptoTel [ETH] (ETT)</option>
# <option value="1222">Energo (TSL)</option>
# <option value="587">Energycoin (ENRG)</option>
# <option value="1007">Enigma (ENG)</option>
# <option value="1102">Enjin Coin (ENJ)</option>
# <option value="1202">EquiTrader (EQT)</option>
# <option value="2484">Ergo (EFYT)</option>
# <option value="1303">Eroscoin (ERO)</option>
# <option value="1428">Eryllium (ERY)</option>
# <option value="468">Espers (ESP)</option>
# <option value="1684">Esports.com (ERT)</option>
# <option value="856">Eternity (ENT)</option>
# <option value="990">EthBet (EBET)</option>
# <option value="1275">Ethbits (ETBS)</option>
# <option value="2527">EtherDelta Token (EDT)</option>
# <option value="1013">EtherDoge (EDOGE)</option>
# <option value="279">Ethereum (ETH)</option>
# <option value="1010">Ethereum Cash (ECASH)</option>
# <option value="453">Ethereum Classic (ETC)</option>
# <option value="870">Ethereum Dark (ETHD)</option>
# <option value="1034">Ethereum Gold (ETG)</option>
# <option value="1062">Ethereum Lite (ELITE)</option>
# <option value="1274">Ethereum Movie Venture (EMV)</option>
# <option value="1232">Etheroll (DICE)</option>
# <option value="1082">Etherparty (FUEL)</option>
# <option value="794">Ethos (ETHOS)</option>
# <option value="1200">EuropeCoin (ERC)</option>
# <option value="1268">EventChain (EVC)</option>
# <option value="664">EverGreenCoin (EGC)</option>
# <option value="997">Everex (EVX)</option>
# <option value="1027">Everus (EVR)</option>
# <option value="2650">Evil Coin (EVIL)</option>
# <option value="1052">Exchange Union (XUC)</option>
# <option value="1016">ExchangeN (EXN)</option>
# <option value="609">ExclusiveCoin (EXCL)</option>
# <option value="150">Execoin (EXE)</option>
# <option value="339">Expanse (EXP)</option>
# <option value="1080">FAPcoin (FAP)</option>
# <option value="217">FIMKrypto (FIMK)</option>
# <option value="241">FLO (FLO)</option>
# <option value="989">FLiK (FLIK)</option>
# <option value="1114">FORCE (FOR)</option>
# <option value="1186">Faceblock (FBL)</option>
# <option value="896">Facecoin (FC)</option>
# <option value="310">Factom (FCT)</option>
# <option value="255">Faircoin (FAIR)</option>
# <option value="804">Falcoin (FAL)</option>
# <option value="191">Fantomcoin (FCN)</option>
# <option value="1130">Farad (FRD)</option>
# <option value="175">Fastcoin (FST)</option>
# <option value="12">Feathercoin (FTC)</option>
# <option value="35">Fedoracoin (TIPS)</option>
# <option value="166">Fibre (FIBRE)</option>
# <option value="2232">FidentiaX (FDX)</option>
# <option value="1348">Filecoin [Futures] (FIL)</option>
# <option value="800">FinCoin (FNC)</option>
# <option value="615">First Bitcoin (BIT)</option>
# <option value="522">First Blood (1ST)</option>
# <option value="1310">Firstcoin (FRST)</option>
# <option value="601">Fitcoin (FIT)</option>
# <option value="1312">Flappycoin (FLAP)</option>
# <option value="765">Flash (FLASH)</option>
# <option value="1261">Flixxo (FLIXX)</option>
# <option value="348">Flycoin (FLY)</option>
# <option value="1098">FlypMe (FYP)</option>
# <option value="586">Foldingcoin (FLDC)</option>
# <option value="1277">Footy Cash (XFT)</option>
# <option value="47">Franko (FRK)</option>
# <option value="939">Frazcoin (FRAZ)</option>
# <option value="30">Freicoin (FRC)</option>
# <option value="108">Freshcoin (FRSH)</option>
# <option value="187">FuelCoin (FC2)</option>
# <option value="1135">Fujicoin (FJC)</option>
# <option value="909">Fujinto (NTO)</option>
# <option value="290">Full Integrity Coin (FIC)</option>
# <option value="761">FunFair (FUN)</option>
# <option value="1250">FundYourselfNow (FYN)</option>
# <option value="802">FuturXe (FXE)</option>
# <option value="182">GAIA (GAIA)</option>
# <option value="384">GCoin (GCN)</option>
# <option value="1191">GOLD Reward Token (GRX)</option>
# <option value="245">GSMcoin (GSM)</option>
# <option value="1089">GXShares (GXS)</option>
# <option value="584">Gambit (GAM)</option>
# <option value="2046">Game (GTC)</option>
# <option value="445">GameBet (GBT)</option>
# <option value="193">GameCredits (GAME)</option>
# <option value="858">Gas (GAS)</option>
# <option value="2566">Gatcoin (GAT)</option>
# <option value="771">GeertCoin (GEERT)</option>
# <option value="206">Gems (GEMZ)</option>
# <option value="1361">Genaro Network (GNX)</option>
# <option value="1173">Genesis Vision (GVT)</option>
# <option value="658">Geocoin (GEO)</option>
# <option value="816">GeyserCoin (GSR)</option>
# <option value="1359">Gifto (GTO)</option>
# <option value="907">Giga Watt Token (WTT)</option>
# <option value="1100">Gimli (GIM)</option>
# <option value="324">Global Currency Reserve (GCR)</option>
# <option value="2021">Global Jobcoin (GJC)</option>
# <option value="799">Global Tour Coin (GTC)</option>
# <option value="73">GlobalBoost-Y (BSTY)</option>
# <option value="1150">GlobalToken (GLT)</option>
# <option value="188">GlowShares (GSX)</option>
# <option value="662">Gnosis (GNO)</option>
# <option value="1207">GoByte (GBX)</option>
# <option value="451">GoldBlocks (GB)</option>
# <option value="1146">GoldPieces (GP)</option>
# <option value="2652">GoldReserve (XGR)</option>
# <option value="49">Goldcoin (GLD)</option>
# <option value="478">Goldmaxcoin (GMX)</option>
# <option value="542">Golem (GNT)</option>
# <option value="562">Golos (GOLOS)</option>
# <option value="1297">Goodomy (GOOD)</option>
# <option value="352">GraniteCoin (GRN)</option>
# <option value="544">Grantcoin (GRT)</option>
# <option value="1251">Greencoin (GRE )</option>
# <option value="1106">Grid+ (GRID)</option>
# <option value="243">Gridcoin (GRC)</option>
# <option value="1144">Grimcoin (GRIM)</option>
# <option value="71">Groestlcoin (GRS)</option>
# <option value="128">Groupcoin (GPC)</option>
# <option value="196">Guarany (GUA)</option>
# <option value="143">Gulden (NLG)</option>
# <option value="807">GulfCoin (MGC)</option>
# <option value="2624">Guncoin (GUN)</option>
# <option value="565">HEAT (HEAT)</option>
# <option value="969">HODL Bucks (HDLB)</option>
# <option value="434">HOdlcoin (HODL)</option>
# <option value="1085">HShare (HSR)</option>
# <option value="162">HTML5COIN (HTML5)</option>
# <option value="2451">HTMLCOIN (HTML)</option>
# <option value="1618">Hacken (HKN)</option>
# <option value="570">Hacker Gold (HKG)</option>
# <option value="2336">Hackspace Capital (HAC)</option>
# <option value="2737">HalalChain (HLC)</option>
# <option value="2623">Halcyon (HAL)</option>
# <option value="1294">Happycoin (HPC)</option>
# <option value="829">HarmonyCoin (HMC)</option>
# <option value="1171">Hawala.Today (HAT)</option>
# <option value="45">Heavycoin (HVC)</option>
# <option value="1039">Hedge (HDG)</option>
# <option value="266">HellasCoin (HLC)</option>
# <option value="1322">Helleniccoin (HNC)</option>
# <option value="1005">HelloGold (HGT)</option>
# <option value="865">Hempcoin (THC)</option>
# <option value="282">Hexx (HXX)</option>
# <option value="572">HiCoin (XHI)</option>
# <option value="1110">High Gain (HIGH)</option>
# <option value="2363">High Performance Blockchain (HPB)</option>
# <option value="462">Hitcoin (HTC)</option>
# <option value="899">Hive (HVN)</option>
# <option value="59">Hobonickels (HBN)</option>
# <option value="1347">HollyWoodCoin (HWC)</option>
# <option value="2217">HomeBlockCoin (HBC)</option>
# <option value="772">Honey (HONEY)</option>
# <option value="139">Horizon (HZ)</option>
# <option value="994">Hubii Network (HBT)</option>
# <option value="647">Humaniq (HMQ)</option>
# <option value="126">Huntercoin (HUC)</option>
# <option value="701">Hush (HUSH)</option>
# <option value="2570">Hydro Protocol (HOT)</option>
# <option value="142">Hyper (HYPER)</option>
# <option value="131">HyperStake (HYP)</option>
# <option value="106">I/O Coin (IOC)</option>
# <option value="2625">I0Coin (I0C)</option>
# <option value="533">ICO OpenLedger (ICOO)</option>
# <option value="1060">ICON (ICX)</option>
# <option value="1042">ICOS (ICOS)</option>
# <option value="2564">IDEX Membership (IDXM)</option>
# <option value="1857">INS Ecosystem (INS)</option>
# <option value="465">ION (ION)</option>
# <option value="2523">IOStoken (IOST)</option>
# <option value="692">IOTA (IOT)</option>
# <option value="2572">IPChain (IPC)</option>
# <option value="529">Iconomi (ICN)</option>
# <option value="1345">Ignis (IGNIS)</option>
# <option value="854">IncaKoin (NKA)</option>
# <option value="567">Incent (INCNT)</option>
# <option value="963">India Coin (INDIA)</option>
# <option value="848">Indorse (IND)</option>
# <option value="14">Infinitecoin (IFC)</option>
# <option value="977">Infinity Economics (XIN)</option>
# <option value="1210">Infinity Pay (IPY)</option>
# <option value="1377">InflationCoin (IFLT)</option>
# <option value="311">Influxcoin (INFX)</option>
# <option value="1216">Ink (INK)</option>
# <option value="1131">Innova (INN)</option>
# <option value="655">InsaneCoin (INSN)</option>
# <option value="1858">InsurePal (IPL)</option>
# <option value="814">InsureX (IXT)</option>
# <option value="1064">Intelligent Trading Tech (ITT)</option>
# <option value="1184">IntenseCoin (ITNS)</option>
# <option value="2519">Internet Node Token (INT)</option>
# <option value="743">Internet of People (IOP)</option>
# <option value="986">Internxt (INXT)</option>
# <option value="1163">Interstellar Holdings (HOLD)</option>
# <option value="960">Interzone (ITZ)</option>
# <option value="2524">InvestDigital (IDT)</option>
# <option value="1153">InvestFeed (IFT)</option>
# <option value="1304">IoT Chain (ITC)</option>
# <option value="29">Ixcoin (IXC)</option>
# <option value="596">Janus (JNS)</option>
# <option value="1061">JavaScript Token (JS)</option>
# <option value="2487">Jetcoin (JET)</option>
# <option value="2552">Jingtum Tech (SWTC)</option>
# <option value="583">Jinn (JINN)</option>
# <option value="534">Jobscoin (JOBS)</option>
# <option value="650">Joincoin (J)</option>
# <option value="787">Joulecoin (XJO)</option>
# <option value="161">Judgecoin (JUDGE)</option>
# <option value="2430">Karbo (KRB)</option>
# <option value="88">Karma (KRM)</option>
# <option value="579">Kashhcoin (KASHH)</option>
# <option value="1404">Kayicoin (KAYI)</option>
# <option value="2549">Kcash (KCASH)</option>
# <option value="1280">KekCoin (KEK)</option>
# <option value="2556">KemCredit (KMC)</option>
# <option value="942">KexCoin (KEXCOIN)</option>
# <option value="981">KickCoin (KICK)</option>
# <option value="959">Kin (KIN)</option>
# <option value="965">Kolion (KLN)</option>
# <option value="611">Komodo (KMD)</option>
# <option value="668">KoreCoin (KORE)</option>
# <option value="905">Kronecoin (KRONE)</option>
# <option value="400">Krypton (KR)</option>
# <option value="1047">KuCoin Shares (KCS)</option>
# <option value="1335">Kubera Coin (KBR)</option>
# <option value="676">Kurrent (KURT)</option>
# <option value="671">Kushcoin (KUSH)</option>
# ...
# </label>
# <label class="btn btn-primary coingecko" id="chart-mode-line">
# <input autocomplete="off" id="option1" name="mode-chart-options" type="radio"/> <i class="fa fa-line-chart"></i>
# </label>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <div class="ajax" style="height: 490px;">
# <img alt="Loader 20" class="img-auto graph-stats-loading" height="20px" src="https://www.coingecko.com/assets/loader-20-86d9029d50c95271ee19e93eaab40ca30749a7b56020e5669814873ed9f44e54.gif" style="display:none;" width="20px"/>
# <div class="coin_portfolio_price_chart" data-prices="[[1517633972864.3,8367.78],[1517634240430.67,8383.41],[1517634576127.5498,8302.86],[1517634863506.54,8290.21],[1517635172614.46,8279.71],[1517635462782.36,8329.15],[1517635776209.5598,8360.15],[1517636061287.28,8364.41],[1517636373103.1,8297.32],[1517636663673.39,8317.68],[1517636977782.48,8320.58],[1517637266404.9302,8340.62],[1517637573032.6199,8412.07],[1517637859122.04,8421.52],[1517638176858.6099,8430.52],[1517638462226.47,8417.65],[1517638774116.69,8378.7],[1517639043762.87,8397.4],[1517639374916.6501,8446.58],[1517639670163.41,8478.2],[1517639973179.01,8463.72],[1517640255311.3699,8520.11],[1517640577674.01,8526.84],[1517640832009.1702,8579.92],[1517641173746.44,8635.82],[1517641463612.27,8629.02],[1517641772545.31,8646.22],[1517642071218.9,8606.44],[1517642376152.2998,8590.99],[1517642663532.34,8572.64],[1517642978601.0898,8598.49],[1517643276657.5798,8575.15],[1517643576754.06,8542.6],[1517643874353.93,8590.52],[1517644180019.45,8626.39],[1517644469640.04,8621.51],[1517644777789.46,8603.74],[1517645073680.82,8606.6],[1517645378441.19,8550.97],[1517645661799.99,8547.0],[1517645976473.72,8549.21],[1517646275438.75,8570.61],[1517646580289.72,8575.35],[1517646869427.68,8629.11],[1517647171300.15,8777.39],[1517647456570.52,8765.06],[1517647772246.14,8768.0],[1517648075706.1702,8758.47],[1517648369703.42,8830.07],[1517648668527.3699,8830.97],[1517648977475.81,8926.1],[1517649271803.9602,8883.0],[1517649577423.85,8833.51],[1517649874220.34,8849.97],[1517650178475.97,8797.14],[1517650477284.97,8801.77],[1517650776410.97,8833.36],[1517651068401.9202,8859.91],[1517651380605.56,8836.56],[1517651674747.3198,8839.84],[1517651975975.41,8842.47],[1517652269505.73,8795.61],[1517652578934.14,8793.67],[1517652872537.27,8762.04],[1517653175183.77,8741.36],[1517653470697.28,8688.46],[1517653777719.33,8710.45],[1517654074829.45,8718.71],[1517654376819.9102,8694.17],[1517654675440.5798,8716.66],[1517654977818.5999,8747.4],[1517655269894.24,8741.4],[1517655575500.07,8709.5],[1517655862537.27,8667.19],[1517656178205.5,8664.56],[1517656476198.75,8715.26],[1517656775936.8801,8739.42],[1517657069518.41,8794.33],[1517657380057.8499,8833.95],[1517657671406.3398,8839.2],[1517657968883.47,8880.17],[1517658257575.69,8883.43],[1517658579605.6099,8838.75],[1517658870803.25,8854.89],[1517659174653.18,8900.62],[1517659472462.8,8951.49],[1517659777348.3,8933.44],[1517660057602.78,8900.29],[1517660376416.34,8904.59],[1517660671098.8,8889.31],[1517660977526.99,8872.57],[1517661268134.53,8859.05],[1517661574447.63,8876.58],[1517661862422.16,8873.22],[1517662176808.7102,8898.02],[1517662475128.48,8963.77],[1517662776233.3801,8939.83],[1517663074071.5698,8924.41],[1517663378007.14,8891.32],[1517663670904.45,8885.74],[1517663976361.51,8875.04],[1517664271703.32,8936.39],[1517664580043.8098,8951.78],[1517664869922.3198,8971.81],[1517665176181.9102,9032.11],[1517665470248.01,9093.37],[1517665781626.71,9125.97],[1517666068226.8801,9099.0],[1517666374866.6,9110.06],[1517666672863.11,9105.66],[1517666978524.28,9086.98],[1517667272624.8901,9167.94],[1517667576726.03,9200.77],[1517667872153.91,9244.01],[1517668179282.3901,9183.21],[1517668459527.38,9183.77],[1517668776869.8699,9221.39],[1517669071627.11,9227.52],[1517669374491.58,9235.29],[1517669676184.4102,9249.51],[1517669976857.5898,9240.02],[1517670274972.3599,9273.78],[1517670581669.3499,9355.0],[1517670876498.41,9351.85],[1517671170662.75,9383.44],[1517671470446.0398,9315.57],[1517671777388.8901,9272.84],[1517672058252.82,9259.26],[1517672379143.6602,9266.02],[1517672676230.7,9245.29],[1517672980114.0898,9242.73],[1517673275312.83,9203.51],[1517673572379.6501,9133.97],[1517673874712.21,9159.53],[1517674180163.5498,9104.56],[1517674471860.58,9055.29],[1517674781402.98,9026.66],[1517675079389.12,9043.55],[1517675380371.46,9097.26],[1517675661032.31,9117.15],[1517675976990.78,9169.05],[1517676279287.66,9181.45],[1517676580662.75,9160.08],[1517676863477.59,9176. ...
# <div class="btn-toolbar mt-3 pull-left" role="toolbar">
# <div id="bsa-zone_1513111948755-1_123456"></div>
# </div>
# <div class="btn-toolbar pull-right mt-3" role="toolbar">
# <div class="dropdown mr-1">
# <button aria-expanded="false" aria-haspopup="true" class="btn btn-sm dropdown-toggle btn-outline-dark" data-toggle="dropdown" type="button">
# Export As <span class="caret"></span>
# </button>
# <ul class="dropdown-menu">
# <li><a class="dropdown-item" href="/price_charts/export/%E6%AF%94%E7%89%B9%E5%B9%A3/usd.xls">Excel</a></li></ul></div></div></div></div></div></div></div></div></div></div></div></div></body></html>
# <li><a class="dropdown-item" href="/price_charts/export/%E6%AF%94%E7%89%B9%E5%B9%A3/usd.csv">CSV</a></li>
#
#
# <div class="btn-group">
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-24h active" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/24_hours?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/24_hours.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/24_hours.json" href="javascript:;">24h</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-7d" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/7_days?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/7_days.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/7_days.json" href="javascript:;">7d</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-14d" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/14_days?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/14_days.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/14_days.json" href="javascript:;">14d</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-30d" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/30_days?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/30_days.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/30_days.json" href="javascript:;">30d</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-60d" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/60_days?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/60_days.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/60_days.json" href="javascript:;">60d</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-90d" data-full-graph-url="https://www.coingecko.com/price_charts/%E6%AF%94%E7%89%B9%E5%B9%A3/usd/90_days?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/price_charts/1/usd/90_days.json" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/90_days.json" href="javascript:;">90d</a>
# <a class="btn btn-primary btn btn-sm graph-stats-btn graph-stats-btn-max" data-full-graph-url="https://www.coingecko.com/chart/%E6%AF%94%E7%89%B9%E5%B9%A3/usd?locale=zh-tw" data-graph-stats-url="https://www.coingecko.com/chart/1/usd.json?locale=zh-tw" data-market-cap-graph-stats-url="https://www.coingecko.com/market_cap/1/usd/max_days.json" href="javascript:;">Max</a>
# </div>
#
#
#
#
# <div class="row">
# <div class="col-md-8 ads text-right">
# <div class="text-center" style="height: 250px;">
# <div id="bsa-zone_1509402283990-1_123456"></div>
# </div>
# </div>
# <div class="col-md-4 pl-5">
# <table class="table">
# <thead>
# <tr>
# <th>日期</th>
# <th>
# 匯率 (USD)
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# 不到 1 分钟前
# </td>
# <td>8991.63</td>
# </tr>
# <tr>
# <td>
# 3 分钟前
# </td>
# <td>8993.76</td>
# </tr>
# <tr>
# <td>
# 8 分钟前
# </td>
# <td>8984.01</td>
# </tr>
# <tr>
# <td>
# 13 分钟前
# </td>
# <td>9018.64</td>
# </tr>
# <tr>
# <td>
# 18 分钟前
# </td>
# <td>9000.01</td>
# </tr>
# <tr>
# <td>
# 23 分钟前
# </td>
# <td>8985.73</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
#
# <div class="card-footer bg-transparent">
# <table class="table table-responsive mt-2">
# <thead>
# <tr>
# <th>貨幣</th>
# <th>代碼</th>
# <th style="text-align:right;">匯率</th>
# <th style="text-align:right;">总市值</th>
# <th style="text-align:right;">成交量</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="border-bottom: none;">比特幣</td>
# <td style="border-bottom: none;">BTC</td>
# <td style="text-align:right;border-bottom: none;">
# <span>$ 8,991.6260</span>
# </td>
# <td style="text-align:right;border-bottom: none;">
# <span>$ 151,456,404,308</span>
# </td>
# <td style="text-align:right;border-bottom: none;">
# <span>$ 3,038,144,906</span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
#
#
#
#
#
# <footer>
# <div class="topfooter">
# <div class="container">
# <div class="row">
# <div class="col-md-2"></div>
# <div class="col-md-8">
# <div class="disclaimer-icon">
# <img alt="disclaimer" src="https://www.coingecko.com/assets/disclaimer-8e54d418cc52b2c9035b439722d8d89ff19fdd06629c738bd348e805f574f337.png"/>
# </div>
# <div class="disclaimer-content">
# <span class="disclaimer"><a href="/zh-tw/%E5%85%8D%E8%B2%AC%E8%81%B2%E6%98%8E">請閱讀免責聲明</a></span>: 貨幣交易是一項高風險的活動。在作出任何決定之前，請咨詢您的財務顧問。 CoinGecko(幣虎)將不承擔任何交易決定。
# </div>
# </div>
# <div class="col-md-2"></div>
# </div>
# </div>
# </div>
# <div class="container" id="footer">
# <div class="footer-header">
# 你喜歡的貨幣不在列裏？
# </div>
# <div class="footer-content">
# 我們將在每個星期增加壹些新的貨幣到排名上。如果您想看到您的貨幣在這個排名上，請於<a href="https://support.coingecko.com">https://support.coingecko.com</a>給我們壹些意見和反饋，
# </div>
# <div class="footer-header-2">喜歡我們的項目嗎？歡迎您慷慨解囊！</div>
# <div class="donations row">
# <div class="col-md-6 coin-wrapper">
# <div class="footer-coin-img"><img alt="Bitcoin" src="https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png"/></div>
# <div class="footer-donate-link"><div class="donate-coin">Bitcoin BTC</div><a href="https://blockchain.info/address/1ECGUKEosEhaZnywCVxw6e1VUcPRqGkhvd" rel="nofollow" target="_blank">1ECGUKEosEhaZnywCVxw6e1VUcPRqGkhvd</a></div>
# </div>
# <div class="col-md-6 coin-wrapper">
# <div class="footer-coin-img"><img alt="Litecoin" src="https://assets.coingecko.com/coins/images/2/thumb/litecoin.png"/></div>
# <div class="footer-donate-link"><div class="donate-coin">Litecoin LTC</div><a href="https://live.blockcypher.com/ltc/address/LZCRywjSPCXC2d8ybWgdTjyQrq7GRg3JqB" rel="nofollow" target="_blank">LZCRywjSPCXC2d8ybWgdTjyQrq7GRg3JqB</a></div>
# </div>
# <div class="col-md-6 coin-wrapper">
# <div class="footer-coin-img"><img alt="Dogecoin" src="https://assets.coingecko.com/coins/images/5/thumb/dogecoin.png"/></div>
# <div class="footer-donate-link"><div class="donate-coin">Dogecoin DOGE</div><a href="https://dogechain.info/address/DS3kJgp3mAdezrV5bmKKoXkUiR5tqbrAgg" rel="nofollow" target="_blank">DS3kJgp3mAdezrV5bmKKoXkUiR5tqbrAgg</a></div>
# </div>
# <div class="col-md-6 coin-wrapper">
# <div class="footer-coin-img"><img alt="Ethereum" src="https://assets.coingecko.com/coins/images/279/thumb/ethereum.png"/></div>
# <div class="footer-donate-link"><div class="donate-coin">Ethereum ETH</div><a href="https://etherscan.io/address/0x4Cdc86fa95Ec2704f0849825f1F8b077deeD8d39" rel="nofollow" target="_blank">0x4Cdc86fa95Ec2704f0849825f1F8b077deeD8d39</a></div>
# </div>
# </div>
# </div>
# <div class="bottomfooter desktop">
# <div class="container">
# <div class="row justify-content-center pt-2">
# <div class="btn-group pull-left" role="group">
# <button class="activate-light btn btn-sm btn-secondary" id="" type="button"><i class="fa fa-sun-o"></i></button>
# <button class="activate-dark btn btn-sm btn-secondary" id="" type="button"><i class="fa fa-moon-o"></i></button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-4">
# <div class="menu-footer-container">
# <ul class="menu-footer-menu">
# <li><a href="/zh-tw/%E5%85%8D%E8%B2%AC%E8%81%B2%E6%98%8E">免責聲明</a></li>
# <li><a href="/zh-tw/%E6%A2%9D%E6%AC%BE">服務條款</a></li>
# <li><a href="/zh-tw/%E9%9A%B1%E7%A7%81%E6%AC%8A">隱私政策</a></li>
# </ul>
# </div>
# </div>
# <div class="col-md-4"><div class="copyright">© 2017 CoinGecko. All Rights Reserved.</div></div>
# <div class="col-md-4">
# <div class="menu-footer-container social-media">
# Follow Us On:
# <ul class="menu-footer-menu">
# <li><a href="https://www.facebook.com/coingecko"><i aria-hidden="true" class="fa fa-facebook"></i></a></li>
# <li><a href="http://twitter.com/coingecko"><i aria-hidden="true" class="fa fa-twitter"></i></a></li>
# <li><a href="https://www.instagram.com/coingecko/"><i aria-hidden="true" class="fa fa-instagram"></i></a></li>
# <li><a href="https://bitcointalk.org/index.php?topic=561516.0"><i aria-hidden="true" class="fa fa-btc"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bottomfooter mobile">
# <div class="container">
# <div class="row justify-content-center pt-2">
# <div class="btn-group pull-left" role="group">
# <button class="activate-light btn btn-sm btn-secondary" type="button"><i class="fa fa-sun-o"></i></button>
# <button class="activate-dark btn btn-sm btn-secondary" type="button"><i class="fa fa-moon-o"></i></button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-4">
# <div class="menu-footer-container">
# <ul class="menu-footer-menu">
# <li><a href="/zh-tw/%E5%85%8D%E8%B2%AC%E8%81%B2%E6%98%8E">免責聲明</a></li>
# <li><a href="/zh-tw/%E6%A2%9D%E6%AC%BE">服務條款</a></li>
# <li><a href="/zh-tw/%E9%9A%B1%E7%A7%81%E6%AC%8A">隱私政策</a></li>
# </ul>
# </div>
# </div>
# <div class="col-md-4">
# <div class="row justify-content-center social-media">
# Follow Us On:
# <ul class="menu-footer-menu">
# <li><a href="https://www.facebook.com/coingecko"><i aria-hidden="true" class="fa fa-facebook"></i></a></li>
# <li><a href="http://twitter.com/coingecko"><i aria-hidden="true" class="fa fa-twitter"></i></a></li>
# <li><a href="https://www.instagram.com/coingecko/"><i aria-hidden="true" class="fa fa-instagram"></i></a></li>
# <li><a href="https://bitcointalk.org/index.php?topic=561516.0"><i aria-hidden="true" class="fa fa-btc"></i></a></li>
# </ul>
# </div>
# </div>
# <div class="col-md-4"><div class="copyright">© 2017 CoinGecko. All Rights Reserved.</div></div>
# </div>
# </div>
# </div>
# </footer>
#
# <script async="" src="https://www.google.com/recaptcha/api.js"></script>
# <script>
#   // $('meta[name=csrf-param]').remove()
#   // $('meta[name=csrf-token]').remove()
#   // $.getJSON('/csrf_meta.json').then(function(json){
#   //   $('<meta>').attr('name', "csrf-param").attr('content', json.param).appendTo('head');
#   //   $('<meta>').attr('name', 'csrf-token').attr('content', json.token).appendTo('head');
#   // });
#   $.getScript('/zh-tw/accounts/current.js')
# </script>
# <script data-cfasync="false" src="//cdn-s2s.buysellads.net/pub/coingecko.js"></script>
# <script src="//m.servedby-buysellads.com/monetization.js" type="text/javascript"></script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-49392197-1', 'coingecko.com');
#     ga('send', 'pageview');
#
#     </script>
# <script>
#     (function(){
#       if(typeof _bsa !== 'undefined' && _bsa) {
#         _bsa.init('fancybar', 'CKYDV2QM', 'placement:coingecko');
#       }
#     })();
#     </script>
# <script>
#         bsa_targeting.push([
#                 "coins",
#                 [
#                 "bitcoin"
#                 ]
#          ]);
#       </script>

# %%
import re
his_price = soup.select('.coin_portfolio_price_chart')[0].prettify()
# *?非貪婪比對
m = re.search('data-prices="(.*?)"', his_price) 
#print(his_price)
#print(m)
#print(m.group(1)) #list of list
print(eval(m.group(1)))
# Out:
# [[1517633972864.3, 8367.78], [1517634240430.67, 8383.41], [1517634576127.5498, 8302.86], [1517634863506.54, 8290.21], [1517635172614.46, 8279.71], [1517635462782.36, 8329.15], [1517635776209.5598, 8360.15], [1517636061287.28, 8364.41], [1517636373103.1, 8297.32], [1517636663673.39, 8317.68], [1517636977782.48, 8320.58], [1517637266404.9302, 8340.62], [1517637573032.6199, 8412.07], [1517637859122.04, 8421.52], [1517638176858.6099, 8430.52], [1517638462226.47, 8417.65], [1517638774116.69, 8378.7], [1517639043762.87, 8397.4], [1517639374916.6501, 8446.58], [1517639670163.41, 8478.2], [1517639973179.01, 8463.72], [1517640255311.3699, 8520.11], [1517640577674.01, 8526.84], [1517640832009.1702, 8579.92], [1517641173746.44, 8635.82], [1517641463612.27, 8629.02], [1517641772545.31, 8646.22], [1517642071218.9, 8606.44], [1517642376152.2998, 8590.99], [1517642663532.34, 8572.64], [1517642978601.0898, 8598.49], [1517643276657.5798, 8575.15], [1517643576754.06, 8542.6], [1517643874353.93, 8590.52], [1517644180019.45, 8626.39], [1517644469640.04, 8621.51], [1517644777789.46, 8603.74], [1517645073680.82, 8606.6], [1517645378441.19, 8550.97], [1517645661799.99, 8547.0], [1517645976473.72, 8549.21], [1517646275438.75, 8570.61], [1517646580289.72, 8575.35], [1517646869427.68, 8629.11], [1517647171300.15, 8777.39], [1517647456570.52, 8765.06], [1517647772246.14, 8768.0], [1517648075706.1702, 8758.47], [1517648369703.42, 8830.07], [1517648668527.3699, 8830.97], [1517648977475.81, 8926.1], [1517649271803.9602, 8883.0], [1517649577423.85, 8833.51], [1517649874220.34, 8849.97], [1517650178475.97, 8797.14], [1517650477284.97, 8801.77], [1517650776410.97, 8833.36], [1517651068401.9202, 8859.91], [1517651380605.56, 8836.56], [1517651674747.3198, 8839.84], [1517651975975.41, 8842.47], [1517652269505.73, 8795.61], [1517652578934.14, 8793.67], [1517652872537.27, 8762.04], [1517653175183.77, 8741.36], [1517653470697.28, 8688.46], [1517653777719.33, 8710.45], [1517654074829.45, 8718.71], [1517654376819.9102, 8694.17], [1517654675440.5798, 8716.66], [1517654977818.5999, 8747.4], [1517655269894.24, 8741.4], [1517655575500.07, 8709.5], [1517655862537.27, 8667.19], [1517656178205.5, 8664.56], [1517656476198.75, 8715.26], [1517656775936.8801, 8739.42], [1517657069518.41, 8794.33], [1517657380057.8499, 8833.95], [1517657671406.3398, 8839.2], [1517657968883.47, 8880.17], [1517658257575.69, 8883.43], [1517658579605.6099, 8838.75], [1517658870803.25, 8854.89], [1517659174653.18, 8900.62], [1517659472462.8, 8951.49], [1517659777348.3, 8933.44], [1517660057602.78, 8900.29], [1517660376416.34, 8904.59], [1517660671098.8, 8889.31], [1517660977526.99, 8872.57], [1517661268134.53, 8859.05], [1517661574447.63, 8876.58], [1517661862422.16, 8873.22], [1517662176808.7102, 8898.02], [1517662475128.48, 8963.77], [1517662776233.3801, 8939.83], [1517663074071.5698, 8924.41], [1517663378007.14, 8891.32], [1517663670904.45, 8885.74], [1517663976361.51, 8875.04], [1517664271703.32, 8936.39], [1517664580043.8098, 8951.78], [1517664869922.3198, 8971.81], [1517665176181.9102, 9032.11], [1517665470248.01, 9093.37], [1517665781626.71, 9125.97], [1517666068226.8801, 9099.0], [1517666374866.6, 9110.06], [1517666672863.11, 9105.66], [1517666978524.28, 9086.98], [1517667272624.8901, 9167.94], [1517667576726.03, 9200.77], [1517667872153.91, 9244.01], [1517668179282.3901, 9183.21], [1517668459527.38, 9183.77], [1517668776869.8699, 9221.39], [1517669071627.11, 9227.52], [1517669374491.58, 9235.29], [1517669676184.4102, 9249.51], [1517669976857.5898, 9240.02], [1517670274972.3599, 9273.78], [1517670581669.3499, 9355.0], [1517670876498.41, 9351.85], [1517671170662.75, 9383.44], [1517671470446.0398, 9315.57], [1517671777388.8901, 9272.84], [1517672058252.82, 9259.26], [1517672379143.6602, 9266.02], [1517672676230.7, 9245.29], [1517672980114.0898, 9242.73], [1517673275312.83, 9203.51], [1517673572379.6501, 9133.97], [1517673874712.21, 9159.53], [1517674180163.5498, 9104.56], [1517674471860.58, 905 ...

# %%
#import re
#his_price = soup.select('#coin_maxd_historical_price_chart')[0].prettify()
#m = re.search('data-prices="(.*?)"', his_price) 
#print(m)
#print(m.group(0))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-993af72673ad> in <module>()
#       1 import re
# ----> 2 his_price = soup.select('#coin_maxd_historical_price_chart')[0].prettify()
#       3 m = re.search('data-prices="(.*?)"', his_price)
#       4 print(m)
#       5 print(m.group(0))
#
# IndexError: list index out of range

# %%
import pandas
df = pandas.DataFrame(eval(m.group(1)))
df.head()
# Out:
#               0        1
# 0  1.517634e+12  8367.78
# 1  1.517634e+12  8383.41
# 2  1.517635e+12  8302.86
# 3  1.517635e+12  8290.21
# 4  1.517635e+12  8279.71

# %%
m.group(1)
# Out:
# '[[1517633972864.3,8367.78],[1517634240430.67,8383.41],[1517634576127.5498,8302.86],[1517634863506.54,8290.21],[1517635172614.46,8279.71],[1517635462782.36,8329.15],[1517635776209.5598,8360.15],[1517636061287.28,8364.41],[1517636373103.1,8297.32],[1517636663673.39,8317.68],[1517636977782.48,8320.58],[1517637266404.9302,8340.62],[1517637573032.6199,8412.07],[1517637859122.04,8421.52],[1517638176858.6099,8430.52],[1517638462226.47,8417.65],[1517638774116.69,8378.7],[1517639043762.87,8397.4],[1517639374916.6501,8446.58],[1517639670163.41,8478.2],[1517639973179.01,8463.72],[1517640255311.3699,8520.11],[1517640577674.01,8526.84],[1517640832009.1702,8579.92],[1517641173746.44,8635.82],[1517641463612.27,8629.02],[1517641772545.31,8646.22],[1517642071218.9,8606.44],[1517642376152.2998,8590.99],[1517642663532.34,8572.64],[1517642978601.0898,8598.49],[1517643276657.5798,8575.15],[1517643576754.06,8542.6],[1517643874353.93,8590.52],[1517644180019.45,8626.39],[1517644469640.04,8621.51],[1517644777789.46,8603.74],[1517645073680.82,8606.6],[1517645378441.19,8550.97],[1517645661799.99,8547.0],[1517645976473.72,8549.21],[1517646275438.75,8570.61],[1517646580289.72,8575.35],[1517646869427.68,8629.11],[1517647171300.15,8777.39],[1517647456570.52,8765.06],[1517647772246.14,8768.0],[1517648075706.1702,8758.47],[1517648369703.42,8830.07],[1517648668527.3699,8830.97],[1517648977475.81,8926.1],[1517649271803.9602,8883.0],[1517649577423.85,8833.51],[1517649874220.34,8849.97],[1517650178475.97,8797.14],[1517650477284.97,8801.77],[1517650776410.97,8833.36],[1517651068401.9202,8859.91],[1517651380605.56,8836.56],[1517651674747.3198,8839.84],[1517651975975.41,8842.47],[1517652269505.73,8795.61],[1517652578934.14,8793.67],[1517652872537.27,8762.04],[1517653175183.77,8741.36],[1517653470697.28,8688.46],[1517653777719.33,8710.45],[1517654074829.45,8718.71],[1517654376819.9102,8694.17],[1517654675440.5798,8716.66],[1517654977818.5999,8747.4],[1517655269894.24,8741.4],[1517655575500.07,8709.5],[1517655862537.27,8667.19],[1517656178205.5,8664.56],[1517656476198.75,8715.26],[1517656775936.8801,8739.42],[1517657069518.41,8794.33],[1517657380057.8499,8833.95],[1517657671406.3398,8839.2],[1517657968883.47,8880.17],[1517658257575.69,8883.43],[1517658579605.6099,8838.75],[1517658870803.25,8854.89],[1517659174653.18,8900.62],[1517659472462.8,8951.49],[1517659777348.3,8933.44],[1517660057602.78,8900.29],[1517660376416.34,8904.59],[1517660671098.8,8889.31],[1517660977526.99,8872.57],[1517661268134.53,8859.05],[1517661574447.63,8876.58],[1517661862422.16,8873.22],[1517662176808.7102,8898.02],[1517662475128.48,8963.77],[1517662776233.3801,8939.83],[1517663074071.5698,8924.41],[1517663378007.14,8891.32],[1517663670904.45,8885.74],[1517663976361.51,8875.04],[1517664271703.32,8936.39],[1517664580043.8098,8951.78],[1517664869922.3198,8971.81],[1517665176181.9102,9032.11],[1517665470248.01,9093.37],[1517665781626.71,9125.97],[1517666068226.8801,9099.0],[1517666374866.6,9110.06],[1517666672863.11,9105.66],[1517666978524.28,9086.98],[1517667272624.8901,9167.94],[1517667576726.03,9200.77],[1517667872153.91,9244.01],[1517668179282.3901,9183.21],[1517668459527.38,9183.77],[1517668776869.8699,9221.39],[1517669071627.11,9227.52],[1517669374491.58,9235.29],[1517669676184.4102,9249.51],[1517669976857.5898,9240.02],[1517670274972.3599,9273.78],[1517670581669.3499,9355.0],[1517670876498.41,9351.85],[1517671170662.75,9383.44],[1517671470446.0398,9315.57],[1517671777388.8901,9272.84],[1517672058252.82,9259.26],[1517672379143.6602,9266.02],[1517672676230.7,9245.29],[1517672980114.0898,9242.73],[1517673275312.83,9203.51],[1517673572379.6501,9133.97],[1517673874712.21,9159.53],[1517674180163.5498,9104.56],[1517674471860.58,9055.29],[1517674781402.98,9026.66],[1517675079389.12,9043.55],[1517675380371.46,9097.26],[1517675661032.31,9117.15],[1517675976990.78,9169.05],[1517676279287.66,9181.45],[1517676580662.75,9160.08],[1517676863477.59,9176.54],[1517677171502.7102,9180.39],[1517677471032.0498 ...

# %%
import pandas
df = pandas.DataFrame(eval(m.group(1).replace('null', 'None')), columns=['timestamp', 'price'])
df.head()
# Out:
#       timestamp    price
# 0  1.517634e+12  8367.78
# 1  1.517634e+12  8383.41
# 2  1.517635e+12  8302.86
# 3  1.517635e+12  8290.21
# 4  1.517635e+12  8279.71

# %%
df.index = pandas.to_datetime(df['timestamp'],unit='ms')
df.index
# Out:
# DatetimeIndex(['2018-02-03 04:59:32.864300', '2018-02-03 05:04:00.430670',
#                '2018-02-03 05:09:36.127550', '2018-02-03 05:14:23.506540',
#                '2018-02-03 05:19:32.614460', '2018-02-03 05:24:22.782360',
#                '2018-02-03 05:29:36.209560', '2018-02-03 05:34:21.287280',
#                '2018-02-03 05:39:33.103100', '2018-02-03 05:44:23.673390',
#                ...
#                '2018-02-04 04:14:26.514960', '2018-02-04 04:19:37.333660',
#                '2018-02-04 04:24:25.285600', '2018-02-04 04:29:10.575890',
#                '2018-02-04 04:34:35.220300', '2018-02-04 04:39:37.654700',
#                '2018-02-04 04:44:22.925020', '2018-02-04 04:49:39.332620',
#                '2018-02-04 04:54:19.686760',        '2018-02-04 04:57:11'],
#               dtype='datetime64[ns]', name='timestamp', length=286, freq=None)

# %%
# %pylab inline
#df.index = df['timestamp']
#df.head()
df['price'].plot(kind = 'line', figsize = [20,10])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.head()
# Out:
#                                timestamp    price
# timestamp
# 2018-02-03 04:59:32.864300  1.517634e+12  8367.78
# 2018-02-03 05:04:00.430670  1.517634e+12  8383.41
# 2018-02-03 05:09:36.127550  1.517635e+12  8302.86
# 2018-02-03 05:14:23.506540  1.517635e+12  8290.21
# 2018-02-03 05:19:32.614460  1.517635e+12  8279.71

# %%
#df['mvg'] = 
#df['month_avg'] = 
df['month_avg'] = df['price'].rolling(window = 30).mean()

# %%
df[['month_avg', 'price']].plot(kind = 'line', figsize = [20,10])

# %%
import pandas_datareader
df = pandas_datareader.DataReader('AAPL', data_source = 'google', start = '2006-01-01')
df.tail()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#               Open    High     Low   Close    Volume
# Date
# 2018-01-29  170.16  170.16  167.07  167.96  50640406
# 2018-01-30  165.52  167.37  164.70  166.97  46048185
# 2018-01-31  166.87  168.44  166.50  167.43  32478930
# 2018-02-01  167.16  168.62  166.76  167.78  47230787
# 2018-02-02  166.00  166.80  160.10  160.50  86593825

# %%
df.index >= '2017-01-01'
# Out:
# array([False, False, False, ...,  True,  True,  True], dtype=bool)

# %%
df.ix[df.index >= '2017-01-01', 'Volume']
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Date
# 2017-01-03     28781865
# 2017-01-04     21118116
# 2017-01-05     22193587
# 2017-01-06     31751900
# 2017-01-09     33561948
# 2017-01-10     24462051
# 2017-01-11     27588593
# 2017-01-12     27086220
# 2017-01-13     26111948
# 2017-01-17     34439843
# 2017-01-18     23712961
# 2017-01-19     25597291
# 2017-01-20     32597892
# 2017-01-23     22050218
# 2017-01-24     23211038
# 2017-01-25     32586673
# 2017-01-26     26337576
# 2017-01-27     20562944
# 2017-01-30     30377503
# 2017-01-31     49200993
# 2017-02-01    111985040
# 2017-02-02     33710411
# 2017-02-03     24507301
# 2017-02-06     26845924
# 2017-02-07     38183841
# 2017-02-08     23004072
# 2017-02-09     28349859
# 2017-02-10     20065458
# 2017-02-13     23035421
# 2017-02-14     33226223
#                 ...
# 2017-12-20     23475649
# 2017-12-21     20949896
# 2017-12-22     16349444
# 2017-12-26     33185536
# 2017-12-27     21498213
# 2017-12-28     16480187
# 2017-12-29     25999922
# 2018-01-02     25555934
# 2018-01-03     29517899
# 2018-01-04     22434597
# 2018-01-05     23660018
# 2018-01-08     20567766
# 2018-01-09     21583997
# 2018-01-10     23959895
# 2018-01-11     18667729
# 2018-01-12     25418080
# 2018-01-16     29565947
# 2018-01-17     34386836
# 2018-01-18     31193352
# 2018-01-19     32425067
# 2018-01-22     27108551
# 2018-01-23     32689146
# 2018-01-24     51105090
# 2018-01-25     41529004
# 2018-01-26     39143011
# 2018-01-29     50640406
# 2018-01-30     46048185
# 2018-01-31     32478930
# 2018-02-01     47230787
# 2018-02-02     86593825
# Name: Volume, Length: 274, dtype: int64

# %%
df.ix[df.index >= '2017-01-01', 'Volume'].plot(kind= 'bar')

# %%
df['diff'] = df['Close'] - df['Open']
df.head()
# Out:
#              Open   High    Low  Close     Volume  diff
# Date
# 2006-01-03  10.34  10.68  10.32  10.68  201853036  0.34
# 2006-01-04  10.73  10.85  10.64  10.71  155225609 -0.02
# 2006-01-05  10.69  10.70  10.54  10.63  112396081 -0.06
# 2006-01-06  10.75  10.96  10.65  10.90  176139334  0.15
# 2006-01-09  10.96  11.03  10.82  10.86  168861224 -0.10

# %%
df['rise'] = df['diff'] > 0 
df['fall'] = df['diff'] <=  0 
df.head()
# Out:
#              Open   High    Low  Close     Volume  diff   rise   fall
# Date
# 2006-01-03  10.34  10.68  10.32  10.68  201853036  0.34   True  False
# 2006-01-04  10.73  10.85  10.64  10.71  155225609 -0.02  False   True
# 2006-01-05  10.69  10.70  10.54  10.63  112396081 -0.06  False   True
# 2006-01-06  10.75  10.96  10.65  10.90  176139334  0.15   True  False
# 2006-01-09  10.96  11.03  10.82  10.86  168861224 -0.10  False   True

# %%
df[['rise', 'fall']].sum()
# Out:
# rise    1521
# fall    1521
# dtype: int64

# %%
# %pylab inline
df[['rise', 'fall']].sum().plot(kind = 'pie', figsize = [5,5], startangle = 90, counterclock = True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df[['rise', 'fall']].sum()
# Out:
# rise    1465
# fall    1462
# dtype: int64

# %%
df['Close'].plot(kind='hist')

# %%
df['ret'] = df['Close'].pct_change(1)
df.head()
# Out:
#              Open   High    Low  Close     Volume  diff   rise   fall  \
# Date
# 2006-01-03  10.34  10.68  10.32  10.68  201853036  0.34   True  False
# 2006-01-04  10.73  10.85  10.64  10.71  155225609 -0.02  False   True
# 2006-01-05  10.69  10.70  10.54  10.63  112396081 -0.06  False   True
# 2006-01-06  10.75  10.96  10.65  10.90  176139334  0.15   True  False
# 2006-01-09  10.96  11.03  10.82  10.86  168861224 -0.10  False   True
#
#                  ret
# Date
# 2006-01-03       NaN
# 2006-01-04  0.002809
# 2006-01-05 -0.007470
# 2006-01-06  0.025400
# 2006-01-09 -0.003670

# %%
df['ret'] = df['Close'].pct_change(1)
df['ret'].plot(kind = 'hist')

# %%
df['ret'].plot(kind = 'box')

# %%
import random
import pandas
#?random_integers
random_integers(0,40, 100)
type(random_integers(0,40, 100))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. Please call randint(0, 40 + 1) instead
#   after removing the cwd from sys.path.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: This function is deprecated. Please call randint(0, 40 + 1) instead
#   """
# numpy.ndarray

# %%
import random
import pandas
#?random_integers
df = pandas.DataFrame(random_integers(0,40, 100))
print(df)
print(df.mean())
df.plot(kind = 'box')
# Out:
#      0
# 0   30
# 1    2
# 2   29
# 3   34
# 4   15
# 5   15
# 6    9
# 7   35
# 8   38
# 9   32
# 10  22
# 11  15
# 12   5
# 13  31
# 14   7
# 15  25
# 16  33
# 17  39
# 18  16
# 19  31
# 20  36
# 21  21
# 22  24
# 23  39
# 24  12
# 25  25
# 26  26
# 27  14
# 28   4
# 29  38
# ..  ..
# 70  21
# 71   6
# 72   3
# 73  31
# 74  33
# 75  24
# 76  30
# 77  23
# 78  35
# 79  10
# 80  20
# 81  25
# 82  20
# 83  39
# 84  28
# 85  25
# 86  26
# 87  26
# 88  20
# 89  21
# 90  34
# 91  40
# 92  37
# 93  36
# 94   8
# 95  12
# 96  34
# 97  15
# 98   4
# 99  25
#
# [100 rows x 1 columns]
# 0    22.07
# dtype: float64
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. Please call randint(0, 40 + 1) instead
#   after removing the cwd from sys.path.

# %%
df = df.append(pandas.DataFrame([999,999,999]))
print(df.mean())
df.plot(kind = 'box')
# Out:
# 0    50.524272
# dtype: float64

# %%
import pandas_datareader
df = pandas_datareader.DataReader(['AAPL', 'GOOG', 'MSFT'], data_source='google', start='2014-01-01')['Close']
df.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
#              AAPL    GOOG   MSFT
# Date
# 2014-01-02  79.02  556.00  37.16
# 2014-01-03  77.28  551.95  36.91
# 2014-01-06  77.70  558.10  36.13
# 2014-01-07  77.15  568.86  36.41
# 2014-01-08  77.64  570.04  35.76

# %%
ret = df.pct_change(1)
ret.head()
#type(ret)
# Out:
#                 AAPL      GOOG      MSFT
# Date
# 2014-01-02       NaN       NaN       NaN
# 2014-01-03 -0.022020 -0.007284 -0.006728
# 2014-01-06  0.005435  0.011142 -0.021132
# 2014-01-07 -0.007079  0.019280  0.007750
# 2014-01-08  0.006351  0.002074 -0.017852

# %%
ret.plot(kind = 'scatter', x = 'GOOG', y = 'MSFT')

# %% [markdown]
# ## 591看坪數跟價格

# %%
import pandas
df = pandas.read_csv('rent_591_sample.csv', index_col=0)

def normalizePrice(price):
    return int(price.replace('元/月', '').replace(',', '') )
df['price'] = df['price'].map(normalizePrice)

# %%
df.head()

# %%
import numpy as np
df['building_area'] = np.log10(df['building_area'])
df['price'] = np.log10(df['price'])

# %%
df[['building_area', 'price']].plot(kind = 'scatter', x= 'building_area', y='price')

# %%
import pandas_datareader
df = pandas_datareader.DataReader(['FB','AAPL', 'AMZN', 'MSFT', 'GOOG'], data_source = 'google', start = '2006-01-01')['Close']
#df.tail()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
#
#
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.

# %%
ret  = df.pct_change(1)

# %%
corr = ret.corr()
corr
# Out:
#           AAPL      AMZN        FB      GOOG      MSFT
# AAPL  1.000000  0.412848  0.226726  0.505748  0.436984
# AMZN  0.412848  1.000000  0.332861  0.500931  0.455255
# FB    0.226726  0.332861  1.000000  0.345987  0.233393
# GOOG  0.505748  0.500931  0.345987  1.000000  0.504092
# MSFT  0.436984  0.455255  0.233393  0.504092  1.000000

# %%
import pandas_datareader
df = pandas_datareader.DataReader(['GM','F', 'MSFT'], data_source = 'google', start = '2006-01-01')['Close']
#df.tail()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
ret  = df.pct_change(1)

# %%
corr = ret.corr()
corr
# Out:
#              F        GM     MSFT
# F     1.000000  0.710865  0.38402
# GM    0.710865  1.000000  0.37171
# MSFT  0.384020  0.371710  1.00000

# %%
# %pylab inline
import matplotlib.pyplot as plt
#corr = rets.corr()
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ([<matplotlib.axis.YTick at 0xc75a940>,
#   <matplotlib.axis.YTick at 0xc1ec8d0>,
#   <matplotlib.axis.YTick at 0xc283470>],
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# ## plotly
# - https://plot.ly/python/
# - https://plot.ly/pandas/
# - https://plot.ly/pandas/line-charts/
# - https://plot.ly/python/getting-started/

# %%
! pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-2.3.0.tar.gz (1.1MB)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\user\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: nbformat>=4.2 in c:\users\user\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: ipython_genutils in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: traitlets>=4.1 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jupyter_core in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->plotly)
# Building wheels for collected packages: plotly
#   Running setup.py bdist_wheel for plotly: started
#   Running setup.py bdist_wheel for plotly: finished with status 'done'
#   Stored in directory: C:\Users\user\AppData\Local\pip\Cache\wheels\11\0e\f6\22208411ddcbfa81a89ae341490c5d12b1df5be988aad494b6
# Successfully built plotly
# Installing collected packages: plotly
# Successfully installed plotly-2.3.0

# %%
# Hosting on Plotly 
! python -c "import plotly; plotly.tools.set_credentials_file(username='reaganwei', api_key='xxxxxxxx')"

# %%
import plotly.plotly as py
import plotly.graph_objs as go


import pandas as pd
import numpy as np

N = 500
x = np.linspace(0, 1, N)
y = np.random.randn(N)
df = pd.DataFrame({'x': x, 'y': y})
df.head()

data = [
    go.Scatter(
        x=df['x'], # assign x as the dataframe column 'x'
        y=df['y']
    )
]
# IPython notebook
# py.iplot(data, filename='pandas/basic-line-plot')

url = py.plot(data, filename='basic-line-plot')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~reaganwei/0 or inside your plot.ly account where it is named 'basic-line-plot'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd
import numpy as np

N = 500
x = np.linspace(0, 1, N)
y = np.random.randn(N)
df = pd.DataFrame({'x': x, 'y': y})
df.head()

data = [
    go.Scatter(
        x=df['x'], # assign x as the dataframe column 'x'
        y=df['y']
    )
]
# IPython notebook
# py.iplot(data, filename='pandas/basic-line-plot')
url = py.plot(data, filename='basic-line-plot')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~reaganwei/0 or inside your plot.ly account where it is named 'basic-line-plot'

# %% [markdown]
# ## 敘述性統計

# %%
import pandas
df = pandas.read_csv('https://raw.githubusercontent.com/ywchiu/tibamepy/master/data/tw2330.csv', parse_dates={'Dates':[0]})

# %%
df.head()
# Out:
#        Dates   Open   High    Low  Close    Volume  Adj Close
# 0 2016-07-21  171.0  172.0  170.0  172.0  33130000      172.0
# 1 2016-07-20  170.0  170.5  169.0  170.0  38053000      170.0
# 2 2016-07-19  170.5  170.5  169.0  170.5  42456000      170.5
# 3 2016-07-18  168.0  170.0  168.0  169.5  24749000      169.5
# 4 2016-07-15  169.5  169.5  169.5  169.5     41000      169.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3904 entries, 0 to 3903
# Data columns (total 7 columns):
# Dates        3904 non-null datetime64[ns]
# Open         3904 non-null float64
# High         3904 non-null float64
# Low          3904 non-null float64
# Close        3904 non-null float64
# Volume       3904 non-null int64
# Adj Close    3904 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 213.6 KB

# %%
df.dtypes
# Out:
# Dates        datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3904.000000  3904.000000  3904.000000  3904.000000  3.904000e+03
# mean     75.924594    76.592746    75.205547    75.939250  5.329918e+07
# std      31.671949    31.812246    31.509466    31.686305  3.269231e+08
# min      32.201900    32.938000    32.109900    32.754000  0.000000e+00
# 25%      54.826000    55.400000    54.200100    54.860425  3.126005e+07
# 50%      63.000000    63.533700    62.443800    63.023600  4.248575e+07
# 75%      88.325000    89.025000    87.700000    88.475000  5.910345e+07
# max     171.000000   172.000000   171.000000   172.000000  2.040451e+10
#
#          Adj Close
# count  3904.000000
# mean     61.916802
# std      34.915214
# min      21.536900
# 25%      38.288100
# 50%      46.848200
# 75%      78.165700
# max     172.000000

# %%
df['Close'].min()
# Out:
# 32.753999999999998

# %%
df['Close'].max()
# Out:
# 172.0

# %%
df['Close'].count()
# Out:
# 3904

# %%
df['Close'].mean()
# Out:
# 75.93924959016354

# %%
df['Close'].median()
# Out:
# 63.0236

# %%
IQR = df['Close'].quantile(0.75) - df['Close'].quantile(0.25)
IQR
# Out:
# 33.61457500000001

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3904.000000  3904.000000  3904.000000  3904.000000  3.904000e+03
# mean     75.924594    76.592746    75.205547    75.939250  5.329918e+07
# std      31.671949    31.812246    31.509466    31.686305  3.269231e+08
# min      32.201900    32.938000    32.109900    32.754000  0.000000e+00
# 25%      54.826000    55.400000    54.200100    54.860425  3.126005e+07
# 50%      63.000000    63.533700    62.443800    63.023600  4.248575e+07
# 75%      88.325000    89.025000    87.700000    88.475000  5.910345e+07
# max     171.000000   172.000000   171.000000   172.000000  2.040451e+10
#
#          Adj Close
# count  3904.000000
# mean     61.916802
# std      34.915214
# min      21.536900
# 25%      38.288100
# 50%      46.848200
# 75%      78.165700
# max     172.000000

# %%
df['Close'].plot(kind = 'box')

# %%
df['Close'].plot(kind = 'hist', bins= 20)

# %%
df['Close'].var()
# Out:
# 1004.0219018810959

# %%
df['Close'].std()
# Out:
# 31.686304642244036

# %%
df['Close'].pct_change(1).head()
# Out:
# 0         NaN
# 1   -0.011628
# 2    0.002941
# 3   -0.005865
# 4    0.000000
# Name: Close, dtype: float64

# %%
df['Close'].head()
# Out:
# 0    172.0
# 1    170.0
# 2    170.5
# 3    169.5
# 4    169.5
# Name: Close, dtype: float64

# %%
df['Close'].pct_change(1).head()
# Out:
# 0         NaN
# 1   -0.011628
# 2    0.002941
# 3   -0.005865
# 4    0.000000
# Name: Close, dtype: float64

# %%
df['DailyReturn'] = df['Close'] / df['Close'].shift(1) - 1
df['DailyReturn'].head()
# Out:
# 0         NaN
# 1   -0.011628
# 2    0.002941
# 3   -0.005865
# 4    0.000000
# Name: DailyReturn, dtype: float64

# %%
df['DailyReturn'].plot(kind = 'hist')

# %% [markdown]
# ## 股價與大盤指數的相關性

# %%
import pandas_datareader
df = pandas_datareader.DataReader(['FB','AAPL', 'AMZN', 'MSFT', 'GOOG', 'F', 'GM'], data_source = 'google', start = '2006-01-01')['Close']
df.tail()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
#
#
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#               AAPL     AMZN      F      FB     GM     GOOG   MSFT
# Date
# 2018-01-29  167.96  1417.68  11.12  185.98  43.02  1175.58  93.92
# 2018-01-30  166.97  1437.82  11.06  187.12  42.70  1163.69  92.74
# 2018-01-31  167.43  1450.89  10.97  186.89  42.41  1169.94  95.01
# 2018-02-01  167.78  1390.00  10.92  193.09  42.43  1167.70  94.26
# 2018-02-02  160.50  1429.95  10.71  190.28  41.00  1111.90  91.78

# %%
df.cov()
# Out:
#               AAPL          AMZN           F            FB          GM  \
# AAPL   2056.984698  12004.350612  103.864191   1235.233491   93.502818
# AMZN  12004.350612  85627.249600  468.336439  12799.072390  878.396928
# F       103.864191    468.336439   14.784767    -28.950696    7.113709
# FB     1235.233491  12799.072390  -28.950696   2220.783235  133.157440
# GM       93.502818    878.396928    7.113709    133.157440   31.398433
# GOOG   9832.965306  67407.385421  450.833982   9324.686854  805.759867
# MSFT    612.019083   4306.727649   22.834000    717.490089   55.329639
#
#               GOOG         MSFT
# AAPL   9832.965306   612.019083
# AMZN  67407.385421  4306.727649
# F       450.833982    22.834000
# FB     9324.686854   717.490089
# GM      805.759867    55.329639
# GOOG  55965.218289  3527.489970
# MSFT   3527.489970   236.091848

# %%
df.corr()
# Out:
#           AAPL      AMZN         F        FB        GM      GOOG      MSFT
# AAPL  1.000000  0.904518  0.595500  0.877580  0.498445  0.916452  0.878231
# AMZN  0.904518  1.000000  0.416182  0.955728  0.544429  0.973739  0.957858
# F     0.595500  0.416182  1.000000 -0.279731  0.570032  0.495551  0.386432
# FB    0.877580  0.955728 -0.279731  1.000000  0.548870  0.974735  0.974853
# GM    0.498445  0.544429  0.570032  0.548870  1.000000  0.635214  0.605319
# GOOG  0.916452  0.973739  0.495551  0.974735  0.635214  1.000000  0.970434
# MSFT  0.878231  0.957858  0.386432  0.974853  0.605319  0.970434  1.000000

# %% [markdown]
# ## 點估計

# %%
import pandas
df = pandas.read_csv('https://raw.githubusercontent.com/ywchiu/tibamepy/master/data/tw2330.csv', parse_dates={'Dates':[0]})

# %%
df.head()
# Out:
#        Dates   Open   High    Low  Close    Volume  Adj Close
# 0 2016-07-21  171.0  172.0  170.0  172.0  33130000      172.0
# 1 2016-07-20  170.0  170.5  169.0  170.0  38053000      170.0
# 2 2016-07-19  170.5  170.5  169.0  170.5  42456000      170.5
# 3 2016-07-18  168.0  170.0  168.0  169.5  24749000      169.5
# 4 2016-07-15  169.5  169.5  169.5  169.5     41000      169.5

# %%
import numpy as np
np.random.seed(10)

# %%
df['DailyReturn'] = df['Close'].pct_change(1)
sample_size = 100
sample = np.random.choice(a = df['DailyReturn'], size = sample_size)

# %%
sample.mean()
# Out:
# 0.0046790036049509454

# %%
df['DailyReturn'].mean()
# Out:
# -0.00011548281518177559

# %%
from scipy import stats
z_critical  = stats.norm.ppf(q = 0.975)
z_critical
# Out:
# 1.959963984540054

# %%
#from scipy import stats
#z_critical  = stats.norm.ppf(q = 0.025)
#z_critical

# %%
pop_stdev = df['DailyReturn'].std()

# %%
margin_of_error = z_critical * (pop_stdev / math.sqrt(sample_size))
sample.mean() - margin_of_error, sample.mean() + margin_of_error
# Out:
# (0.00073991187372230306, 0.0086180953361795869)
