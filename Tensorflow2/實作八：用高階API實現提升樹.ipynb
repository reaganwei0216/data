# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
#讀取資料
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
test = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')
y_train = train.pop('survived')
y_test = test.pop('survived')
train
# Out:
#         sex   age  n_siblings_spouses  ...     deck  embark_town alone
# 0      male  22.0                   1  ...  unknown  Southampton     n
# 1    female  38.0                   1  ...        C    Cherbourg     n
# 2    female  26.0                   0  ...  unknown  Southampton     y
# 3    female  35.0                   1  ...        C  Southampton     n
# 4      male  28.0                   0  ...  unknown   Queenstown     y
# ..      ...   ...                 ...  ...      ...          ...   ...
# 622    male  28.0                   0  ...  unknown  Southampton     y
# 623    male  25.0                   0  ...  unknown  Southampton     y
# 624  female  19.0                   0  ...        B  Southampton     y
# 625  female  28.0                   1  ...  unknown  Southampton     n
# 626    male  32.0                   0  ...  unknown   Queenstown     y
#
# [627 rows x 9 columns]

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
numeric_columns = ['age', 'fare']

feature_columns = []
#類別欄位處理
for feature_name in categorical_columns:
  #依據train的feature_name將categorical轉one-hot
  vocabulary = train[feature_name].unique()
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

#數值欄位處理
for feature_name in numeric_columns:
  feature_columns.append(tf.feature_column.numeric_column(feature_name,
                                                          dtype=tf.float32))

# %%
def make_input_fn(X, y, n_epochs=10, shuffle=True, batch_size=64):
  def input_function():
    dataset = tf.data.Dataset.from_tensor_slices((dict(X), y))
    if shuffle:
      dataset = dataset.shuffle(1000)
    dataset = dataset.batch(batch_size).repeat(n_epochs)
    return dataset
  return input_function

train_input_fn = make_input_fn(train, y_train)
test_input_fn = make_input_fn(test, y_test, n_epochs=1, shuffle=False)

# %%
params = {
  'n_trees': 50, #樹的數量
  'max_depth': 3, #樹的深度
  'n_batches_per_layer': 5, #每一層訓練批次數
}

est = tf.estimator.BoostedTreesClassifier(feature_columns, **params)
est.train(train_input_fn, max_steps=100)

results = est.evaluate(test_input_fn)
pd.Series(results).to_frame()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpsla7l56m
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpsla7l56m', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpsla7l56m/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 95...
# INFO:tensorflow:Saving checkpoints for 95 into /tmp/tmpsla7l56m/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 95...
# INFO:tensorflow:Loss for final step: 0.31662574.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-02-10T04:13:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpsla7l56m/model.ckpt-95
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.60081s
# INFO:tensorflow:Finished evaluation at 2021-02-10-04:13:39
# INFO:tensorflow:Saving dict for global step 95: accuracy = 0.7878788, accuracy_baseline = 0.625, auc = 0.8370371, auc_precision_recall = 0.80702275, average_loss = 0.4706542, global_step = 95, label/mean = 0.375, loss = 0.45484313, precision = 0.74712646, prediction/mean = 0.3973394, recall = 0.65656567
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 95: /tmp/tmpsla7l56m/model.ckpt-95
#                               0
# accuracy               0.787879
# accuracy_baseline      0.625000
# auc                    0.837037
# auc_precision_recall   0.807023
# average_loss           0.470654
# label/mean             0.375000
# loss                   0.454843
# precision              0.747126
# prediction/mean        0.397339
# recall                 0.656566
# global_step           95.000000

# %%
pred_dicts = list(est.predict(test_input_fn))
pred_dicts
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp47qeoacv/model.ckpt-97
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14014995], dtype=float32),
#   'logits': array([-1.8140451], dtype=float32),
#   'probabilities': array([0.8598501 , 0.14014997], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.321709], dtype=float32),
#   'logits': array([-0.7459291], dtype=float32),
#   'probabilities': array([0.678291  , 0.32170898], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77604127], dtype=float32),
#   'logits': array([1.242744], dtype=float32),
#   'probabilities': array([0.22395872, 0.77604127], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6254818], dtype=float32),
#   'logits': array([0.51288176], dtype=float32),
#   'probabilities': array([0.37451822, 0.6254818 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21051118], dtype=float32),
#   'logits': array([-1.321847], dtype=float32),
#   'probabilities': array([0.78948885, 0.21051118], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71164495], dtype=float32),
#   'logits': array([0.9033867], dtype=float32),
#   'probabilities': array([0.28835505, 0.711645  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5407225], dtype=float32),
#   'logits': array([0.16325152], dtype=float32),
#   'probabilities': array([0.4592775, 0.5407225], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16900367], dtype=float32),
#   'logits': array([-1.5927049], dtype=float32),
#   'probabilities': array([0.83099633, 0.16900368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5808813], dtype=float32),
#   'logits': array([0.32639226], dtype=float32),
#   'probabilities': array([0.4191187, 0.5808813], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6855153], dtype=float32),
#   'logits': array([0.7792354], dtype=float32),
#   'probabilities': array([0.3144847, 0.6855153], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60918236], dtype=float32),
#   'logits': array([0.44387653], dtype=float32),
#   'probabilities': array([0.39081767, 0.60918236], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15757328], dtype=float32),
#   'logits': array([-1.676396], dtype=float32),
#   'probabilities': array([0.8424267, 0.1575733], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8828326], dtype=float32),
#   'logits': array([2.0195317], dtype=float32),
#   'probabilities': array([0.11716742, 0.8828326 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2935387], dtype=float32),
#   'logits': array([-0.87825894], dtype=float32),
#   'probabilities': array([0.7064613 , 0.29353872], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81416357], dtype=float32),
#   'logits': array([1.4772943], dtype=float32),
#   'probabilities': array([0.18583645, 0.81416357], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6198915], dtype=float32),
#   'logits': array([0.4890879], dtype=float32),
#   'probabilities': array([0.38010845, 0.6198915 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3142445], dtype=float32),
#   'logits': array([-0.78034973], dtype=float32),
#   'probabilities': array([0.6857555, 0.3142445], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84822124], dtype=float32),
#   'logits': array([1.7207175], dtype=float32),
#   'probabilities': array([0.15177876, 0.84822124], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47765222], dtype=float32),
#   'logits': array([-0.08945073], dtype=float32),
#   'probabilities': array([0.5223478 , 0.47765222], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15757328], dtype=float32),
#   'logits': array([-1.676396], dtype=float32),
#   'probabilities': array([0.8424267, 0.1575733], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18196893], dtype=float32),
#   'logits': array([-1.5030644], dtype=float32),
#   'probabilities': array([0.81803113, 0.18196894], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64572495], dtype=float32),
#   'logits': array([0.6003001], dtype=float32),
#   'probabilities': array([0.35427505, 0.64572495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11746961], dtype=float32),
#   'logits': array([-2.0166135], dtype=float32),
#   'probabilities': array([0.88253033, 0.11746962], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6368783], dtype=float32),
#   'logits': array([0.56184065], dtype=float32),
#   'probabilities': array([0.36312166, 0.6368783 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69692034], dtype=float32),
#   'logits': array([0.83267546], dtype=float32),
#   'probabilities': array([0.30307966, 0.69692034], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18819097], dtype=float32),
#   'logits': array([-1.4618078], dtype=float32),
#   'probabilities': array([0.81180906, 0.188191  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2959], dtype=float32),
#   'logits': array([-0.8668989], dtype=float32),
#   'probabilities': array([0.7041, 0.2959], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46737638], dtype=float32),
#   'logits': array([-0.13068014], dtype=float32),
#   'probabilities': array([0.53262365, 0.46737638], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8229628], dtype=float32),
#   'logits': array([1.5365512], dtype=float32),
#   'probabilities': array([0.17703718, 0.8229628 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17914468], dtype=float32),
#   'logits': array([-1.522153], dtype=float32),
#   'probabilities': array([0.8208553, 0.1791447], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7656232], dtype=float32),
#   'logits': array([1.1837599], dtype=float32),
#   'probabilities': array([0.23437683, 0.7656232 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57080483], dtype=float32),
#   'logits': array([0.28513566], dtype=float32),
#   'probabilities': array([0.42919514, 0.57080483], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2018916], dtype=float32),
#   'logits': array([-1.3745135], dtype=float32),
#   'probabilities': array([0.7981084 , 0.20189159], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14124995], dtype=float32),
#   'logits': array([-1.8049469], dtype=float32),
#   'probabilities': array([0.85875005, 0.14124994], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17656648], dtype=float32),
#   'logits': array([-1.5397854], dtype=float32),
#   'probabilities': array([0.8234335 , 0.17656647], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15483648], dtype=float32),
#   'logits': array([-1.6971605], dtype=float32),
#   'probabilities': array([0.8451635 , 0.15483649], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.88143444], dtype=float32),
#   'logits': array([2.0060844], dtype=float32),
#   'probabilities': array([0.11856557, 0.88143444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71257764], dtype=float32),
#   'logits': array([0.9079362], dtype=float32),
#   'probabilities': array([0.28742233, 0.71257764], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21517962], dtype=float32),
#   'logits': array([-1.2939817], dtype=float32),
#   'probabilities': array([0.7848203 , 0.21517962], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49497592], dtype=float32),
#   'logits': array([-0.02009702], dtype=float32),
#   'probabilities': array([0.5050241 , 0.49497592], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2252483], dtype=float32),
#   'logits': array([-1.2353394], dtype=float32),
#   'probabilities': array([0.7747517 , 0.22524828], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34007213], dtype=float32),
#   'logits': array([-0.6629729], dtype=float32),
#   'probabilities': array([0.6599279 , 0.34007213], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.83265495], dtype=float32),
#   'logits': array([1.6045611], dtype=float32),
#   'probabilities': array([0.16734509, 0.83265483], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16900367], dtype=float32),
#   'logits': array([-1.5927049], dtype=float32),
#   'probabilities': array([0.83099633, 0.16900368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37274027], dtype=float32),
#   'logits': array([-0.52047896], dtype=float32),
#   'probabilities': array([0.62725973, 0.3727402 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4811004], dtype=float32),
#   'logits': array([-0.07563438], dtype=float32),
#   'probabilities': array([0.51889956, 0.48110038], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2850227], dtype=float32),
#   'logits': array([-0.919682], dtype=float32),
#   'probabilities': array([0.7149773, 0.2850227], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1299856], dtype=float32),
#   'logits': array([-1.9010863], dtype=float32),
#   'probabilities': array([0.8700144 , 0.12998557], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18819097], dtype=float32),
#   'logits': array([-1.4618078], dtype=float32),
#   'probabilities': array([0.81180906, 0.188191  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11588559], dtype=float32),
#   'logits': array([-2.0319834], dtype=float32),
#   'probabilities': array([0.88411444, 0.11588556], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15216777], dtype=float32),
#   'logits': array([-1.7176993], dtype=float32),
#   'probabilities': array([0.8478322 , 0.15216774], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16900367], dtype=float32),
#   'logits': array([-1.5927049], dtype=float32),
#   'probabilities': array([0.83099633, 0.16900368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9195261], dtype=float32),
#   'logits': array([2.4359248], dtype=float32),
#   'probabilities': array([0.08047395, 0.91952604], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.129002], dtype=float32),
#   'logits': array([-1.9098116], dtype=float32),
#   'probabilities': array([0.870998  , 0.12900202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3105361], dtype=float32),
#   'logits': array([-0.79761434], dtype=float32),
#   'probabilities': array([0.6894639 , 0.31053606], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66245306], dtype=float32),
#   'logits': array([0.674245], dtype=float32),
#   'probabilities': array([0.33754694, 0.662453  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8515842], dtype=float32),
#   'logits': array([1.7470803], dtype=float32),
#   'probabilities': array([0.14841582, 0.85158414], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61579764], dtype=float32),
#   'logits': array([0.4717491], dtype=float32),
#   'probabilities': array([0.38420236, 0.6157977 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27306905], dtype=float32),
#   'logits': array([-0.9791069], dtype=float32),
#   'probabilities': array([0.726931  , 0.27306902], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14321023], dtype=float32),
#   'logits': array([-1.7888784], dtype=float32),
#   'probabilities': array([0.8567897 , 0.14321029], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41337374], dtype=float32),
#   'logits': array([-0.35003582], dtype=float32),
#   'probabilities': array([0.5866263 , 0.41337377], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6157887], dtype=float32),
#   'logits': array([0.4717113], dtype=float32),
#   'probabilities': array([0.3842113 , 0.61578876], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8720035], dtype=float32),
#   'logits': array([1.9187902], dtype=float32),
#   'probabilities': array([0.12799653, 0.8720035 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42444783], dtype=float32),
#   'logits': array([-0.3045408], dtype=float32),
#   'probabilities': array([0.57555217, 0.4244478 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09991699], dtype=float32),
#   'logits': array([-2.198147], dtype=float32),
#   'probabilities': array([0.900083  , 0.09991701], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16900367], dtype=float32),
#   'logits': array([-1.5927049], dtype=float32),
#   'probabilities': array([0.83099633, 0.16900368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20856494], dtype=float32),
#   'logits': array([-1.3335973], dtype=float32),
#   'probabilities': array([0.791435  , 0.20856495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.129002], dtype=float32),
#   'logits': array([-1.9098116], dtype=float32),
#   'probabilities': array([0.870998  , 0.12900202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15483648], dtype=float32),
#   'logits': array([-1.6971605], dtype=float32),
#   'probabilities': array([0.8451635 , 0.15483649], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6571647], dtype=float32),
#   'logits': array([0.6506845], dtype=float32),
#   'probabilities': array([0.3428353, 0.6571647], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.93412006], dtype=float32),
#   'logits': array([2.65177], dtype=float32),
#   'probabilities': array([0.06587999, 0.93412   ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61579764], dtype=float32),
#   'logits': array([0.4717491], dtype=float32),
#   'probabilities': array([0.38420236, 0.6157977 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2935387], dtype=float32),
#   'logits': array([-0.87825894], dtype=float32),
#   'probabilities': array([0.7064613 , 0.29353872], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16646403], dtype=float32),
#   'logits': array([-1.6108975], dtype=float32),
#   'probabilities': array([0.833536  , 0.16646405], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9675855], dtype=float32),
#   'logits': array([3.3961968], dtype=float32),
#   'probabilities': array([0.03241453, 0.96758544], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75457317], dtype=float32),
#   'logits': array([1.1231534], dtype=float32),
#   'probabilities': array([0.2454268 , 0.75457317], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61579764], dtype=float32),
#   'logits': array([0.4717491], dtype=float32),
#   'probabilities': array([0.38420236, 0.6157977 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1700952], dtype=float32),
#   'logits': array([-1.5849525], dtype=float32),
#   'probabilities': array([0.8299048 , 0.17009524], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7771333], dtype=float32),
#   'logits': array([1.2490381], dtype=float32),
#   'probabilities': array([0.2228667, 0.7771333], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81416357], dtype=float32),
#   'logits': array([1.4772943], dtype=float32),
#   'probabilities': array([0.18583645, 0.81416357], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9482144], dtype=float32),
#   'logits': array([2.9074683], dtype=float32),
#   'probabilities': array([0.05178561, 0.9482144 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3864537], dtype=float32),
#   'logits': array([-0.46224383], dtype=float32),
#   'probabilities': array([0.6135463 , 0.38645366], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26260656], dtype=float32),
#   'logits': array([-1.0324646], dtype=float32),
#   'probabilities': array([0.7373934 , 0.26260653], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8940169], dtype=float32),
#   'logits': array([2.132445], dtype=float32),
#   'probabilities': array([0.1059831, 0.8940169], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59411], dtype=float32),
#   'logits': array([0.3809823], dtype=float32),
#   'probabilities': array([0.40589002, 0.59411   ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8720035], dtype=float32),
#   'logits': array([1.9187902], dtype=float32),
#   'probabilities': array([0.12799653, 0.8720035 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40655357], dtype=float32),
#   'logits': array([-0.3782313], dtype=float32),
#   'probabilities': array([0.59344643, 0.40655357], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13846982], dtype=float32),
#   'logits': array([-1.8280575], dtype=float32),
#   'probabilities': array([0.8615302 , 0.13846985], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4120634], dtype=float32),
#   'logits': array([-0.35544202], dtype=float32),
#   'probabilities': array([0.58793664, 0.4120634 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49836573], dtype=float32),
#   'logits': array([-0.00653714], dtype=float32),
#   'probabilities': array([0.50163424, 0.4983657 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39248687], dtype=float32),
#   'logits': array([-0.43687066], dtype=float32),
#   'probabilities': array([0.6075131 , 0.39248687], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62406516], dtype=float32),
#   'logits': array([0.50683904], dtype=float32),
#   'probabilities': array([0.3759348 , 0.62406516], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61579764], dtype=float32),
#   'logits': array([0.4717491], dtype=float32),
#   'probabilities': array([0.38420236, 0.6157977 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24433574], dtype=float32),
#   'logits': array([-1.1290541], dtype=float32),
#   'probabilities': array([0.7556643 , 0.24433573], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7129603], dtype=float32),
#   'logits': array([0.9098054], dtype=float32),
#   'probabilities': array([0.28703967, 0.71296036], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81166935], dtype=float32),
#   'logits': array([1.4608935], dtype=float32),
#   'probabilities': array([0.1883307, 0.8116693], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74461645], dtype=float32),
#   'logits': array([1.0701028], dtype=float32),
#   'probabilities': array([0.25538355, 0.7446165 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74461645], dtype=float32),
#   'logits': array([1.0701028], dtype=float32),
#   'probabilities': array([0.25538355, 0.7446165 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6368783], dtype=float32),
#   'logits': array([0.56184065], dtype=float32),
#   'probabilities': array([0.36312166, 0.6368783 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64572495], dtype=float32),
#   'logits': array([0.6003001], dtype=float32),
#   'probabilities': array([0.35427505, 0.64572495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09991699], dtype=float32),
#   'logits': array([-2.198147], dtype=float32),
#   'probabilities': array([0.900083  , 0.09991701], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.88143444], dtype=float32),
#   'logits': array([2.0060844], dtype=float32),
#   'probabilities': array([0.11856557, 0.88143444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55279106], dtype=float32),
#   'logits': array([0.21195427], dtype=float32),
#   'probabilities': array([0.4472089 , 0.55279106], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.129002], dtype=float32),
#   'logits': array([-1.9098116], dtype=float32),
#   'probabilities': array([0.870998  , 0.12900202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57080483], dtype=float32),
#   'logits': array([0.28513566], dtype=float32),
#   'probabilities': array([0.42919514, 0.57080483], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7656232], dtype=float32),
#   'logits': array([1.1837599], dtype=float32),
#   'probabilities': array([0.23437683, 0.7656232 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5902349], dtype=float32),
#   'logits': array([0.3649366], dtype=float32),
#   'probabilities': array([0.4097651 , 0.59023494], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15217379], dtype=float32),
#   'logits': array([-1.7176526], dtype=float32),
#   'probabilities': array([0.84782624, 0.15217379], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5300723], dtype=float32),
#   'logits': array([0.12043444], dtype=float32),
#   'probabilities': array([0.46992773, 0.5300723 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8281488], dtype=float32),
#   'logits': array([1.5725635], dtype=float32),
#   'probabilities': array([0.17185125, 0.8281488 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18196893], dtype=float32),
#   'logits': array([-1.5030644], dtype=float32),
#   'probabilities': array([0.81803113, 0.18196894], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7419427], dtype=float32),
#   'logits': array([1.0560904], dtype=float32),
#   'probabilities': array([0.2580573, 0.7419427], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1700952], dtype=float32),
#   'logits': array([-1.5849525], dtype=float32),
#   'probabilities': array([0.8299048 , 0.17009524], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13846982], dtype=float32),
#   'logits': array([-1.8280575], dtype=float32),
#   'probabilities': array([0.8615302 , 0.13846985], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58564615], dtype=float32),
#   'logits': array([0.3459954], dtype=float32),
#   'probabilities': array([0.41435385, 0.58564615], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13846982], dtype=float32),
#   'logits': array([-1.8280575], dtype=float32),
#   'probabilities': array([0.8615302 , 0.13846985], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12316495], dtype=float32),
#   'logits': array([-1.9627944], dtype=float32),
#   'probabilities': array([0.87683505, 0.12316494], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41337374], dtype=float32),
#   'logits': array([-0.35003582], dtype=float32),
#   'probabilities': array([0.5866263 , 0.41337377], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24788746], dtype=float32),
#   'logits': array([-1.109911], dtype=float32),
#   'probabilities': array([0.7521125 , 0.24788748], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9018531], dtype=float32),
#   'logits': array([2.2179863], dtype=float32),
#   'probabilities': array([0.09814689, 0.9018531 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14124995], dtype=float32),
#   'logits': array([-1.8049469], dtype=float32),
#   'probabilities': array([0.85875005, 0.14124994], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60918236], dtype=float32),
#   'logits': array([0.44387653], dtype=float32),
#   'probabilities': array([0.39081767, 0.60918236], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9160872], dtype=float32),
#   'logits': array([2.3903334], dtype=float32),
#   'probabilities': array([0.0839128, 0.9160872], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
# ...
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3388599], dtype=float32),
#   'logits': array([-0.66837907], dtype=float32),
#   'probabilities': array([0.66114014, 0.3388599 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15170947], dtype=float32),
#   'logits': array([-1.7212558], dtype=float32),
#   'probabilities': array([0.84829056, 0.15170948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2302877], dtype=float32),
#   'logits': array([-1.2066873], dtype=float32),
#   'probabilities': array([0.7697123 , 0.23028772], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74461645], dtype=float32),
#   'logits': array([1.0701028], dtype=float32),
#   'probabilities': array([0.25538355, 0.7446165 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3887585], dtype=float32),
#   'logits': array([-0.45253387], dtype=float32),
#   'probabilities': array([0.6112415 , 0.38875848], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4752252], dtype=float32),
#   'logits': array([-0.09918033], dtype=float32),
#   'probabilities': array([0.5247748 , 0.47522524], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18819097], dtype=float32),
#   'logits': array([-1.4618078], dtype=float32),
#   'probabilities': array([0.81180906, 0.188191  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8720035], dtype=float32),
#   'logits': array([1.9187902], dtype=float32),
#   'probabilities': array([0.12799653, 0.8720035 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.88143444], dtype=float32),
#   'logits': array([2.0060844], dtype=float32),
#   'probabilities': array([0.11856557, 0.88143444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18115082], dtype=float32),
#   'logits': array([-1.5085698], dtype=float32),
#   'probabilities': array([0.8188492 , 0.18115085], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60918236], dtype=float32),
#   'logits': array([0.44387653], dtype=float32),
#   'probabilities': array([0.39081767, 0.60918236], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16646403], dtype=float32),
#   'logits': array([-1.6108975], dtype=float32),
#   'probabilities': array([0.833536  , 0.16646405], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7065169], dtype=float32),
#   'logits': array([0.87852716], dtype=float32),
#   'probabilities': array([0.29348308, 0.7065169 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8456459], dtype=float32),
#   'logits': array([1.7008518], dtype=float32),
#   'probabilities': array([0.15435405, 0.8456459 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7300042], dtype=float32),
#   'logits': array([0.9946438], dtype=float32),
#   'probabilities': array([0.2699958, 0.7300042], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64572495], dtype=float32),
#   'logits': array([0.6003001], dtype=float32),
#   'probabilities': array([0.35427505, 0.64572495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21517962], dtype=float32),
#   'logits': array([-1.2939817], dtype=float32),
#   'probabilities': array([0.7848203 , 0.21517962], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43688163], dtype=float32),
#   'logits': array([-0.25382757], dtype=float32),
#   'probabilities': array([0.5631184 , 0.43688166], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10994089], dtype=float32),
#   'logits': array([-2.0913453], dtype=float32),
#   'probabilities': array([0.8900591 , 0.10994086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64572495], dtype=float32),
#   'logits': array([0.6003001], dtype=float32),
#   'probabilities': array([0.35427505, 0.64572495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66245306], dtype=float32),
#   'logits': array([0.674245], dtype=float32),
#   'probabilities': array([0.33754694, 0.662453  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09991699], dtype=float32),
#   'logits': array([-2.198147], dtype=float32),
#   'probabilities': array([0.900083  , 0.09991701], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11793071], dtype=float32),
#   'logits': array([-2.0121737], dtype=float32),
#   'probabilities': array([0.8820693 , 0.11793068], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79648876], dtype=float32),
#   'logits': array([1.3644918], dtype=float32),
#   'probabilities': array([0.20351122, 0.79648876], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52381223], dtype=float32),
#   'logits': array([0.09532102], dtype=float32),
#   'probabilities': array([0.47618777, 0.52381223], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81902015], dtype=float32),
#   'logits': array([1.5097232], dtype=float32),
#   'probabilities': array([0.18097983, 0.8190202 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5049202], dtype=float32),
#   'logits': array([0.01968134], dtype=float32),
#   'probabilities': array([0.49507982, 0.5049202 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1566791], dtype=float32),
#   'logits': array([-1.683148], dtype=float32),
#   'probabilities': array([0.84332097, 0.15667906], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16900367], dtype=float32),
#   'logits': array([-1.5927049], dtype=float32),
#   'probabilities': array([0.83099633, 0.16900368], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19389793], dtype=float32),
#   'logits': array([-1.4248787], dtype=float32),
#   'probabilities': array([0.8061021, 0.1938979], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12878454], dtype=float32),
#   'logits': array([-1.9117486], dtype=float32),
#   'probabilities': array([0.87121546, 0.12878454], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.740832], dtype=float32),
#   'logits': array([1.0502973], dtype=float32),
#   'probabilities': array([0.259168, 0.740832], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7065169], dtype=float32),
#   'logits': array([0.87852716], dtype=float32),
#   'probabilities': array([0.29348308, 0.7065169 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16646403], dtype=float32),
#   'logits': array([-1.6108975], dtype=float32),
#   'probabilities': array([0.833536  , 0.16646405], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2018916], dtype=float32),
#   'logits': array([-1.3745135], dtype=float32),
#   'probabilities': array([0.7981084 , 0.20189159], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.83723515], dtype=float32),
#   'logits': array([1.6377985], dtype=float32),
#   'probabilities': array([0.16276483, 0.83723515], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55882275], dtype=float32),
#   'logits': array([0.23638564], dtype=float32),
#   'probabilities': array([0.44117725, 0.55882275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86091757], dtype=float32),
#   'logits': array([1.822932], dtype=float32),
#   'probabilities': array([0.13908243, 0.86091757], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74959725], dtype=float32),
#   'logits': array([1.0964656], dtype=float32),
#   'probabilities': array([0.25040272, 0.74959725], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1189301], dtype=float32),
#   'logits': array([-2.002601], dtype=float32),
#   'probabilities': array([0.88106984, 0.11893011], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5639077], dtype=float32),
#   'logits': array([0.25703663], dtype=float32),
#   'probabilities': array([0.4360923, 0.5639077], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16933343], dtype=float32),
#   'logits': array([-1.5903587], dtype=float32),
#   'probabilities': array([0.8306666 , 0.16933344], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44696328], dtype=float32),
#   'logits': array([-0.21294804], dtype=float32),
#   'probabilities': array([0.55303675, 0.44696325], dtype=float32)}]
