# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
#sex:性別
#age:年齡
#n_siblings_spouses:船上的兄弟姊妹或配偶數
#parch:船上父母或子女數量
#fare:票價
#class:艙等
#deck:鄰近的甲板
#embark_town:登船的港口
#alone:是否單獨一人

# %%
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
train
# Out:
#      survived     sex   age  ...     deck  embark_town  alone
# 0           0    male  22.0  ...  unknown  Southampton      n
# 1           1  female  38.0  ...        C    Cherbourg      n
# 2           1  female  26.0  ...  unknown  Southampton      y
# 3           1  female  35.0  ...        C  Southampton      n
# 4           0    male  28.0  ...  unknown   Queenstown      y
# ..        ...     ...   ...  ...      ...          ...    ...
# 622         0    male  28.0  ...  unknown  Southampton      y
# 623         0    male  25.0  ...  unknown  Southampton      y
# 624         1  female  19.0  ...        B  Southampton      y
# 625         0  female  28.0  ...  unknown  Southampton      n
# 626         0    male  32.0  ...  unknown   Queenstown      y
#
# [627 rows x 10 columns]

# %%
#讀取資料
train = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
test = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')
y_train = train.pop('survived')
y_test = test.pop('survived')
train
# Out:
#         sex   age  n_siblings_spouses  ...     deck  embark_town alone
# 0      male  22.0                   1  ...  unknown  Southampton     n
# 1    female  38.0                   1  ...        C    Cherbourg     n
# 2    female  26.0                   0  ...  unknown  Southampton     y
# 3    female  35.0                   1  ...        C  Southampton     n
# 4      male  28.0                   0  ...  unknown   Queenstown     y
# ..      ...   ...                 ...  ...      ...          ...   ...
# 622    male  28.0                   0  ...  unknown  Southampton     y
# 623    male  25.0                   0  ...  unknown  Southampton     y
# 624  female  19.0                   0  ...        B  Southampton     y
# 625  female  28.0                   1  ...  unknown  Southampton     n
# 626    male  32.0                   0  ...  unknown   Queenstown     y
#
# [627 rows x 9 columns]

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
numeric_columns = ['age', 'fare']

feature_columns = []
#類別欄位處理
for feature_name in categorical_columns:
  #依據train的feature_name將categorical轉one-hot
  vocabulary = train[feature_name].unique()
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

#數值欄位處理
for feature_name in numeric_columns:
  feature_columns.append(tf.feature_column.numeric_column(feature_name,
                                                          dtype=tf.float32))

# %%
def make_input_fn(X, y, n_epochs=10, shuffle=True, batch_size=32):
  def input_function():
    dataset = tf.data.Dataset.from_tensor_slices((dict(X), y))
    if shuffle:
      dataset = dataset.shuffle(1000)
    dataset = dataset.batch(batch_size).repeat(n_epochs)
    return dataset
  return input_function

train_input_fn = make_input_fn(train, y_train)
test_input_fn = make_input_fn(test, y_test, n_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
linear_est.train(train_input_fn)
results = linear_est.evaluate(test_input_fn)
pd.Series(results).to_frame()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp2zqt_2gl
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp2zqt_2gl', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp2zqt_2gl/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 89.8348
# INFO:tensorflow:loss = 0.5351646, step = 100 (1.116 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 200...
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp2zqt_2gl/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 200...
# INFO:tensorflow:Loss for final step: 0.2335073.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-02-10T03:28:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp2zqt_2gl/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.67984s
# INFO:tensorflow:Finished evaluation at 2021-02-10-03:28:03
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.7689394, accuracy_baseline = 0.625, auc = 0.8339456, auc_precision_recall = 0.790373, average_loss = 0.4746067, global_step = 200, label/mean = 0.375, loss = 0.46611723, precision = 0.7111111, prediction/mean = 0.35477808, recall = 0.64646465
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmp2zqt_2gl/model.ckpt-200
#                                0
# accuracy                0.768939
# accuracy_baseline       0.625000
# auc                     0.833946
# auc_precision_recall    0.790373
# average_loss            0.474607
# label/mean              0.375000
# loss                    0.466117
# precision               0.711111
# prediction/mean         0.354778
# recall                  0.646465
# global_step           200.000000

# %%
pred_dicts = list(linear_est.predict(test_input_fn))
pred_dicts
# Out:
# INFO:tensorflow:Calling model_fn.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1727: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp2zqt_2gl/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06795394], dtype=float32),
#   'logits': array([-2.6185522], dtype=float32),
#   'probabilities': array([0.932046  , 0.06795393], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26455945], dtype=float32),
#   'logits': array([-1.0224037], dtype=float32),
#   'probabilities': array([0.7354405 , 0.26455945], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6693368], dtype=float32),
#   'logits': array([0.70518696], dtype=float32),
#   'probabilities': array([0.33066323, 0.6693368 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.577534], dtype=float32),
#   'logits': array([0.31265837], dtype=float32),
#   'probabilities': array([0.42246598, 0.577534  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24593247], dtype=float32),
#   'logits': array([-1.120425], dtype=float32),
#   'probabilities': array([0.75406754, 0.24593249], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72199965], dtype=float32),
#   'logits': array([0.9544025], dtype=float32),
#   'probabilities': array([0.2780003 , 0.72199965], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5290992], dtype=float32),
#   'logits': array([0.11652857], dtype=float32),
#   'probabilities': array([0.47090077, 0.5290992 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09866174], dtype=float32),
#   'logits': array([-2.2121835], dtype=float32),
#   'probabilities': array([0.9013382 , 0.09866173], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56993175], dtype=float32),
#   'logits': array([0.28157288], dtype=float32),
#   'probabilities': array([0.4300682 , 0.56993175], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.698053], dtype=float32),
#   'logits': array([0.8380435], dtype=float32),
#   'probabilities': array([0.301947, 0.698053], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.640282], dtype=float32),
#   'logits': array([0.5765882], dtype=float32),
#   'probabilities': array([0.35971805, 0.640282  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09862417], dtype=float32),
#   'logits': array([-2.212606], dtype=float32),
#   'probabilities': array([0.90137583, 0.09862417], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8356736], dtype=float32),
#   'logits': array([1.6263828], dtype=float32),
#   'probabilities': array([0.16432649, 0.8356736 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.329308], dtype=float32),
#   'logits': array([-0.7113166], dtype=float32),
#   'probabilities': array([0.670692  , 0.32930797], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80938476], dtype=float32),
#   'logits': array([1.4460177], dtype=float32),
#   'probabilities': array([0.19061519, 0.80938476], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48436275], dtype=float32),
#   'logits': array([-0.06256932], dtype=float32),
#   'probabilities': array([0.5156372 , 0.48436275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14696842], dtype=float32),
#   'logits': array([-1.7585788], dtype=float32),
#   'probabilities': array([0.8530315 , 0.14696842], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80319226], dtype=float32),
#   'logits': array([1.4063666], dtype=float32),
#   'probabilities': array([0.19680776, 0.80319226], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3298123], dtype=float32),
#   'logits': array([-0.70903414], dtype=float32),
#   'probabilities': array([0.6701877 , 0.32981226], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07984946], dtype=float32),
#   'logits': array([-2.444394], dtype=float32),
#   'probabilities': array([0.9201506 , 0.07984947], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10124311], dtype=float32),
#   'logits': array([-2.183488], dtype=float32),
#   'probabilities': array([0.8987569 , 0.10124312], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07630817], dtype=float32),
#   'logits': array([-2.4935985], dtype=float32),
#   'probabilities': array([0.9236918 , 0.07630818], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62465227], dtype=float32),
#   'logits': array([0.50934225], dtype=float32),
#   'probabilities': array([0.37534776, 0.62465227], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06262659], dtype=float32),
#   'logits': array([-2.7058918], dtype=float32),
#   'probabilities': array([0.9373734 , 0.06262659], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64492846], dtype=float32),
#   'logits': array([0.5968202], dtype=float32),
#   'probabilities': array([0.3550715 , 0.64492846], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5536146], dtype=float32),
#   'logits': array([0.21528608], dtype=float32),
#   'probabilities': array([0.4463854, 0.5536146], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1600537], dtype=float32),
#   'logits': array([-1.6578286], dtype=float32),
#   'probabilities': array([0.8399463, 0.1600537], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21940137], dtype=float32),
#   'logits': array([-1.2691584], dtype=float32),
#   'probabilities': array([0.78059864, 0.21940136], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20462447], dtype=float32),
#   'logits': array([-1.3576379], dtype=float32),
#   'probabilities': array([0.7953755 , 0.20462447], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8018613], dtype=float32),
#   'logits': array([1.3979683], dtype=float32),
#   'probabilities': array([0.19813871, 0.8018613 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11633326], dtype=float32),
#   'logits': array([-2.027621], dtype=float32),
#   'probabilities': array([0.88366675, 0.11633325], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75749904], dtype=float32),
#   'logits': array([1.1390166], dtype=float32),
#   'probabilities': array([0.24250096, 0.75749904], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17598037], dtype=float32),
#   'logits': array([-1.5438218], dtype=float32),
#   'probabilities': array([0.8240196 , 0.17598037], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6203172], dtype=float32),
#   'logits': array([0.49089485], dtype=float32),
#   'probabilities': array([0.37968278, 0.6203172 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23439078], dtype=float32),
#   'logits': array([-1.1836822], dtype=float32),
#   'probabilities': array([0.7656092 , 0.23439078], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08418704], dtype=float32),
#   'logits': array([-2.3867712], dtype=float32),
#   'probabilities': array([0.91581297, 0.08418705], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14071155], dtype=float32),
#   'logits': array([-1.8093927], dtype=float32),
#   'probabilities': array([0.8592885 , 0.14071153], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11534505], dtype=float32),
#   'logits': array([-2.0372696], dtype=float32),
#   'probabilities': array([0.88465494, 0.11534506], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.86675686], dtype=float32),
#   'logits': array([1.8725827], dtype=float32),
#   'probabilities': array([0.13324316, 0.86675686], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07774263], dtype=float32),
#   'logits': array([-2.4734206], dtype=float32),
#   'probabilities': array([0.9222574 , 0.07774264], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67866236], dtype=float32),
#   'logits': array([0.7476312], dtype=float32),
#   'probabilities': array([0.32133767, 0.67866236], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10115201], dtype=float32),
#   'logits': array([-2.1844895], dtype=float32),
#   'probabilities': array([0.89884806, 0.10115202], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39920655], dtype=float32),
#   'logits': array([-0.40877217], dtype=float32),
#   'probabilities': array([0.6007935 , 0.39920655], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22313493], dtype=float32),
#   'logits': array([-1.2474899], dtype=float32),
#   'probabilities': array([0.776865  , 0.22313495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15362963], dtype=float32),
#   'logits': array([-1.7064123], dtype=float32),
#   'probabilities': array([0.8463704 , 0.15362963], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7758436], dtype=float32),
#   'logits': array([1.241607], dtype=float32),
#   'probabilities': array([0.2241564, 0.7758436], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09864295], dtype=float32),
#   'logits': array([-2.2123947], dtype=float32),
#   'probabilities': array([0.901357  , 0.09864295], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25268948], dtype=float32),
#   'logits': array([-1.0843194], dtype=float32),
#   'probabilities': array([0.74731046, 0.25268948], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34151462], dtype=float32),
#   'logits': array([-0.6565518], dtype=float32),
#   'probabilities': array([0.6584854 , 0.34151462], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31602427], dtype=float32),
#   'logits': array([-0.7721033], dtype=float32),
#   'probabilities': array([0.68397576, 0.3160243 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08826683], dtype=float32),
#   'logits': array([-2.3349829], dtype=float32),
#   'probabilities': array([0.91173315, 0.08826683], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20267418], dtype=float32),
#   'logits': array([-1.3696637], dtype=float32),
#   'probabilities': array([0.79732585, 0.20267418], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05419025], dtype=float32),
#   'logits': array([-2.8595405], dtype=float32),
#   'probabilities': array([0.9458097 , 0.05419024], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08381672], dtype=float32),
#   'logits': array([-2.391584], dtype=float32),
#   'probabilities': array([0.9161833 , 0.08381672], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10668065], dtype=float32),
#   'logits': array([-2.1251044], dtype=float32),
#   'probabilities': array([0.8933193 , 0.10668064], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09104415], dtype=float32),
#   'logits': array([-2.300952], dtype=float32),
#   'probabilities': array([0.9089558 , 0.09104415], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15591353], dtype=float32),
#   'logits': array([-1.6889534], dtype=float32),
#   'probabilities': array([0.84408647, 0.15591352], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9347152], dtype=float32),
#   'logits': array([2.6614816], dtype=float32),
#   'probabilities': array([0.06528486, 0.9347152 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16771981], dtype=float32),
#   'logits': array([-1.6018744], dtype=float32),
#   'probabilities': array([0.8322802 , 0.16771981], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08198868], dtype=float32),
#   'logits': array([-2.4156284], dtype=float32),
#   'probabilities': array([0.91801125, 0.08198868], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21848743], dtype=float32),
#   'logits': array([-1.2745028], dtype=float32),
#   'probabilities': array([0.7815126 , 0.21848743], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53205526], dtype=float32),
#   'logits': array([0.12839705], dtype=float32),
#   'probabilities': array([0.46794477, 0.53205526], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17960593], dtype=float32),
#   'logits': array([-1.5190196], dtype=float32),
#   'probabilities': array([0.82039404, 0.17960595], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7945405], dtype=float32),
#   'logits': array([1.352515], dtype=float32),
#   'probabilities': array([0.20545952, 0.7945405 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15920554], dtype=float32),
#   'logits': array([-1.6641512], dtype=float32),
#   'probabilities': array([0.84079444, 0.15920553], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59711254], dtype=float32),
#   'logits': array([0.39344817], dtype=float32),
#   'probabilities': array([0.40288752, 0.59711254], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34677473], dtype=float32),
#   'logits': array([-0.6332467], dtype=float32),
#   'probabilities': array([0.6532253 , 0.34677473], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09039318], dtype=float32),
#   'logits': array([-2.3088436], dtype=float32),
#   'probabilities': array([0.9096068 , 0.09039319], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10591915], dtype=float32),
#   'logits': array([-2.13312], dtype=float32),
#   'probabilities': array([0.8940808 , 0.10591915], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61807936], dtype=float32),
#   'logits': array([0.481404], dtype=float32),
#   'probabilities': array([0.38192067, 0.61807936], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8813376], dtype=float32),
#   'logits': array([2.0051577], dtype=float32),
#   'probabilities': array([0.11866245, 0.8813376 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31614444], dtype=float32),
#   'logits': array([-0.7715476], dtype=float32),
#   'probabilities': array([0.6838556 , 0.31614444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0384352], dtype=float32),
#   'logits': array([-3.2195883], dtype=float32),
#   'probabilities': array([0.96156484, 0.0384352 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10394583], dtype=float32),
#   'logits': array([-2.154131], dtype=float32),
#   'probabilities': array([0.89605415, 0.10394583], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11646649], dtype=float32),
#   'logits': array([-2.0263257], dtype=float32),
#   'probabilities': array([0.8835335 , 0.11646648], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07791847], dtype=float32),
#   'logits': array([-2.4709706], dtype=float32),
#   'probabilities': array([0.92208153, 0.07791847], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09608775], dtype=float32),
#   'logits': array([-2.2414703], dtype=float32),
#   'probabilities': array([0.9039122 , 0.09608775], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11534505], dtype=float32),
#   'logits': array([-2.0372696], dtype=float32),
#   'probabilities': array([0.88465494, 0.11534506], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6793413], dtype=float32),
#   'logits': array([0.75074637], dtype=float32),
#   'probabilities': array([0.32065868, 0.6793413 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9488312], dtype=float32),
#   'logits': array([2.9201002], dtype=float32),
#   'probabilities': array([0.05116884, 0.9488312 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60450953], dtype=float32),
#   'logits': array([0.42429072], dtype=float32),
#   'probabilities': array([0.39549047, 0.60450953], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.329308], dtype=float32),
#   'logits': array([-0.7113166], dtype=float32),
#   'probabilities': array([0.670692  , 0.32930797], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14766957], dtype=float32),
#   'logits': array([-1.7529972], dtype=float32),
#   'probabilities': array([0.85233045, 0.14766957], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9156318], dtype=float32),
#   'logits': array([2.3844228], dtype=float32),
#   'probabilities': array([0.08436829, 0.9156318 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07930993], dtype=float32),
#   'logits': array([-2.45176], dtype=float32),
#   'probabilities': array([0.92069006, 0.07930994], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42398632], dtype=float32),
#   'logits': array([-0.30643034], dtype=float32),
#   'probabilities': array([0.5760137, 0.4239863], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5901428], dtype=float32),
#   'logits': array([0.36455554], dtype=float32),
#   'probabilities': array([0.40985724, 0.5901428 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08440899], dtype=float32),
#   'logits': array([-2.3838959], dtype=float32),
#   'probabilities': array([0.915591  , 0.08440898], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7862406], dtype=float32),
#   'logits': array([1.3024113], dtype=float32),
#   'probabilities': array([0.21375947, 0.7862406 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8240055], dtype=float32),
#   'logits': array([1.5437241], dtype=float32),
#   'probabilities': array([0.17599455, 0.8240055 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.94573444], dtype=float32),
#   'logits': array([2.8580732], dtype=float32),
#   'probabilities': array([0.0542655 , 0.94573444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16098861], dtype=float32),
#   'logits': array([-1.6508906], dtype=float32),
#   'probabilities': array([0.83901143, 0.16098863], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08451106], dtype=float32),
#   'logits': array([-2.382576], dtype=float32),
#   'probabilities': array([0.91548896, 0.08451106], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.93990815], dtype=float32),
#   'logits': array([2.7499082], dtype=float32),
#   'probabilities': array([0.06009183, 0.93990815], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4205708], dtype=float32),
#   'logits': array([-0.3204307], dtype=float32),
#   'probabilities': array([0.5794292, 0.4205708], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7301656], dtype=float32),
#   'logits': array([0.9954629], dtype=float32),
#   'probabilities': array([0.26983437, 0.7301656 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17790687], dtype=float32),
#   'logits': array([-1.5305934], dtype=float32),
#   'probabilities': array([0.8220931 , 0.17790689], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05621567], dtype=float32),
#   'logits': array([-2.820702], dtype=float32),
#   'probabilities': array([0.9437843 , 0.05621567], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09378678], dtype=float32),
#   'logits': array([-2.2682507], dtype=float32),
#   'probabilities': array([0.90621316, 0.09378678], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24380198], dtype=float32),
#   'logits': array([-1.1319468], dtype=float32),
#   'probabilities': array([0.756198, 0.243802], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07764576], dtype=float32),
#   'logits': array([-2.4747725], dtype=float32),
#   'probabilities': array([0.9223542 , 0.07764576], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60188454], dtype=float32),
#   'logits': array([0.41332358], dtype=float32),
#   'probabilities': array([0.39811543, 0.60188454], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41221312], dtype=float32),
#   'logits': array([-0.35482383], dtype=float32),
#   'probabilities': array([0.58778685, 0.41221312], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56504446], dtype=float32),
#   'logits': array([0.2616604], dtype=float32),
#   'probabilities': array([0.4349556 , 0.56504446], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61766285], dtype=float32),
#   'logits': array([0.47964007], dtype=float32),
#   'probabilities': array([0.38233712, 0.61766285], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16018663], dtype=float32),
#   'logits': array([-1.6568401], dtype=float32),
#   'probabilities': array([0.8398134 , 0.16018663], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7849889], dtype=float32),
#   'logits': array([1.2949796], dtype=float32),
#   'probabilities': array([0.21501115, 0.7849889 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79743856], dtype=float32),
#   'logits': array([1.3703616], dtype=float32),
#   'probabilities': array([0.20256142, 0.79743856], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7024705], dtype=float32),
#   'logits': array([0.8590899], dtype=float32),
#   'probabilities': array([0.29752952, 0.7024705 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.0602045], dtype=float32),
#   'logits': array([-2.7479153], dtype=float32),
#   'probabilities': array([0.9397955, 0.0602045], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7485153], dtype=float32),
#   'logits': array([1.0907094], dtype=float32),
#   'probabilities': array([0.25148472, 0.7485153 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.638254], dtype=float32),
#   'logits': array([0.5677939], dtype=float32),
#   'probabilities': array([0.361746, 0.638254], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63183093], dtype=float32),
#   'logits': array([0.5400794], dtype=float32),
#   'probabilities': array([0.36816913, 0.63183093], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04379382], dtype=float32),
#   'logits': array([-3.0834808], dtype=float32),
#   'probabilities': array([0.95620614, 0.04379382], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.865657], dtype=float32),
#   'logits': array([1.8630922], dtype=float32),
#   'probabilities': array([0.13434304, 0.865657  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6259336], dtype=float32),
#   'logits': array([0.51481074], dtype=float32),
#   'probabilities': array([0.37406644, 0.6259336 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07982774], dtype=float32),
#   'logits': array([-2.4446898], dtype=float32),
#   'probabilities': array([0.9201723 , 0.07982774], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61382407], dtype=float32),
#   'logits': array([0.4634152], dtype=float32),
#   'probabilities': array([0.38617593, 0.61382407], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08190662], dtype=float32),
#   'logits': array([-2.4167194], dtype=float32),
#   'probabilities': array([0.9180934 , 0.08190661], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7627911], dtype=float32),
#   'logits': array([1.1680429], dtype=float32),
#   'probabilities': array([0.23720892, 0.7627911 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50248474], dtype=float32),
#   'logits': array([0.00993913], dtype=float32),
#   'probabilities': array([0.49751523, 0.50248474], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09330124], dtype=float32),
#   'logits': array([-2.2739768], dtype=float32),
#   'probabilities': array([0.9066987 , 0.09330124], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41015074], dtype=float32),
#   'logits': array([-0.3633421], dtype=float32),
#   'probabilities': array([0.58984923, 0.41015074], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81746656], dtype=float32),
#   'logits': array([1.4992764], dtype=float32),
#   'probabilities': array([0.18253349, 0.81746656], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08782737], dtype=float32),
#   'logits': array([-2.340456], dtype=float32),
#   'probabilities': array([0.9121727 , 0.08782738], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08200831], dtype=float32),
#   'logits': array([-2.4153678], dtype=float32),
#   'probabilities': array([0.9179917, 0.0820083], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6102818], dtype=float32),
#   'logits': array([0.448497], dtype=float32),
#   'probabilities': array([0.38971817, 0.6102818 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10474187], dtype=float32),
#   'logits': array([-2.1456132], dtype=float32),
#   'probabilities': array([0.8952581 , 0.10474186], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09872896], dtype=float32),
#   'logits': array([-2.2114277], dtype=float32),
#   'probabilities': array([0.90127105, 0.09872895], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16072193], dtype=float32),
#   'logits': array([-1.6528664], dtype=float32),
#   'probabilities': array([0.8392781 , 0.16072194], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06270267], dtype=float32),
#   'logits': array([-2.7045965], dtype=float32),
#   'probabilities': array([0.93729734, 0.06270267], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6186948], dtype=float32),
#   'logits': array([0.48401207], dtype=float32),
#   'probabilities': array([0.38130516, 0.6186948 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09603275], dtype=float32),
#   'logits': array([-2.2421038], dtype=float32),
#   'probabilities': array([0.90396726, 0.09603275], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04504736], dtype=float32),
#   'logits': array([-3.0539474], dtype=float32),
#   'probabilities': array([0.95495266, 0.04504736], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07774263], dtype=float32),
#   'logits': array([-2.4734206], dtype=float32),
#   'probabilities': array([0.9222574 , 0.07774264], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09854159], dtype=float32),
#   'logits': array([-2.2135353], dtype=float32),
#   'probabilities': array([0.90145844, 0.09854159], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12749831], dtype=float32),
#   'logits': array([-1.9232614], dtype=float32),
#   'probabilities': array([0.8725017 , 0.12749831], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13337968], dtype=float32),
#   'logits': array([-1.8714011], dtype=float32),
#   'probabilities': array([0.8666203 , 0.13337968], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8890442], dtype=float32),
#   'logits': array([2.0810156], dtype=float32),
#   'probabilities': array([0.11095574, 0.8890442 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08290955], dtype=float32),
#   'logits': array([-2.4034557], dtype=float32),
#   'probabilities': array([0.9170905 , 0.08290955], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09114846], dtype=float32),
#   'logits': array([-2.2996922], dtype=float32),
#   'probabilities': array([0.90885156, 0.09114847], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64023495], dtype=float32),
#   'logits': array([0.5763841], dtype=float32),
#   'probabilities': array([0.35976502, 0.64023495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
# ...
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36448032], dtype=float32),
#   'logits': array([-0.5559705], dtype=float32),
#   'probabilities': array([0.6355197 , 0.36448032], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07567206], dtype=float32),
#   'logits': array([-2.502658], dtype=float32),
#   'probabilities': array([0.92432797, 0.07567206], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13004218], dtype=float32),
#   'logits': array([-1.9005859], dtype=float32),
#   'probabilities': array([0.8699578 , 0.13004217], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73754513], dtype=float32),
#   'logits': array([1.0332482], dtype=float32),
#   'probabilities': array([0.26245484, 0.73754513], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44993684], dtype=float32),
#   'logits': array([-0.20092577], dtype=float32),
#   'probabilities': array([0.55006313, 0.44993687], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09685288], dtype=float32),
#   'logits': array([-2.2326922], dtype=float32),
#   'probabilities': array([0.9031471 , 0.09685288], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33420575], dtype=float32),
#   'logits': array([-0.68922406], dtype=float32),
#   'probabilities': array([0.6657943 , 0.33420572], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20698895], dtype=float32),
#   'logits': array([-1.3431718], dtype=float32),
#   'probabilities': array([0.79301107, 0.20698893], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.871924], dtype=float32),
#   'logits': array([1.9180787], dtype=float32),
#   'probabilities': array([0.12807597, 0.871924  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84943247], dtype=float32),
#   'logits': array([1.7301567], dtype=float32),
#   'probabilities': array([0.15056755, 0.84943247], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11229438], dtype=float32),
#   'logits': array([-2.0675163], dtype=float32),
#   'probabilities': array([0.8877056 , 0.11229439], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6234041], dtype=float32),
#   'logits': array([0.5040223], dtype=float32),
#   'probabilities': array([0.37659585, 0.6234041 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09138729], dtype=float32),
#   'logits': array([-2.2968125], dtype=float32),
#   'probabilities': array([0.9086127 , 0.09138729], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1319733], dtype=float32),
#   'logits': array([-1.8836229], dtype=float32),
#   'probabilities': array([0.8680267, 0.1319733], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5982664], dtype=float32),
#   'logits': array([0.39824682], dtype=float32),
#   'probabilities': array([0.40173364, 0.5982664 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10473988], dtype=float32),
#   'logits': array([-2.1456344], dtype=float32),
#   'probabilities': array([0.89526016, 0.10473987], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.85819095], dtype=float32),
#   'logits': array([1.800345], dtype=float32),
#   'probabilities': array([0.14180909, 0.85819095], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7814235], dtype=float32),
#   'logits': array([1.2739811], dtype=float32),
#   'probabilities': array([0.2185765, 0.7814235], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08869772], dtype=float32),
#   'logits': array([-2.3296404], dtype=float32),
#   'probabilities': array([0.9113023 , 0.08869773], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6447775], dtype=float32),
#   'logits': array([0.5961607], dtype=float32),
#   'probabilities': array([0.35522255, 0.6447775 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10801816], dtype=float32),
#   'logits': array([-2.1111465], dtype=float32),
#   'probabilities': array([0.8919819 , 0.10801816], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24614194], dtype=float32),
#   'logits': array([-1.1192958], dtype=float32),
#   'probabilities': array([0.7538581 , 0.24614193], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08408019], dtype=float32),
#   'logits': array([-2.3881578], dtype=float32),
#   'probabilities': array([0.9159198 , 0.08408018], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64488554], dtype=float32),
#   'logits': array([0.59663254], dtype=float32),
#   'probabilities': array([0.3551145 , 0.64488554], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52477485], dtype=float32),
#   'logits': array([0.09918052], dtype=float32),
#   'probabilities': array([0.47522518, 0.52477485], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05450241], dtype=float32),
#   'logits': array([-2.8534665], dtype=float32),
#   'probabilities': array([0.94549763, 0.05450241], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17057502], dtype=float32),
#   'logits': array([-1.5815575], dtype=float32),
#   'probabilities': array([0.82942504, 0.17057501], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7757172], dtype=float32),
#   'logits': array([1.2408803], dtype=float32),
#   'probabilities': array([0.22428279, 0.7757172 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35087568], dtype=float32),
#   'logits': array([-0.61519223], dtype=float32),
#   'probabilities': array([0.6491243, 0.3508757], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7789504], dtype=float32),
#   'logits': array([1.2595601], dtype=float32),
#   'probabilities': array([0.22104962, 0.7789504 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3347704], dtype=float32),
#   'logits': array([-0.6866873], dtype=float32),
#   'probabilities': array([0.6652296, 0.3347704], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07946659], dtype=float32),
#   'logits': array([-2.4496167], dtype=float32),
#   'probabilities': array([0.92053336, 0.07946658], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.101254], dtype=float32),
#   'logits': array([-2.1833682], dtype=float32),
#   'probabilities': array([0.8987461 , 0.10125401], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10957953], dtype=float32),
#   'logits': array([-2.0950432], dtype=float32),
#   'probabilities': array([0.8904205 , 0.10957953], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.02295394], dtype=float32),
#   'logits': array([-3.7510443], dtype=float32),
#   'probabilities': array([0.9770461 , 0.02295394], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8248392], dtype=float32),
#   'logits': array([1.5494838], dtype=float32),
#   'probabilities': array([0.17516084, 0.8248392 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66899014], dtype=float32),
#   'logits': array([0.70362127], dtype=float32),
#   'probabilities': array([0.33100984, 0.66899014], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13197412], dtype=float32),
#   'logits': array([-1.8836157], dtype=float32),
#   'probabilities': array([0.86802584, 0.1319741 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20173684], dtype=float32),
#   'logits': array([-1.3754742], dtype=float32),
#   'probabilities': array([0.79826313, 0.20173684], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8290382], dtype=float32),
#   'logits': array([1.578826], dtype=float32),
#   'probabilities': array([0.17096183, 0.8290382 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3722315], dtype=float32),
#   'logits': array([-0.5226554], dtype=float32),
#   'probabilities': array([0.6277685, 0.3722315], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08219294], dtype=float32),
#   'logits': array([-2.4129179], dtype=float32),
#   'probabilities': array([0.9178071 , 0.08219294], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79472154], dtype=float32),
#   'logits': array([1.3536246], dtype=float32),
#   'probabilities': array([0.20527843, 0.79472154], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7616856], dtype=float32),
#   'logits': array([1.161943], dtype=float32),
#   'probabilities': array([0.23831442, 0.7616856 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07170694], dtype=float32),
#   'logits': array([-2.56076], dtype=float32),
#   'probabilities': array([0.9282931 , 0.07170694], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48600805], dtype=float32),
#   'logits': array([-0.05598241], dtype=float32),
#   'probabilities': array([0.51399195, 0.48600805], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16771981], dtype=float32),
#   'logits': array([-1.6018744], dtype=float32),
#   'probabilities': array([0.8322802 , 0.16771981], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3660493], dtype=float32),
#   'logits': array([-0.5492032], dtype=float32),
#   'probabilities': array([0.6339507 , 0.36604926], dtype=float32)}]
